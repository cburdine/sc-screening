# %% [markdown]
# # SuperCon Dataset: Initial Exploration
# ---
#
# This is a notebook contining some of my initial explorations of the SuperCon dataset.

# %% [markdown]
# ### Dependencies:
#
# To run this notebook you will need to run `pip3 install <dependency>` for all of the packages listed below. These dependencies are preinstalled in this project's associated Docker container:

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import tqdm
import pymatgen

# %% [markdown]
# ### Datasets:
# Download each of the following and configure the path variables below:
#
# * [Tc SuperCon Dataset (CSV)](https://github.com/vstanev1/Supercon).
# * [Periodic Table of Elements (CSV)](https://gist.github.com/GoodmanSciences/c2dd862cd38f21b0ad36b8f96b4bf1ee)

# %%
SUPERCON_CSV = '/media/colin/Shared/colin/git/materials-ml/\
jupyter/supercond-exploration/data/Supercon-master/Supercon_data.csv'

SUPERCON_V2_CSV = '/media/colin/Shared/colin/git/materials-ml/\
jupyter/supercond-exploration/data/Supercon-master/supercon2_v22.12.03.csv'

PTABLE_CSV = '/media/colin/Shared/colin/git/materials-ml/\
jupyter/supercond-exploration/data/PTable/PeriodicTable.csv'

# %% [markdown]
# This is the path that the cleaned data will be exported to:

# %%
CLEANED_SUPERCON_V2_CSV = '/media/colin/Shared/colin/git/materials-ml/\
jupyter/supercond-exploration/data/Supercon-master/supercon2_cleaned.csv'

# %% [markdown]
# ### Configure Matplotlib:

# %%
from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap

# if set to None, figures will not be saved:
FIGURE_OUTPUT_DIR = './figures' 

# This sets the pdf rendering to be pdflatex-compatible:
plt.rcParams.update({
    'pgf.texsystem' : 'pdflatex'
})

# use seaborn plot style:
plt.style.use('seaborn')

# %% [markdown]
# ## Load Periodic Table Data:

# %%
ptable_df = pd.read_csv(PTABLE_CSV)
ptable_df # render in notebook
# Out:
#      AtomicNumber      Element Symbol  AtomicMass  NumberofNeutrons  \
# 0               1     Hydrogen      H       1.007                 0
# 1               2       Helium     He       4.002                 2
# 2               3      Lithium     Li       6.941                 4
# 3               4    Beryllium     Be       9.012                 5
# 4               5        Boron      B      10.811                 6
# ..            ...          ...    ...         ...               ...
# 113           114    Flerovium     Fl     289.000               175
# 114           115    Moscovium     Mc     288.000               173
# 115           116  Livermorium     Lv     292.000               176
# 116           117   Tennessine     Ts     295.000               178
# 117           118    Oganesson     Og     294.000               176
#
#      NumberofProtons  NumberofElectrons  Period  Group       Phase  ...  \
# 0                  1                  1       1    1.0         gas  ...
# 1                  2                  2       1   18.0         gas  ...
# 2                  3                  3       2    1.0       solid  ...
# 3                  4                  4       2    2.0       solid  ...
# 4                  5                  5       2   13.0       solid  ...
# ..               ...                ...     ...    ...         ...  ...
# 113              114                114       7   14.0  artificial  ...
# 114              115                115       7   15.0  artificial  ...
# 115              116                116       7   16.0  artificial  ...
# 116              117                117       7   17.0  artificial  ...
# 117              118                118       7   18.0  artificial  ...
#
#     FirstIonization   Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 0           13.5984  0.000090       14.175        20.28              3.0
# 1           24.5874  0.000179          NaN         4.22              5.0
# 2            5.3917  0.534000      453.850      1615.00              5.0
# 3            9.3227  1.850000     1560.150      2742.00              6.0
# 4            8.2980  2.340000     2573.150      4200.00              6.0
# ..              ...       ...          ...          ...              ...
# 113             NaN       NaN          NaN          NaN              NaN
# 114             NaN       NaN          NaN          NaN              NaN
# 115             NaN       NaN          NaN          NaN              NaN
# 116             NaN       NaN          NaN          NaN              NaN
# 117             NaN       NaN          NaN          NaN              NaN
#
#      Discoverer    Year  SpecificHeat  NumberofShells  NumberofValence
# 0     Cavendish  1766.0        14.304               1              1.0
# 1       Janssen  1868.0         5.193               1              NaN
# 2     Arfvedson  1817.0         3.582               2              1.0
# 3    Vaulquelin  1798.0         1.825               2              2.0
# 4    Gay-Lussac  1808.0         1.026               2              3.0
# ..          ...     ...           ...             ...              ...
# 113         NaN  1999.0           NaN               7              4.0
# 114         NaN  2010.0           NaN               7              5.0
# 115         NaN  2000.0           NaN               7              6.0
# 116         NaN  2010.0           NaN               7              7.0
# 117         NaN  2006.0           NaN               7              8.0
#
# [118 rows x 28 columns]

# %%
supercon_df = pd.read_csv(SUPERCON_CSV)
supercon2_df = pd.read_csv(SUPERCON_V2_CSV)

supercon2_df # view in notebook
# Out:
#                              id                       rawMaterial  \
# 0      61ba959a7c13e4f711c50c3e                       InO x films
# 1      61ba959a0cb3d3a5e6c50c3e         x = 0.04, 0.05, and 0.06)
# 2      61ba959a720b8b3d36c50c3e              amorphous In-O films
# 3      61ba959a6a35f302ddc50c3e                          x= 0.108
# 4      61ba959a85b12ae79ac50c3e                       PrRu 2 Si 2
# ...                         ...                               ...
# 40319  61ba9fbb3136e52869c51390                  NbSe 2 nanobelts
# 40320  61ba9fbb0a416aa3d9c51367                             MgB 2
# 40321  61ba9fbcab9e3e9324c5138b                             CaBi2
# 40322  61ba9fbcab9e3e9324c5138c         single-crystalline CaBi 2
# 40323  61ba9fbc5cc438644dc51362  single crystals of Cd 2 Re 2 O 7
#
#          materialId name        formula doping               shape  \
# 0      1.942078e+09  NaN          InO x    NaN               films
# 1      1.064204e+09  NaN            NaN    NaN                 NaN
# 2     -1.411819e+09  NaN           In-O    NaN               films
# 3      4.969883e+08  NaN            NaN    NaN                 NaN
# 4     -5.030707e+08  NaN    PrRu 2 Si 2    NaN                 NaN
# ...             ...  ...            ...    ...                 ...
# 40319  1.325648e+09  NaN         NbSe 2    NaN           nanobelts
# 40320  1.438579e+09  NaN          MgB 2    NaN                 NaN
# 40321 -1.219075e+09  NaN          CaBi2    NaN                 NaN
# 40322 -2.079131e+09  NaN         CaBi 2    NaN  single-crystalline
# 40323  9.498040e+08  NaN  Cd 2 Re 2 O 7    NaN     single crystals
#
#          materialClass fabrication substrate  ... appliedPressure section  \
# 0               Oxides         NaN       NaN  ...             NaN    body
# 1                  NaN         NaN       NaN  ...             NaN    body
# 2               Alloys         NaN       NaN  ...             NaN    body
# 3                  NaN         NaN       NaN  ...             NaN    body
# 4               Alloys         NaN       NaN  ...             NaN  header
# ...                ...         ...       ...  ...             ...     ...
# 40319    Chalcogenides         NaN       NaN  ...             NaN    body
# 40320  Alloys, Borides         NaN       NaN  ...             NaN    body
# 40321           Alloys         NaN       NaN  ...             NaN  header
# 40322           Alloys         NaN       NaN  ...             NaN    body
# 40323           Oxides         NaN       NaN  ...             NaN    body
#
#       subsection        hash  \
# 0         figure  b7d13f231a
# 1      paragraph  67f5567e75
# 2            NaN  e74ca47303
# 3         figure  c8fb7503bc
# 4       abstract  e8285dd0b7
# ...          ...         ...
# 40319  paragraph  7767ae827b
# 40320  paragraph  eb762175eb
# 40321   abstract  04bc481d97
# 40322  paragraph  04bc481d97
# 40323  paragraph  a18267f5b4
#
#                                                    title  \
# 0      Infinite-randomness fixed point of the quantum...
# 1      Tuning the interplay between nematicity and sp...
# 2      Scaling analysis of the magnetic field-tuned q...
# 3      Doping evolution of antiferromagnetism and tra...
# 4                 Crystal-field interactions in PrRu2Si2
# ...                                                  ...
# 40319  Magnetic switching of phase-slip dissipation i...
# 40320  Effects of Al doping on the structural and ele...
# 40321  Observation of topological surface state in a ...
# 40322  Observation of topological surface state in a ...
# 40323  Structural phase transition in the superconduc...
#
#                                  doi  \
# 0         10.1103/physrevb.99.054515
# 1         10.1038/s41467-018-04471-7
# 2                   10.1134/1.568304
# 3                                NaN
# 4        10.1088/0953-8984/12/34/307
# ...                              ...
# 40319     10.1103/physrevb.75.020501
# 40320     10.1103/physrevb.66.012511
# 40321                            NaN
# 40322                            NaN
# 40323  10.1016/s0022-3697(02)00090-2
#
#                                                  authors  \
# 0      Nicholas A Lewellyn, Ilana M Percher, J J Nels...
# 1      S-H Baek, Dilip Bhoi, Woohyun Nam, Bumsung Lee...
# 2      V F Gantmakher, M V Golubkov, V T Dolgopolov, ...
# 3      Rui Zhang, Dongliang Gong, Xingye Lu, Shiliang...
# 4                    R Michalski, Z Ropka, R J Radwanski
# ...                                                  ...
# 40319  Abram Falk, Mandar M Deshmukh, Amy L Prieto, J...
# 40320                  O De La Peña, A Aguayo, R De Coss
# 40321  Gyanendra Dhakal, M Mofazzel Hosen, Ayana Ghos...
# 40322  Gyanendra Dhakal, M Mofazzel Hosen, Ayana Ghos...
# 40323   M Hanawa, J Yamaura, Y Muraoka, F Sakai, Z Hiroi
#
#                                      publisher  \
# 0              American Physical Society (APS)
# 1      Springer Science and Business Media LLC
# 2                      Pleiades Publishing Ltd
# 3                                          NaN
# 4                               IOP Publishing
# ...                                        ...
# 40319          American Physical Society (APS)
# 40320          American Physical Society (APS)
# 40321                                      NaN
# 40322                                      NaN
# 40323                              Elsevier BV
#
#                                                  journal    year
# 0                                      Physical Review B  2019.0
# 1                                  Nature Communications  2018.0
# 2      Journal of Experimental and Theoretical Physic...  1998.0
# 3                                                    NaN  2015.0
# 4                   Journal of Physics: Condensed Matter  2014.0
# ...                                                  ...     ...
# 40319                                  Physical Review B  2007.0
# 40320                                  Physical Review B  2014.0
# 40321                                                NaN  2019.0
# 40322                                                NaN  2019.0
# 40323         Journal of Physics and Chemistry of Solids  2001.0
#
# [40324 rows x 23 columns]

# %%
from pprint import pprint
pprint(list(supercon2_df.columns))
# Out:
# ['id',
#  'rawMaterial',
#  'materialId',
#  'name',
#  'formula',
#  'doping',
#  'shape',
#  'materialClass',
#  'fabrication',
#  'substrate',
#  'variables',
#  'criticalTemperature',
#  'criticalTemperatureMeasurementMethod',
#  'appliedPressure',
#  'section',
#  'subsection',
#  'hash',
#  'title',
#  'doi',
#  'authors',
#  'publisher',
#  'journal',
#  'year']

# %%
pd.set_option("display.max_rows", 2000)
parse_test_df = supercon2_df[['rawMaterial', 'formula', 'variables', 'criticalTemperature', 'appliedPressure']]

parse_test_df_samples = parse_test_df[:50]
display(parse_test_df_samples)
# Out:
#                                           rawMaterial  \
# 0                                         InO x films
# 1                           x = 0.04, 0.05, and 0.06)
# 2                                amorphous In-O films
# 3                                            x= 0.108
# 4                                         PrRu 2 Si 2
# 5                                          Lu3Os4Ge13
# 6                                          LaMnO 3.04
# 7              doping con- centrations 0.06 < x ≤ 0.1
# 8                             La 0.8 Ca 0.2 MnO 3.015
# 9                                          LaMnO 3.06
# 10                                        LaMnO 3.045
# 11                                           x = 0.23
# 12                          La 0.87 Ca 0.13 MnO 3.035
# 13                                          Ru-(1222)
# 14                                          Ru-(1212)
# 15                               (Li 1−x Fe x )OHFeSe
# 16                                    Li1−xFex)OHFeSe
# 17                                    A x Fe 2−y Se 2
# 18                           (Li1−xFex)OHFeSe crystal
# 19                           Fe 1+x Se single crystal
# 20                                monolayer FeSe film
# 21                                               SCFs
# 22            A x Fe 2−y Se 2 (A=K, Rb, Cs, Tl, etc.)
# 23                                       FeSe/SrTiO 3
# 24                               (Li 1−x Fe x OH)FeSe
# 25                                       0.11 BSCCO-o
# 26                            0.15 YBCO 123 (Ca=0.00)
# 27                                      bulk 2H-TaS 2
# 28                                         Sr 2 RuO 4
# 29               O-enriched single-crystalline sample
# 30                            Mn-substituted crystals
# 31                                          x ≈ 0.575
# 32               optimally doped BaFe 1.9 Ni 0.1 As 2
# 33                                             LaH 10
# 34                                        Sc 20 BC 27
# 35                                              H 3 S
# 36                                              MgB 2
# 37                      Nb 3 Ga, Nb 3 Ge, and Nb 3 Si
# 38                                 V 3 Ga and Nb 3 Sn
# 39                                            Nb 3 Sn
# 40                                             V 3 Si
# 41                   Y 0.54 Pr 0.46 Ba 2 Cu 3 O 71-δ4
# 42                                               FeSe
# 43                                           FeSe 1−x
# 44                                           FeSe 1−x
# 45                                           FeSe 1−x
# 46                                             NaFeAs
# 47                                             V42226
# 48  fluorine-doped La-Fe arsenide oxide LaFeAsO 1-...
# 49                                        LaFe 2 As 2
#
#                              formula           variables criticalTemperature  \
# 0                              InO x                 NaN               2.8 K
# 1                                NaN  x=0.04, 0.05, 0.06                 2 K
# 2                               In-O                 NaN                 2 K
# 3                                NaN             x=0.108                20 K
# 4                        PrRu 2 Si 2                 NaN                 14K
# 5                         Lu3Os4Ge13                 NaN              2.85 K
# 6                         LaMnO 3.04                 NaN               125 K
# 7                                NaN     x=≤ 0.1, 0.06 <               140 K
# 8            La 0.8 Ca 0.2 MnO 3.015                 NaN               190 K
# 9                         LaMnO 3.06                 NaN       125 and 150 K
# 10                       LaMnO 3.045                 NaN                130K
# 11                               NaN              x=0.23               140 K
# 12         La 0.87 Ca 0.13 MnO 3.035                 NaN               170 K
# 13                               NaN                 NaN            30 -35 K
# 14                               NaN                 NaN                45 K
# 15              (Li 1−x Fe x )OHFeSe                 NaN                 40K
# 16                   Li1−xFex)OHFeSe                 NaN                 40K
# 17                   A x Fe 2−y Se 2                 NaN                 32K
# 18                  (Li1−xFex)OHFeSe                 NaN                 50K
# 19                         Fe 1+x Se                 NaN                  8K
# 20                              FeSe                 NaN                 65K
# 21                              SCFs                 NaN                29 K
# 22                   A x Fe 2−y Se 2     A=K, Rb, Cs, Tl            30 − 40K
# 23                      FeSe/SrTiO 3                 NaN           60 − 100K
# 24              (Li 1−x Fe x OH)FeSe                 NaN                 40K
# 25                               NaN                 NaN                77 K
# 26                               NaN             Ca=0.00                90 K
# 27                          2H-TaS 2                 NaN                2.7K
# 28                        Sr 2 RuO 4                 NaN               1.2 K
# 29                               NaN                 NaN               1.5 K
# 30                               NaN                 NaN                25 K
# 31                               NaN             x=0.575              24.2 K
# 32              BaFe 1.9 Ni 0.1 As 2                 NaN                20 K
# 33                            LaH 10                 NaN               260 K
# 34                       Sc 20 BC 27                 NaN               7.7 K
# 35                             H 3 S                 NaN               203 K
# 36                             MgB 2                 NaN                39 K
# 37     Nb 3 Ga, Nb 3 Ge, and Nb 3 Si                 NaN                23 K
# 38                V 3 Ga and Nb 3 Sn                 NaN             15-18 K
# 39                           Nb 3 Sn                 NaN                18 K
# 40                            V 3 Si                 NaN                17 K
# 41  Y 0.54 Pr 0.46 Ba 2 Cu 3 O 71-δ4                 NaN                38 K
# 42                              FeSe                 NaN               300 K
# 43                          FeSe 1−x                 NaN               6÷8 K
# 44                          FeSe 1−x                 NaN                 8 K
# 45                          FeSe 1−x                 NaN                37 K
# 46                            NaFeAs                 NaN           9K to 18K
# 47                      V42226V42226                 NaN              37.2 K
# 48                   LaFeAsO 1-x F x                 NaN                ~26K
# 49                       LaFe 2 As 2                 NaN              12.1 K
#
#      appliedPressure
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19  ambient pressure
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# 30               NaN
# 31               NaN
# 32               NaN
# 33               NaN
# 34               NaN
# 35               NaN
# 36               NaN
# 37               NaN
# 38               NaN
# 39               NaN
# 40               NaN
# 41               NaN
# 42               NaN
# 43               NaN
# 44               NaN
# 45             9 GPa
# 46               NaN
# 47               NaN
# 48               NaN
# 49               NaN

# %%
from sctk.materials import Superconductor, PeriodicTable
import re

FORMULA_XLAT_TABLE = str.maketrans(
    "−", 
    "-")

VARIABLE_ELEMENT_RE = r'([A-Z][A-Z]?)([~ ]*=[~ ]*([A-Z][a-z]?[,]?[ ]*)+)'
VARIABLE_ASSIGNMENT_RE = r'([a-zαβγδ])[ ]*[≤<>~]?=[≤<>~]?[ ]*(\d*[\./]\d+)'
TC_RE = r'[~ ]*((\d*[\.])?\d+)([~ ]*±[~ ]*((\d*[\.])?\d+))?'
TC_RANGE_RE = TC_RE + TC_RE

ELEMENT_RE = '('+'|'.join(sorted(PeriodicTable.keys(), key=lambda x: -len(x)))+')'

def parse_Tc(s):
    if not isinstance(s,str):
        return None
    
    values = []
    for match in re.finditer(TC_RE, s):
        values.append(float(match.group(1)))
    
    return values[0] if len(values) == 1 else None

def parse_pressure(s):
    if not isinstance(s,str):
        return 0.0
    
    values = []
    for match in re.finditer(TC_RE, s):
        values.append(float(match.group(1)))
    
    return max(values) if values else 0.0

def parse_classes(s):
    if not isinstance(s, str):
        return []
    return [ item.strip() for item in s.split(',') ]

def find_max_count(formula):
    m = 0
    for (elem, count) in formula:
        if isinstance(count, list):
            m = find_max_count(elem)
        elif isinstance(count,int) or isinstance(count,float):
            m = max(m,count)
            
    return m

def parse_row_data(row, supercon_df):
    
    # parse row entries:
    formula = row['formula']
    raw_material = row['rawMaterial']
    variables = row['variables']
    row_Tc = parse_Tc(row['criticalTemperature'])
    pressure = parse_pressure(row['appliedPressure'])
    shape = row['shape'] if isinstance(row['shape'],str) else ''
    classes = parse_classes(row['materialClass'])
    substrate = row['substrate'] if isinstance(row['substrate'],str) else ''
    doi = row['doi']
    
    # ignore materials with no Tc listed:
    if not row_Tc:
        return []
    
    # compile metadata:
    metadata = {
        'Tc' : row_Tc,
        'pressure': pressure,
        'shape' : shape,
        'classes' : classes,
        'substrate' : substrate,
        'doi' : doi
    }
    
    # find database fields that came from the same paper:
    samepaper_rows = supercon_df[supercon_df['doi'] == row['doi']] if row['doi'] else []
    samepaper_fields = [ r['variables']   for _, r in samepaper_rows.iterrows() ] + \
                       [ r['rawMaterial'] for _, r in samepaper_rows.iterrows() ]
    samepaper_Tc = [ r['criticalTemperature'] for _, r in samepaper_rows.iterrows() ]*2
    
    # try to parse formula directly:
    parsed_materials = []
    if isinstance(formula, str):
        formula = formula.translate(FORMULA_XLAT_TABLE)
        try:
            material = Superconductor(formula)
            parsed_materials.append(material)
        except:
            pass
        
        # if parsing failed, try searching for variable elements elsewhere in the same paper:
        if not parsed_materials:
            for field in samepaper_fields:
                if isinstance(field, str) and (match := re.match(VARIABLE_ELEMENT_RE, field)):
                    variable = match.group(1)
                    sub_list = match.group(2)
                    substituted_elements = [
                        m.group(0) for m in re.finditer(ELEMENT_RE, sub_list)
                    ]

                    # try applying each substitution:
                    for sub in substituted_elements:
                        try:
                            material = Superconductor(formula, variable_elements=[variable])
                        except:
                            continue
                        
                        material.substitute_element(variable,sub)
                        if not material.variable_elements:
                            parsed_materials.append(material)
                
    # apply substitutions to variables in the formula:
    substituted_materials = []
    for material in parsed_materials:
        
        # ignore if material has large max count or too many variables:
        if find_max_count(material.formula) >= 100 or len(material.variables) > 6:
            continue
        
        possible_substitutions = {}
        substitutions = {}
        if material.variables:
            if isinstance(variables, str) and (match := re.match(VARIABLE_ASSIGNMENT_RE, variables)):
                v, val = match.group(1), float(eval(match.group(2)))
                possible_substitutions[v] = set([val])
            else:
                # look for variables to substitute elsewhere in paper (with same reported Tc):
                for field, Tc_str in zip(samepaper_fields, samepaper_Tc):
                    if parse_Tc(Tc_str) == row_Tc and \
                       isinstance(field,str) and (match := re.match(VARIABLE_ASSIGNMENT_RE, field)):
                        v, val = match.group(1), float(eval(match.group(2)))
                        
                        # add parsed value (from elsewhere in the paper) to set of possible substitutions:
                        if v not in possible_substitutions:
                            possible_substitutions[v] = set()
                        possible_substitutions[v].add(val)
            
            
            for v in material.variables:
                substitutions[v] = list(possible_substitutions[v]) \
                                    if v in possible_substitutions else []
        
        #--------------------------------------------------------------------------------
        # apply manual filters based on composition:
        material_comp = material.get_composition()
        
        # 1. filter out corrupted Y entries (metallic Y has max Tc of 25K)
        if len(material_comp) == 1 and 'Y' in material_comp and row_Tc > 25.0:
            continue
            
        # 2. remove materials with undefined or ambiguous pristine structures (e.g. of the form "Al 0.01")
        if not material.get_pristine_material() or \
            None in material.get_pristine_material().get_composition().values():
            continue
            
        # 3. fiter out any materials with Tc > 280 K without applied pressure or indicated features
        #    (this should screen out most of the Curie temperatures accidentally parsed):
        if row_Tc > 280 and pressure <= 1e-5:
            continue
            
        # account for unlisted pressure in high-Tc Hydrides:
        if row_Tc > 140 and pressure <= 1e-5:
            if 'Hydrides' in classes:
                metadata['pressure'] = 170.0
            else:
                continue
            
        substituted_materials.append((material, substitutions, metadata))
        
        
    return substituted_materials

# %%
from tqdm import tqdm

supercon_list = []
for i, row in tqdm(supercon2_df.iterrows()):
    supercon_list.extend(parse_row_data(row, supercon2_df))
    
known_materials = []
for mat, subs, md in supercon_list:
    empty_sublist = False
    for v in subs.values():
        if len(v) == 0:
            empty_sublist = True
                
    if not empty_sublist:
        known_materials.append((mat,subs, md))
# Out:
# 40324it [03:13, 208.46it/s]

# %%
print('Parsed Materials: ', len(supercon_list), 'of', len(supercon2_df))
print('Materials with specified doping: ', len(known_materials), 'of', len(supercon_list))
# Out:
# Parsed Materials:  23881 of 40324
# Materials with specified doping:  19466 of 23881

# %% [markdown]
# # Export Parsed Dataset to CSV:

# %%
cleaned_supercon2_df = pd.DataFrame(index=np.arange(0, len(supercon_list)),columns=(
    'Material', 'Substitutions', 'Tc (K)', 'Pressure (GPa)', 'Classes', 'Shape', 'Substrate', 'DOI'))

for i, (material, subs, metadata) in enumerate(tqdm(supercon_list)):
    cleaned_supercon2_df.loc[i] = [
        material.get_formula_string(fmt='cod'),
        str(subs),
        metadata['Tc'],
        str(metadata['pressure']),
        str(metadata['classes']),
        str(metadata['shape']),
        str(metadata['substrate']),
        str(metadata['doi']),
    ]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23881/23881 [00:02<00:00, 8969.15it/s]

# %%
cleaned_supercon2_df[cleaned_supercon2_df['Tc (K)'] > 150]
# Out:
#                                 Material Substitutions  Tc (K) Pressure (GPa)  \
# 14                               La H 10            {}   260.0          170.0
# 16                                 H 3 S            {}   203.0          170.0
# 218                                H 3 S            {}   203.0          150.0
# 392                              La H 10            {}   260.0          170.0
# 410              Hg Ba 2 Ca 2 Cu 3 O 8+δ     {'δ': []}   160.0           30.0
# 518                              La H 10            {}   265.0          190.0
# 519                                Y H 6            {}   264.0          120.0
# 520                                Y H 6            {}   290.0          300.0
# 522                                Y H 6            {}   260.0          120.0
# 540                                H 2 S            {}   203.0          170.0
# 618                             Si 2 H 6            {}   153.0          170.0
# 619                                H 3 S            {}   200.0          170.0
# 622                              La H 10            {}   200.0          170.0
# 708                                H 3 S            {}   203.0          150.0
# 943                                H 2 S            {}   203.0          155.0
# 944                                    S            {}   203.0          155.0
# 945                                H 3 S            {}   280.0          250.0
# 1097                               H 3 S            {}   280.0          250.0
# 1123                               H 2 S            {}   190.0          150.0
# 1421                            H 2 S 18            {}   204.0          170.0
# 1422                              Sc H 6            {}   196.0          170.0
# 1423                               Y H 6            {}   231.5          170.0
# 1424                             La H 10            {}   250.0          170.0
# 1425                               Y H 6            {}   231.0          170.0
# 1426                               Y H 6            {}   231.0          170.0
# 1569                               H 3 S            {}   203.0          155.0
# 1570                               H 3 S            {}   203.0          170.0
# 1657                           Ca Y H 12            {}   258.0          170.0
# 1658                             La H 10            {}   200.0          170.0
# 1660                               Y H 6            {}   220.0          170.0
# 1661                               H 3 S            {}   160.0          130.0
# 1662                              La H x     {'x': []}   215.0          170.0
# 1667                               H 3 S            {}   203.0          170.0
# 1670                             La H 10            {}   250.0          170.0
# 1671                               H 3 S            {}   200.0          170.0
# 1672                             La H 10            {}   250.0          170.0
# 1674                               H x S     {'x': []}   203.0          170.0
# 1677                             La H 10            {}   280.0          210.0
# 1679                             La H 10            {}   234.0          170.0
# 1680                               Y H 9            {}   240.0          170.0
# 1682                              La H x     {'x': []}   250.0          170.0
# 1683                             La H 10            {}   250.0          170.0
# 1685                             La H 10            {}   250.0          170.0
# 1686                               H 3 S            {}   203.0          170.0
# 1687                 S 0.925 P 0.075 H 3            {}   280.0          250.0
# 1831                                   S            {}   200.0          155.0
# 1832                               H 3 S            {}   200.0          170.0
# 2271                             La H 10            {}   250.0          218.0
# 2272                               H 3 S            {}   203.0          150.0
# 2273                               Y H 6            {}   203.0          237.0
# 2494                               H 3 S            {}   200.0          170.0
# 2730                             La H 10            {}   260.0          170.0
# 2732                             La H 10            {}   233.0          170.0
# 2765                               Y H 6            {}   240.0          165.0
# 2767                               S H 3            {}   200.0          200.0
# 2773             Hg Ba 2 Ca 2 Cu 3 O 8+δ     {'δ': []}   164.0           31.0
# 2806                               H 2 S            {}   190.0          170.0
# 2873                     H 3 S 0.9 P 0.1            {}   265.0          170.0
# 2874                    H 3 S 0.7 Te 0.3            {}   161.0          170.0
# 2875                              H 3 Se            {}   194.0          170.0
# 2876                 H 3 S 0.925 P 0.075            {}   280.0          250.0
# 2877                               H 3 S            {}   194.0          170.0
# 2878                               H 3 S            {}   194.0          170.0
# 2879                  H 3 S 0.96 Si 0.04            {}   274.0          170.0
# 2880                 H 3 S 0.925 P 0.075            {}   280.0          170.0
# 2881                     H 3 S 0.9 O 0.1            {}   198.0          170.0
# 2882                 H 3 S 0.925 P 0.075            {}   280.0          250.0
# 2883                     H 3 S 0.9 P 0.1            {}   250.0          170.0
# 3195                              Y H 10            {}   280.0          200.0
# 3196                               H 3 S            {}   203.0          170.0
# 3714                              Y H 10            {}   303.0          400.0
# 3715                               Y H 6            {}   264.0          120.0
# 3716                              Mg H 6            {}   271.0          300.0
# 3717                               H 2 S            {}   203.0          155.0
# 3718                              Ca H 6            {}   235.0          150.0
# 4019                               H 3 S            {}   200.0          200.0
# 4020                               H 2 S            {}   200.0          200.0
# 4067                             La H 10            {}   250.0          150.0
# 4068                             La H 10            {}   200.0          150.0
# 4069                             La H 10            {}   270.0          200.0
# 4153                               H 2 S            {}   203.0          200.0
# 4154                               H 2 S            {}   203.0          200.0
# 4164                               Y H 9            {}   256.0          177.0
# 4262                               H 3 S            {}   200.0          170.0
# 4453                          C S 3 H 13            {}   280.0          170.0
# 4454                                   S            {}   203.0          155.0
# 4455                             H 3 S 6            {}   203.0          150.0
# 4670                               H 3 S            {}   262.0          140.0
# 4671                               H 3 S            {}   200.0          150.0
# 4701                             La H 10            {}   250.0          170.0
# 4704                             La H 10            {}   250.0          170.0
# 4729                               H 3 S            {}   200.0          170.0
# 4730                               H 3 S            {}   190.0          170.0
# 4824                              Ca H 6            {}   235.0          170.0
# 4875                     La (O F) Bi S 2            {}   300.0            4.0
# 5079                               S H 3            {}   203.0          170.0
# 5194                               H 3 S            {}   203.0          150.0
# 5402                             Ce In 3            {}   230.0           2.43
# 5404                             Ce In 3            {}   230.0           2.43
# 5870                               H 3 S            {}   203.0          170.0
# 6008                               H 3 S            {}   190.0          170.0
# 6009                               H 2 S            {}   190.0          150.0
# 6014                             H 2 S 7            {}   190.0          170.0
# 6016                               H 2 S            {}   190.0          170.0
# 6034              Hg Ba 2 Ca 2 Cu 3 O 10            {}   166.0           25.0
# 6304                               H 3 S            {}   200.0          170.0
# 6305                               H 3 S            {}   203.0          250.0
# 6315                               H 3 S            {}   180.0          200.0
# 6342                               H 3 S            {}   203.0          150.0
# 6343                             La H 10            {}   215.0          150.0
# 6344                             La H 10            {}   215.0          150.0
# 6422                               H 2 S            {}   203.0          170.0
# 6683   (Nd 0.94 Ca 0.06) Ba 2 Cu 3 O 7-δ     {'δ': []}   523.0            8.0
# 6699                         K H 2 P O 4            {}   210.0          170.0
# 6751                               H 2 S            {}   203.0          155.0
# 6754                       Hg Ba Ca Cu O            {}   164.0          310.0
# 6772                               H 3 S            {}   151.0          170.0
# 6778                                   H            {}   240.0          450.0
# 6967                             La H 10            {}   260.0          200.0
# 7050               Hg Ba 2 Ca 2 Cu 3 O 9            {}   164.0           30.0
# 7246             Hg Ba 2 Ca 2 Cu 3 O 8+δ     {'δ': []}   164.0           31.0
# 7638                               H 2 S            {}   190.0          170.0
# 7639                               H 2 S            {}   190.0          190.0
# 7640                               H 2 S            {}   190.0          180.0
# 7643                               H 2 S            {}   205.0          170.0
# 7672             Hg Ba 2 Ca 2 Cu 3 O 8+y     {'y': []}   160.0           31.0
# 7940                               H 2 S            {}   190.0          170.0
# 7944                               H 3 S            {}   203.0          170.0
# 7945                             La H 10            {}   260.0          170.0
# 8011                               H 3 S            {}   203.0          155.0
# 8012                               H 3 S            {}   193.0          172.0
# 8014                               H 3 S            {}   200.0          200.0
# 8015                               H 2 S            {}   200.0          200.0
# 8380                               H 2 S            {}   190.0          170.0
# 8381                               H 2 S            {}   190.0          170.0
# 8383                               H 2 S            {}   190.0          170.0
# 8402                               H 3 S            {}   203.0          170.0
# 8859                               H 2 S            {}   203.0          150.0
# 9018                               H 3 S            {}   203.0          150.0
# 9313                             La H 10            {}   260.0          170.0
# 9816                               H 3 S            {}   203.0          170.0
# 9930             Hg Ba 2 Ca 2 Cu 3 O 8+δ     {'δ': []}   164.0           31.0
# 10040                              H 3 S            {}   203.0          170.0
# 10041                              H 3 S            {}   203.0          170.0
# 10258                              H 3 S            {}   200.0          200.0
# 10413                              H 3 S            {}   280.0          170.0
# 10450                              H 3 S            {}   203.0          170.0
# 10628                             Ca H 6            {}   240.0          150.0
# 10629                           Si 2 H 6            {}   174.0          275.0
# 10655         Tl 2 Ba 2 Ca 2 Cu 3 O 10+δ     {'δ': []}   250.0            4.0
# 10664                              H 3 S            {}   203.0          155.0
# 10702                            La H 10            {}   203.0          155.0
# 10925                                  S            {}   203.0          250.0
# 10931                              H 2 S            {}   190.0          170.0
# 11304                            La H 10            {}   233.0          170.0
# 11305                            La H 10            {}   233.0          170.0
# 11526                              H 3 S            {}   203.0          155.0
# 12389                              H 2 S            {}   203.0          155.0
# 12416                         Ce Rh In 5            {}   200.0           25.0
# 12418                         Ce Co In 5            {}   200.0           25.0
# 12865                            Ce In 3            {}   230.0           2.43
# 12915                              H 3 S            {}   203.0           90.0
# 12924                              Y H 9            {}   262.0          182.0
# 12926                                  S            {}   287.0          267.0
# 12932                                  S            {}   287.0          267.0
# 12953                             La H 3            {}   250.0          170.0
# 12954                              H 3 S            {}   200.0          150.0
# 13160                              H 3 S            {}   203.0          170.0
# 13245                              S H 3            {}   203.0          200.0
# 13444                              H 3 S            {}   170.0          170.0
# 13445                                  S            {}   203.0          200.0
# 13757                              H 3 S            {}   203.0          155.0
# 13758                             Ca H 6            {}   215.0          172.0
# 13759                             Ca H 6            {}   215.0          172.0
# 13760                             Ca H 6            {}   215.0          172.0
# 13780                              H 3 S            {}   203.0          200.0
# 14121                            La H 10            {}   250.0          170.0
# 14123                            La H 10            {}   220.0          210.0
# 14124                              S H 3            {}   203.0          170.0
# 14260                              H 3 S            {}   181.0          170.0
# 14262                              H 3 S            {}   181.0          250.0
# 14265                              H 3 S            {}   181.0          170.0
# 14268                              H 2 S            {}   200.0          200.0
# 14301                              H 3 S            {}   178.0          170.0
# 14310           Bi 2 Sr 2 Ca 2 Cu 3 O 10            {}   164.0          200.0
# 14311                    Y Ba 2 Cu 3 O 7            {}   164.0          200.0
# 14312                              H 3 S            {}   200.0          200.0
# 14315              Hg Ba 2 Ca 2 Cu 3 O 7            {}   164.0          200.0
# 14351             Hg Ba 2 Ca 2 Cu 3 O 10            {}   164.0           30.0
# 14493                              H 2 S            {}   203.0          155.0
# 14495                              H 3 S            {}   200.0          170.0
# 14689                              Y H 6            {}   224.0          166.0
# 14691                            H 5 S 2            {}   200.0          170.0
# 14692                              H 3 S            {}   203.0          170.0
# 14694                            La H 10            {}   260.0          190.0
# 14695                             Sc H 9            {}   233.0          300.0
# 14697                            La H 10            {}   260.0          190.0
# 14912             (Li 1-x Fe x O H) Fe S     {'x': []}   250.0          170.0
# 15145                              Y H 9            {}   262.0          182.0
# 15148                              Y H 9            {}   262.0          182.0
# 15150                              H 3 S            {}   203.0          155.0
# 15175           (N H 3) 0.9 Na Rb 2 C 60            {}   250.0          170.0
# 15532                              H 2 S            {}   203.0           90.0
# 15599                             Si H 4            {}   166.0          202.0
# 15636                              H 3 S            {}   203.0          160.0
# 15719                          La B H 17            {}   223.0          170.0
# 15722                          La B H 17            {}   180.0          170.0
# 15747                              H 3 S            {}   203.0          170.0
# 16036                          La Be H 8            {}   191.0           50.0
# 16037                          Ca Be H 8            {}   300.0          210.0
# 16038                          La Be H 8            {}   191.0           50.0
# 16090                              S H 3            {}   203.0          170.0
# 16091                            La H 10            {}   265.0          170.0
# 16096                            La H 10            {}   260.0          150.0
# 16358                          H 2 H 2 S            {}   190.0           20.0
# 16443                                  H            {}   242.0          450.0
# 16445                H 3 S 0.925 P 0.075            {}   280.0          250.0
# 16456                              H 2 S            {}   200.0          170.0
# 16457                              H 2 S            {}   200.0          170.0
# 16537                              Y H 9            {}   243.0          201.0
# 16540                              H 3 S            {}   203.0          155.0
# 16542                            Th H 10            {}   161.0          175.0
# 16954                              H 3 S            {}   203.0          200.0
# 16971                            La H 10            {}   200.0          170.0
# 16972                              H 2 S            {}   203.0          150.0
# 17072                              H 3 S            {}   203.0          170.0
# 17073                              H 3 S            {}   200.0          170.0
# 17074                              H 3 S            {}   165.0          170.0
# 17145                            La H 10            {}   200.0          250.0
# 17146                            La H 10            {}   230.0          170.0
# 17346                              Y H 4            {}   235.0          170.0
# 17347                             Ca H 6            {}   205.0          150.0
# 17348                            Sr H 10            {}   259.0          170.0
# 17349                              Y H 6            {}   200.0          170.0
# 17398                              H 3 S            {}   200.0          170.0
# 17403                              H 2 S            {}   203.0          170.0
# 17556                              H 3 S            {}   203.0          155.0
# 17654                              H 3 S            {}   200.0          170.0
# 17656                              H 3 S            {}   166.0          170.0
# 17657                              H 3 S            {}   166.0          170.0
# 17658                              H 3 S            {}   166.0          170.0
# 17849              Hg Ba 2 Ca 2 Cu 3 O y     {'y': []}   164.0           31.0
# 17922                              Hg 12            {}   164.0           45.0
# 17951              Hg Ba 2 Ca 2 Cu 3 O 9            {}   164.0           30.0
# 18086                              H 2 S            {}   190.0          170.0
# 18087                              H 2 S            {}   190.0          170.0
# 18088                              H 2 S            {}   190.0          150.0
# 18089                              H 2 S            {}   190.0          170.0
# 18104                              H 2 S            {}   190.0          170.0
# 18145                            La H 10            {}   215.0          170.0
# 18146                             Ca H 6            {}   235.0          150.0
# 18147                             Ca H 6            {}   200.0          170.0
# 18148                              H 3 S            {}   203.0          155.0
# 18149                             Ca H 6            {}   215.0          170.0
# 18150                             Ca H 6            {}   215.0          172.0
# 18170                              H 3 S            {}   200.0          200.0
# 18723                              H 3 S            {}   250.0          170.0
# 18724                              H 3 S            {}   203.0          162.0
# 18725                              H 3 S            {}   203.0          162.0
# 18962                              H 3 S            {}   203.0          170.0
# 19005                              H 3 S            {}   203.0          155.0
# 19026                              H 2 S            {}   203.0          170.0
# 19027                              H 2 S            {}   203.0          170.0
# 19030                              H 2 S            {}   203.0          155.0
# 19203                              H 2 S            {}   203.0          150.0
# 19457                             Ca H 6            {}   235.0          150.0
# 19459                             Mg H 6            {}   260.0          300.0
# 19521                              H 3 S            {}   200.0          170.0
# 19522                              H 3 S            {}   200.0          170.0
# 19798            Hg Ba 2 Ca 2 Cu 3 O 8+y     {'y': []}   164.0           31.0
# 20019                              Y H 9            {}   180.0          170.0
# 20021                            La H 10            {}   218.0          170.0
# 20125                              H 3 S            {}   200.0          170.0
# 20188                              H 3 S            {}   203.0          170.0
# 20190                              H 3 S            {}   203.0          170.0
# 20191                              H 3 S            {}   203.0          170.0
# 20266                       Li 2 Mg H 16            {}   473.0          250.0
# 20267                            La H 10            {}   260.0          180.0
# 20268                            La H 10            {}   260.0          170.0
# 20371             La 0.67 Ca 0.33 Mn O 3            {}   254.0           20.0
# 20480                            Ce In 3            {}   230.0           2.43
# 20481                            Ce In 3            {}   200.0            2.5
# 20915                  K 0.8 Fe 1.7 Se 2            {}   200.0           11.0
# 20969              Hg Ba 2 Ca 2 Cu 3 O 8            {}   164.0           30.0
# 20986                              H 2 S            {}   200.0          170.0
# 21181                              S H 3            {}   200.0           30.0
# 21396                             Ca H 6            {}   235.0          150.0
# 21400                              S H 3            {}   200.0          170.0
# 21401                              Y H 6            {}   200.0          100.0
# 21402                              S H 3            {}   203.0          200.0
# 21404                            La H 10            {}   260.0          170.0
# 21461                              H 3 S            {}   203.0          155.0
# 21462                            La H 10            {}   170.0          350.0
# 21463                              H 3 S            {}   203.0          155.0
# 21464                            La H 10            {}   249.0          150.0
# 21471                              H 3 S            {}   200.0          170.0
# 21472                              H 3 S            {}   200.0          155.0
# 21473                              H 3 S            {}   203.0          155.0
# 21474                              H 2 S            {}   203.0          155.0
# 21505                              H 3 S            {}   200.0          200.0
# 21881                              H 2 S            {}   200.0           90.0
# 22048                                H 2            {}   200.0          200.0
# 22050                              S H 3            {}   203.0          170.0
# 22186                              H 3 S            {}   203.0          155.0
# 22267                              H 2 S            {}   190.0          200.0
# 22268                              H 2 S            {}   190.0          170.0
# 22566                             Ca H 6            {}   235.0          150.0
# 22568                      Hg Ba Ca Cu O            {}  1000.0          100.0
# 22570                            La H 10            {}   253.0          170.0
# 22571                            La H 10            {}   200.0          170.0
# 22572                           La Y H x     {'x': []}   253.0          170.0
# 22611              Hg Ba 2 Ca 2 Cu 3 O 8            {}   164.0           30.0
# 22956                              H 3 S            {}   203.0          170.0
# 22985                           H 3 S 32            {}   265.0          300.0
# 22988                             Y H 10            {}   200.0          170.0
# 23013                              H 3 S            {}   203.0          170.0
# 23014                        H 24 S 7 Na            {}   191.0          150.0
# 23022                             Mg B 2            {}   203.0          150.0
# 23135                            La H 10            {}   265.0          170.0
# 23198                      Na 0.04 N H 3            {}   200.0          170.0
# 23204                  Y Ba 2 Cu 3 O 7-δ     {'δ': []}   164.0           30.0
# 23338                            La H 10            {}   250.0          237.0
# 23339                            La H 10            {}   203.0          155.0
# 23340                              Y H 6            {}   250.0          237.0
# 23362            Hg Ba 2 Ca 2 Cu 3 O 8+δ     {'δ': []}   164.0           30.0
# 23814                              H 3 S            {}   203.0          150.0
# 23815                       Li 2 Mg H 16            {}   473.0          250.0
#
#                                                  Classes Shape Substrate  \
# 14                                ['Hydrides', 'Alloys']
# 16                         ['Hydrides', 'Chalcogenides']
# 218                                                   []
# 392                               ['Hydrides', 'Alloys']
# 410                                           ['Alloys']
# 518                               ['Hydrides', 'Alloys']
# 519                               ['Hydrides', 'Alloys']
# 520                               ['Hydrides', 'Alloys']
# 522                               ['Hydrides', 'Alloys']
# 540                        ['Hydrides', 'Chalcogenides']
# 618                               ['Hydrides', 'Alloys']
# 619                        ['Hydrides', 'Chalcogenides']
# 622                               ['Hydrides', 'Alloys']
# 708                        ['Hydrides', 'Chalcogenides']
# 943                        ['Hydrides', 'Chalcogenides']
# 944                                                   []
# 945                        ['Hydrides', 'Chalcogenides']
# 1097                       ['Hydrides', 'Chalcogenides']
# 1123                       ['Hydrides', 'Chalcogenides']
# 1421                       ['Hydrides', 'Chalcogenides']
# 1422                              ['Hydrides', 'Alloys']
# 1423                              ['Hydrides', 'Alloys']
# 1424                              ['Hydrides', 'Alloys']
# 1425                              ['Hydrides', 'Alloys']
# 1426                              ['Hydrides', 'Alloys']
# 1569                       ['Hydrides', 'Chalcogenides']
# 1570                       ['Hydrides', 'Chalcogenides']
# 1657                              ['Hydrides', 'Alloys']
# 1658                              ['Hydrides', 'Alloys']
# 1660                              ['Hydrides', 'Alloys']
# 1661                       ['Hydrides', 'Chalcogenides']
# 1662                              ['Hydrides', 'Alloys']
# 1667                       ['Hydrides', 'Chalcogenides']
# 1670                              ['Hydrides', 'Alloys']
# 1671                       ['Hydrides', 'Chalcogenides']
# 1672                              ['Hydrides', 'Alloys']
# 1674                       ['Hydrides', 'Chalcogenides']
# 1677                              ['Hydrides', 'Alloys']
# 1679                              ['Hydrides', 'Alloys']
# 1680                              ['Hydrides', 'Alloys']
# 1682                              ['Hydrides', 'Alloys']
# 1683                              ['Hydrides', 'Alloys']
# 1685                              ['Hydrides', 'Alloys']
# 1686                       ['Hydrides', 'Chalcogenides']
# 1687          ['Hydrides', 'Chalcogenides', 'Pnictides']
# 1831                                                  []
# 1832                       ['Hydrides', 'Chalcogenides']
# 2271                              ['Hydrides', 'Alloys']
# 2272                       ['Hydrides', 'Chalcogenides']
# 2273                              ['Hydrides', 'Alloys']
# 2494                       ['Hydrides', 'Chalcogenides']
# 2730                              ['Hydrides', 'Alloys']
# 2732                              ['Hydrides', 'Alloys']
# 2765                              ['Hydrides', 'Alloys']
# 2767                       ['Hydrides', 'Chalcogenides']
# 2773                                          ['Alloys']
# 2806                       ['Hydrides', 'Chalcogenides']
# 2873          ['Hydrides', 'Chalcogenides', 'Pnictides']
# 2874                       ['Hydrides', 'Chalcogenides']
# 2875                       ['Hydrides', 'Chalcogenides']
# 2876          ['Hydrides', 'Chalcogenides', 'Pnictides']
# 2877                       ['Hydrides', 'Chalcogenides']
# 2878                       ['Hydrides', 'Chalcogenides']
# 2879                       ['Hydrides', 'Chalcogenides']
# 2880          ['Hydrides', 'Chalcogenides', 'Pnictides']
# 2881             ['Hydrides', 'Chalcogenides', 'Oxides']
# 2882          ['Hydrides', 'Chalcogenides', 'Pnictides']
# 2883          ['Hydrides', 'Chalcogenides', 'Pnictides']
# 3195                              ['Hydrides', 'Alloys']
# 3196                       ['Hydrides', 'Chalcogenides']
# 3714                              ['Hydrides', 'Alloys']
# 3715                              ['Hydrides', 'Alloys']
# 3716                              ['Hydrides', 'Alloys']
# 3717                       ['Hydrides', 'Chalcogenides']
# 3718                              ['Hydrides', 'Alloys']
# 4019                       ['Hydrides', 'Chalcogenides']
# 4020                                                  []
# 4067                              ['Hydrides', 'Alloys']
# 4068                              ['Hydrides', 'Alloys']
# 4069                              ['Hydrides', 'Alloys']
# 4153                       ['Hydrides', 'Chalcogenides']
# 4154                       ['Hydrides', 'Chalcogenides']
# 4164                              ['Hydrides', 'Alloys']
# 4262                       ['Hydrides', 'Chalcogenides']
# 4453           ['Hydrides', 'Carbides', 'Chalcogenides']
# 4454                                                  []
# 4455                       ['Hydrides', 'Chalcogenides']
# 4670                       ['Hydrides', 'Chalcogenides']
# 4671                       ['Hydrides', 'Chalcogenides']
# 4701                              ['Hydrides', 'Alloys']
# 4704                              ['Hydrides', 'Alloys']
# 4729                       ['Hydrides', 'Chalcogenides']
# 4730                       ['Hydrides', 'Chalcogenides']
# 4824                              ['Hydrides', 'Alloys']
# 4875                                          ['Alloys']
# 5079                       ['Hydrides', 'Chalcogenides']
# 5194                       ['Hydrides', 'Chalcogenides']
# 5402                                          ['Alloys']
# 5404                                          ['Alloys']
# 5870                       ['Hydrides', 'Chalcogenides']
# 6008                       ['Hydrides', 'Chalcogenides']
# 6009                       ['Hydrides', 'Chalcogenides']
# 6014                       ['Hydrides', 'Chalcogenides']
# 6016                       ['Hydrides', 'Chalcogenides']
# 6034                                          ['Alloys']
# 6304                       ['Hydrides', 'Chalcogenides']
# 6305                       ['Hydrides', 'Chalcogenides']
# 6315                       ['Hydrides', 'Chalcogenides']
# 6342                       ['Hydrides', 'Chalcogenides']
# 6343                              ['Hydrides', 'Alloys']
# 6344                              ['Hydrides', 'Alloys']
# 6422                       ['Hydrides', 'Chalcogenides']
# 6683                              ['Oxides', 'Cuprates']
# 6699                 ['Hydrides', 'Oxides', 'Pnictides']
# 6751                       ['Hydrides', 'Chalcogenides']
# 6754                                                  []
# 6772                       ['Hydrides', 'Chalcogenides']
# 6778                                                  []
# 6967                              ['Hydrides', 'Alloys']
# 7050                              ['Oxides', 'Cuprates']
# 7246                                          ['Alloys']
# 7638                       ['Hydrides', 'Chalcogenides']
# 7639                       ['Hydrides', 'Chalcogenides']
# 7640                       ['Hydrides', 'Chalcogenides']
# 7643                       ['Hydrides', 'Chalcogenides']
# 7672                                          ['Alloys']
# 7940                       ['Hydrides', 'Chalcogenides']
# 7944                       ['Hydrides', 'Chalcogenides']
# 7945                              ['Hydrides', 'Alloys']
# 8011                       ['Hydrides', 'Chalcogenides']
# 8012                       ['Hydrides', 'Chalcogenides']
# 8014                       ['Hydrides', 'Chalcogenides']
# 8015                                                  []
# 8380                       ['Hydrides', 'Chalcogenides']
# 8381                       ['Hydrides', 'Chalcogenides']
# 8383                       ['Hydrides', 'Chalcogenides']
# 8402                       ['Hydrides', 'Chalcogenides']
# 8859                                                  []
# 9018                       ['Hydrides', 'Chalcogenides']
# 9313                              ['Hydrides', 'Alloys']
# 9816                       ['Hydrides', 'Chalcogenides']
# 9930                                          ['Alloys']
# 10040                      ['Hydrides', 'Chalcogenides']
# 10041                      ['Hydrides', 'Chalcogenides']
# 10258                      ['Hydrides', 'Chalcogenides']
# 10413                      ['Hydrides', 'Chalcogenides']
# 10450                      ['Hydrides', 'Chalcogenides']
# 10628                             ['Hydrides', 'Alloys']
# 10629                             ['Hydrides', 'Alloys']
# 10655                                         ['Alloys']
# 10664                      ['Hydrides', 'Chalcogenides']
# 10702                             ['Hydrides', 'Alloys']
# 10925                                                 []
# 10931                      ['Hydrides', 'Chalcogenides']
# 11304                             ['Hydrides', 'Alloys']
# 11305                             ['Hydrides', 'Alloys']
# 11526                      ['Hydrides', 'Chalcogenides']
# 12389                                                 []
# 12416                                         ['Alloys']
# 12418                                         ['Alloys']
# 12865                                         ['Alloys']
# 12915                      ['Hydrides', 'Chalcogenides']
# 12924                             ['Hydrides', 'Alloys']
# 12926                                                 []
# 12932                                                 []
# 12953                                                 []
# 12954                                                 []
# 13160                      ['Hydrides', 'Chalcogenides']
# 13245                      ['Hydrides', 'Chalcogenides']
# 13444                      ['Hydrides', 'Chalcogenides']
# 13445                                                 []
# 13757                      ['Hydrides', 'Chalcogenides']
# 13758                             ['Hydrides', 'Alloys']
# 13759                             ['Hydrides', 'Alloys']
# 13760                             ['Hydrides', 'Alloys']
# 13780                                                 []
# 14121                             ['Hydrides', 'Alloys']
# 14123                             ['Hydrides', 'Alloys']
# 14124                      ['Hydrides', 'Chalcogenides']
# 14260                      ['Hydrides', 'Chalcogenides']
# 14262                      ['Hydrides', 'Chalcogenides']
# 14265                      ['Hydrides', 'Chalcogenides']
# 14268                      ['Hydrides', 'Chalcogenides']
# 14301                      ['Hydrides', 'Chalcogenides']
# 14310                                                 []
# 14311                                                 []
# 14312                      ['Hydrides', 'Chalcogenides']
# 14315                             ['Oxides', 'Cuprates']
# 14351                                                 []
# 14493                      ['Hydrides', 'Chalcogenides']
# 14495                      ['Hydrides', 'Chalcogenides']
# 14689                             ['Hydrides', 'Alloys']
# 14691                      ['Hydrides', 'Chalcogenides']
# 14692                      ['Hydrides', 'Chalcogenides']
# 14694                             ['Hydrides', 'Alloys']
# 14695                             ['Hydrides', 'Alloys']
# 14697                             ['Hydrides', 'Alloys']
# 14912  ['Hydrides', 'Iron-chalcogenides', 'Chalcogeni...
# 15145                             ['Hydrides', 'Alloys']
# 15148                             ['Hydrides', 'Alloys']
# 15150                      ['Hydrides', 'Chalcogenides']
# 15175               ['Hydrides', 'Nitrides', 'Carbides']
# 15532                      ['Hydrides', 'Chalcogenides']
# 15599                             ['Hydrides', 'Alloys']
# 15636                      ['Hydrides', 'Chalcogenides']
# 15719                  ['Hydrides', 'Alloys', 'Borides']
# 15722                  ['Hydrides', 'Alloys', 'Borides']
# 15747                      ['Hydrides', 'Chalcogenides']
# 16036                             ['Hydrides', 'Alloys']
# 16037                             ['Hydrides', 'Alloys']
# 16038                             ['Hydrides', 'Alloys']
# 16090                      ['Hydrides', 'Chalcogenides']
# 16091                             ['Hydrides', 'Alloys']
# 16096                             ['Hydrides', 'Alloys']
# 16358                                         ['Alloys']
# 16443                                                 []
# 16445         ['Hydrides', 'Chalcogenides', 'Pnictides']
# 16456                      ['Hydrides', 'Chalcogenides']
# 16457                      ['Hydrides', 'Chalcogenides']
# 16537                             ['Hydrides', 'Alloys']
# 16540                      ['Hydrides', 'Chalcogenides']
# 16542                             ['Hydrides', 'Alloys']
# 16954                      ['Hydrides', 'Chalcogenides']
# 16971                             ['Hydrides', 'Alloys']
# 16972                      ['Hydrides', 'Chalcogenides']
# 17072                      ['Hydrides', 'Chalcogenides']
# 17073                      ['Hydrides', 'Chalcogenides']
# 17074                      ['Hydrides', 'Chalcogenides']
# 17145                             ['Hydrides', 'Alloys']
# 17146                             ['Hydrides', 'Alloys']
# 17346                             ['Hydrides', 'Alloys']
# 17347                             ['Hydrides', 'Alloys']
# 17348                             ['Hydrides', 'Alloys']
# 17349                             ['Hydrides', 'Alloys']
# 17398                      ['Hydrides', 'Chalcogenides']
# 17403                      ['Hydrides', 'Chalcogenides']
# 17556                      ['Hydrides', 'Chalcogenides']
# 17654                      ['Hydrides', 'Chalcogenides']
# 17656                      ['Hydrides', 'Chalcogenides']
# 17657                      ['Hydrides', 'Chalcogenides']
# 17658                      ['Hydrides', 'Chalcogenides']
# 17849                             ['Oxides', 'Cuprates']
# 17922                                         ['Alloys']
# 17951                             ['Oxides', 'Cuprates']
# 18086                      ['Hydrides', 'Chalcogenides']
# 18087                      ['Hydrides', 'Chalcogenides']
# 18088                      ['Hydrides', 'Chalcogenides']
# 18089                      ['Hydrides', 'Chalcogenides']
# 18104                      ['Hydrides', 'Chalcogenides']
# 18145                             ['Hydrides', 'Alloys']
# 18146                             ['Hydrides', 'Alloys']
# 18147                             ['Hydrides', 'Alloys']
# 18148                                                 []
# 18149                             ['Hydrides', 'Alloys']
# 18150                             ['Hydrides', 'Alloys']
# 18170                      ['Hydrides', 'Chalcogenides']
# 18723                      ['Hydrides', 'Chalcogenides']
# 18724                      ['Hydrides', 'Chalcogenides']
# 18725                                                 []
# 18962                      ['Hydrides', 'Chalcogenides']
# 19005                      ['Hydrides', 'Chalcogenides']
# 19026                      ['Hydrides', 'Chalcogenides']
# 19027                      ['Hydrides', 'Chalcogenides']
# 19030                      ['Hydrides', 'Chalcogenides']
# 19203                                                 []
# 19457                             ['Hydrides', 'Alloys']
# 19459                             ['Hydrides', 'Alloys']
# 19521                      ['Hydrides', 'Chalcogenides']
# 19522                      ['Hydrides', 'Chalcogenides']
# 19798                                         ['Alloys']
# 20019                             ['Hydrides', 'Alloys']
# 20021                             ['Hydrides', 'Alloys']
# 20125                      ['Hydrides', 'Chalcogenides']
# 20188                      ['Hydrides', 'Chalcogenides']
# 20190                      ['Hydrides', 'Chalcogenides']
# 20191                      ['Hydrides', 'Chalcogenides']
# 20266                             ['Hydrides', 'Alloys']
# 20267                             ['Hydrides', 'Alloys']
# 20268                             ['Hydrides', 'Alloys']
# 20371                                         ['Oxides']
# ...
# 520                  10.1103/physrevb.99.220502
# 522                  10.1103/physrevb.99.220502
# 540                      10.1002/andp.201700197
# 618                                         nan
# 619                                         nan
# 622                                         nan
# 708                      10.1002/andp.201800139
# 943                      10.7566/jpsj.87.124711
# 944                      10.7566/jpsj.87.124711
# 945                      10.7566/jpsj.87.124711
# 1097                     10.7567/apex.11.053101
# 1123                         10.1039/c6cp08036g
# 1421                    10.1007/1-4020-3989-1_6
# 1422                    10.1007/1-4020-3989-1_6
# 1423                    10.1007/1-4020-3989-1_6
# 1424                    10.1007/1-4020-3989-1_6
# 1425                    10.1007/1-4020-3989-1_6
# 1426                    10.1007/1-4020-3989-1_6
# 1569               10.1080/01411594.2012.658051
# 1570               10.1080/01411594.2012.658051
# 1657              10.1016/j.physrep.2020.02.003
# 1658              10.1016/j.physrep.2020.02.003
# 1660              10.1016/j.physrep.2020.02.003
# 1661              10.1016/j.physrep.2020.02.003
# 1662              10.1016/j.physrep.2020.02.003
# 1667              10.1016/j.physrep.2020.02.003
# 1670              10.1016/j.physrep.2020.02.003
# 1671              10.1016/j.physrep.2020.02.003
# 1672              10.1016/j.physrep.2020.02.003
# 1674              10.1016/j.physrep.2020.02.003
# 1677              10.1016/j.physrep.2020.02.003
# 1679              10.1016/j.physrep.2020.02.003
# 1680              10.1016/j.physrep.2020.02.003
# 1682              10.1016/j.physrep.2020.02.003
# 1683              10.1016/j.physrep.2020.02.003
# 1685              10.1016/j.physrep.2020.02.003
# 1686              10.1016/j.physrep.2020.02.003
# 1687              10.1016/j.physrep.2020.02.003
# 1831                   10.1088/1361-6668/aa5f3c
# 1832                   10.1088/1361-6668/aa5f3c
# 2271                                        nan
# 2272                                        nan
# 2273                                        nan
# 2494               10.1007/978-94-007-2384-9_22
# 2730                     10.7566/jpsj.84.104706
# 2732                     10.7566/jpsj.84.104706
# 2765                           10.1063/1.439573
# 2767                           10.1063/1.439573
# 2773                 10.1016/j.jpcs.2012.12.024
# 2806                10.1209/0295-5075/108/47007
# 2873                                        nan
# 2874                                        nan
# 2875                                        nan
# 2876                                        nan
# 2877                                        nan
# 2878                                        nan
# 2879                                        nan
# 2880                                        nan
# 2881                                        nan
# 2882                                        nan
# 2883                                        nan
# 3195                  10.1038/s41586-019-1201-8
# 3196                  10.1038/s41586-019-1201-8
# 3714                                        nan
# 3715                                        nan
# 3716                                        nan
# 3717                                        nan
# 3718                                        nan
# 4019                          10.1063/pt.3.4204
# 4020                          10.1063/pt.3.4204
# 4067                  10.1051/jphyscol:19888969
# 4068                  10.1051/jphyscol:19888969
# 4069                  10.1051/jphyscol:19888969
# 4153                 10.1142/9789814733632_0003
# 4154                 10.1142/9789814733632_0003
# 4164                                        nan
# 4262                          10.1038/nphys4156
# 4453                                        nan
# 4454                                        nan
# 4455                                        nan
# 4670                10.1103/physrevb.100.174513
# 4671                10.1103/physrevb.100.174513
# 4701                  10.1016/j.ssc.2019.113769
# 4704                  10.1016/j.ssc.2019.113769
# 4729                     10.1002/chem.201705321
# 4730                     10.1002/chem.201705321
# 4824                10.1016/j.physc.2015.03.002
# 4875                  10.1107/s1600536807009634
# 5079                                        nan
# 5194                10.1103/physrevb.100.184503
# 5402                       10.1143/jpsj.73.1647
# 5404                       10.1143/jpsj.73.1647
# 5870                 10.1103/physrevb.97.214510
# 6008                        10.1038/nature14964
# 6009                        10.1038/nature14964
# 6014                        10.1038/nature14964
# 6016                        10.1038/nature14964
# 6034                                        nan
# 6304                 10.1007/s10948-019-05277-4
# 6305                 10.1007/s10948-019-05277-4
# 6315                 10.1140/epjb/e2016-70020-0
# 6342                 10.1038/s41598-020-58065-9
# 6343                 10.1038/s41598-020-58065-9
# 6344                 10.1038/s41598-020-58065-9
# 6422                 10.1103/physrevb.91.094501
# 6683                                        nan
# 6699                                        nan
# 6751                                        nan
# 6754                                        nan
# 6772                 10.1103/physrevb.92.060508
# 6778                     10.1002/pssb.201349087
# 6967                                        nan
# 7050                10.1016/j.physc.2015.02.027
# 7246                        10.1155/2015/969564
# 7638                                        nan
# 7639                                        nan
# 7640                                        nan
# 7643                                        nan
# 7672                  10.1007/s10948-016-3489-z
# 7940                 10.1103/physrevb.91.224513
# 7944                     10.3390/condmat4020043
# 7945                     10.3390/condmat4020043
# 8011                 10.1016/j.jpcs.2018.08.020
# 8012                 10.1016/j.jpcs.2018.08.020
# 8014                 10.1103/physrevb.93.104526
# 8015                 10.1103/physrevb.93.104526
# 8380                 10.1103/physrevb.91.060511
# 8381                 10.1103/physrevb.91.060511
# 8383                 10.1103/physrevb.91.060511
# 8402             10.1103/physrevlett.123.077001
# 8859                          10.1063/1.4959154
# 9018                10.1103/physrevb.100.060502
# 9313                     10.20948/prepr-2019-52
# 9816                 10.1103/physrevb.94.134509
# 9930                 10.1103/physrevb.97.174508
# 10040                      10.1155/2019/6795250
# 10041                      10.1155/2019/6795250
# 10258                10.1103/physrevb.91.220507
# 10413                                       nan
# 10450                                       nan
# 10628               10.1016/j.physc.2012.12.002
# 10629               10.1016/j.physc.2012.12.002
# 10655              10.1007/978-94-010-0520-3_26
# 10664                 10.1016/j.ssc.2018.05.009
# 10702                                       nan
# 10925            10.1088/0031-8949/85/03/035704
# 10931             10.1088/0953-2048/28/8/085018
# 11304               10.1103/physrevb.101.104506
# 11305               10.1103/physrevb.101.104506
# 11526                 10.1038/s41535-018-0133-0
# 12389                 10.1103/physrevx.8.031067
# 12416                                       nan
# 12418                                       nan
# 12865            10.1088/0953-8984/19/12/125202
# 12915                                       nan
# 12924                                       nan
# 12926                                       nan
# 12932                                       nan
# 12953                         10.1063/1.4959154
# 12954                         10.1063/1.4959154
# 13160               10.1209/0295-5075/118/37003
# 13245         10.1103/physrevmaterials.1.074803
# 13444                10.1103/physrevb.94.060502
# 13445                10.1103/physrevb.94.060502
# 13757                                       nan
# 13758                                       nan
# 13759                                       nan
# 13760                                       nan
# 13780                10.1103/physrevb.95.134506
# 14121               10.1103/physrevb.100.094505
# 14123               10.1103/physrevb.100.094505
# 14124               10.1103/physrevb.100.094505
# 14260                10.1103/physrevb.93.094525
# 14262                10.1103/physrevb.93.094525
# 14265                10.1103/physrevb.93.094525
# 14268                10.1103/physrevb.93.094525
# 14301                         10.1038/srep38570
# 14310               10.1007/978-3-319-52675-1_2
# 14311               10.1007/978-3-319-52675-1_2
# 14312               10.1007/978-3-319-52675-1_2
# 14315               10.1007/978-3-319-52675-1_2
# 14351             10.1016/s0921-4534(97)01035-6
# 14493                    10.1002/andp.201600390
# 14495                    10.1002/andp.201600390
# 14689                                       nan
# 14691                                       nan
# 14692                                       nan
# 14694                                       nan
# 14695                                       nan
# 14697                                       nan
# 14912                        10.1039/c6sc05268a
# 15145                                       nan
# 15148                                       nan
# 15150                                       nan
# 15175             10.1103/physrevlett.88.096401
# 15532                 10.1007/s11433-019-9452-y
# 15599                                       nan
# 15636               10.1103/physrevb.100.094521
# 15719                                       nan
# 15722                                       nan
# 15747                         10.1038/srep24816
# 16036                        10.1039/c2cp42734f
# 16037                        10.1039/c2cp42734f
# 16038                        10.1039/c2cp42734f
# 16090                  10.1088/1361-648x/ab0db2
# 16091                  10.1088/1361-648x/ab0db2
# 16096                  10.1088/1361-648x/ab0db2
# 16358               10.1016/j.physc.2015.03.003
# 16443                10.1103/physrevb.96.064517
# 16445                10.1103/physrevb.96.064517
# 16456                    10.1002/chin.201621003
# 16457                    10.1002/chin.201621003
# 16537                10.1103/physrevb.99.024508
# 16540                10.1103/physrevb.99.024508
# 16542                10.1103/physrevb.99.024508
# 16954                10.1038/s41598-017-07145-4
# 16971                                       nan
# 16972                                       nan
# 17072                                       nan
# 17073               10.1103/physrevlett.72.1132
# 17074               10.1103/physrevlett.72.1132
# 17145                                       nan
# 17146                                       nan
# 17346                10.1103/physrevb.96.100502
# 17347                10.1103/physrevb.96.100502
# 17348                10.1103/physrevb.96.100502
# 17349                10.1103/physrevb.96.100502
# 17398                 10.1016/j.ssc.2016.05.019
# 17403                10.1103/physrevb.93.184510
# 17556            10.1103/physrevlett.121.047002
# 17654                                       nan
# 17656                                       nan
# 17657                                       nan
# 17658                                       nan
# 17849                                       nan
# 17922               10.1016/j.physc.2015.02.047
# 17951               10.1016/j.physc.2015.02.047
# 18086                10.1103/physrevb.91.180502
# 18087                10.1103/physrevb.91.180502
# 18088                10.1103/physrevb.91.180502
# 18089                10.1103/physrevb.91.180502
# 18104              10.1016/0038-1098(89)90009-4
# 18145                                       nan
# 18146                                       nan
# 18147                                       nan
# 18148                                       nan
# 18149                                       nan
# 18150                                       nan
# 18170                     10.1515/nsm-2017-0005
# 18723               10.1209/0295-5075/118/37003
# 18724               10.1209/0295-5075/118/37003
# 18725               10.1209/0295-5075/118/37003
# 18962                                       nan
# 19005                   10.1126/science.aaw4278
# 19026                10.1103/physrevb.93.020103
# 19027                10.1103/physrevb.93.020103
# 19030                10.1103/physrevb.93.020103
# 19203                         10.1063/1.4808207
# 19457                                       nan
# 19459                                       nan
# 19521                 10.1142/s0217979217450035
# 19522                 10.1142/s0217979217450035
# 19798                 10.1016/j.ssc.2013.04.015
# 20019                                       nan
# 20021                                       nan
# 20125                         10.1038/srep22873
# 20188                    10.1002/andp.201500316
# 20190                    10.1002/andp.201500316
# 20191                    10.1002/andp.201500316
# 20266                                       nan
# 20267                                       nan
# 20268                                       nan
# 20371                                       nan
# 20480                10.1103/physrevb.77.064508
# 20481                10.1103/physrevb.77.064508
# 20915                 10.1016/j.ssc.2011.03.014
# 20969             10.1016/s0304-8853(97)00999-2
# 20986                     10.1515/znb-2019-0103
# 21181                10.1103/physrevb.98.140504
# 21396             10.1021/acs.inorgchem.8b03165
# 21400             10.1021/acs.inorgchem.8b03165
# 21401             10.1021/acs.inorgchem.8b03165
# 21402             10.1021/acs.inorgchem.8b03165
# 21404             10.1021/acs.inorgchem.8b03165
# 21461                 10.1142/s0217984914500523
# 21462                 10.1142/s0217984914500523
# 21463                 10.1142/s0217984914500523
# 21464                 10.1142/s0217984914500523
# 21471                  10.1088/1361-648x/aa80d0
# 21472                  10.1088/1361-648x/aa80d0
# 21473                  10.1088/1361-648x/aa80d0
# 21474                  10.1088/1361-648x/aa80d0
# 21505                    10.3390/condmat4020057
# 21881                         10.1038/nphys3760
# 22048              10.1007/978-3-319-44680-6_21
# 22050              10.1007/978-3-319-44680-6_21
# 22186          10.1103/physrevapplied.13.024041
# 22267                10.1103/physrevb.91.184511
# 22268                10.1103/physrevb.91.184511
# 22566  10.1146/annurev-conmatphys-031218-013413
# 22568  10.1146/annurev-conmatphys-031218-013413
# 22570                                       nan
# 22571                                       nan
# 22572                                       nan
# 22611                                       nan
# 22956                     10.1515/nsm-2015-0006
# 22985               10.1103/physrevb.100.174506
# 22988               10.1103/physrevb.100.174506
# 23013                                       nan
# 23014                                       nan
# 23022                                       nan
# 23135                                       nan
# 23198                                       nan
# 23204                                       nan
# 23338                                       nan
# 23339                                       nan
# 23340                                       nan
# 23362                           10.2172/1176942
# 23814                       10.1149/2.008112jes
# 23815                       10.1149/2.008112jes

# %%
cleaned_supercon2_df.to_csv(CLEANED_SUPERCON_V2_CSV, index=False)

# %%
display(pd.read_csv(CLEANED_SUPERCON_V2_CSV))
# Out:
#               Material Substitutions  Tc (K)  Pressure (GPa)  \
# 0               In O x     {'x': []}    2.80             0.0
# 1                 In O            {}    2.00             0.0
# 2         Pr Ru 2 Si 2            {}   14.00             0.0
# 3      Lu 3 Os 4 Ge 13            {}    2.85             0.0
# 4         La Mn O 3.04            {}  125.00             0.0
# ...                ...           ...     ...             ...
# 23876          Nb Se 2            {}    7.00             0.0
# 23877           Mg B 2            {}   40.00             0.0
# 23878          Ca Bi 2            {}    2.00             0.0
# 23879          Ca Bi 2            {}    2.00             0.0
# 23880    Cd 2 Re 2 O 7            {}    1.00             0.0
#
#                      Classes               Shape Substrate  \
# 0                 ['Oxides']               films       NaN
# 1                 ['Alloys']               films       NaN
# 2                 ['Alloys']                 NaN       NaN
# 3                 ['Alloys']                 NaN       NaN
# 4                 ['Oxides']                 NaN       NaN
# ...                      ...                 ...       ...
# 23876      ['Chalcogenides']           nanobelts       NaN
# 23877  ['Alloys', 'Borides']                 NaN       NaN
# 23878             ['Alloys']                 NaN       NaN
# 23879             ['Alloys']  single-crystalline       NaN
# 23880             ['Oxides']     single crystals       NaN
#
#                                  DOI
# 0         10.1103/physrevb.99.054515
# 1                   10.1134/1.568304
# 2        10.1088/0953-8984/12/34/307
# 3                                NaN
# 4      10.1103/physrevlett.87.127206
# ...                              ...
# 23876     10.1103/physrevb.75.020501
# 23877     10.1103/physrevb.66.012511
# 23878                            NaN
# 23879                            NaN
# 23880  10.1016/s0022-3697(02)00090-2
#
# [23881 rows x 8 columns]

# %%
from pprint import pprint
formulas = set(cleaned_supercon2_df['Material'])
for f in formulas:
    if f:
        if pm := Superconductor(f).get_pristine_material(with_variables=True):
            print(Superconductor(f).formula,'\n  ', pm.formula)
# Out:
# [(Cu, 3), (O, 6.67)]
#    [(Cu, 3), (O, '7-a')]
# [(Bi, 2), (Pd, 1)]
#    [(Bi, 2), (Pd, 1)]
# [([(In, 1), (Mn, 1)], 1), (As, 1)]
#    [(In, 1), (Mn, 1), (As, 1)]
# [(Fe, '1-x'), (Cu, 'x'), (Se, 1)]
#    [(Fe, '1-x'), (Cu, 'x'), (Se, 1)]
# [(Ca, 1), (Pd, 2), (As, 2)]
#    [(Ca, 1), (Pd, 2), (As, 2)]
# [(Th, 1.8), (Sc, 0.2), (Ni, 1), (C, 2)]
#    [(Th, '2-a'), (Sc, 'a'), (Ni, 1), (C, 2)]
# [(Ca, 1.88), (Na, 0.12), (Cu, 1), (O, 2), (Cl, 2)]
#    [(Ca, '2-a'), (Na, 'a'), (Cu, 1), (O, 2), (Cl, 2)]
# [(Sn, 0.4), (Sb, 0.6)]
#    [(Sn, 'a'), (Sb, '1-a')]
# [(La, 1), (H, 'x')]
#    [(La, 1), (H, 'x')]
# [(Li, 0.75), (B, 1), (C, 1)]
#    [(Li, '1-a'), (B, 1), (C, 1)]
# [(Ba, '1-x'), (Rb, 'x'), (Fe, 2), (As, 2)]
#    [(Ba, '1-x'), (Rb, 'x'), (Fe, 2), (As, 2)]
# [(Ba, 1), (Fe, 1.8), (Co, 0.2), (Fe, 2), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Co, 'a'), (Fe, 2), (As, 2)]
# [(La, 1), (O, 0.8), (F, 0.2), (Fe, 1), (As, 0.95), (Sb, 0.05)]
#    [(La, 1), (O, '1-a'), (F, 'a'), (Fe, 1), (As, '1-b'), (Sb, 'b')]
# [(Ce, 1), (Pt, 2), (In, 7)]
#    [(Ce, 1), (Pt, 2), (In, 7)]
# [(Li, 2), (Pt, 1), (Si, 3)]
#    [(Li, 2), (Pt, 1), (Si, 3)]
# [(Fe, '1-y'), (Ni, 'y'), (Te, 0.5), (Se, 0.5)]
#    [(Fe, '1-y'), (Ni, 'y'), (Te, 'a'), (Se, '1-a')]
# [(Co, 1), (Fe, 1)]
#    [(Co, 1), (Fe, 1)]
# [(La, 2), (Cu, 1), (O, '4-δ')]
#    [(La, 2), (Cu, 1), (O, '4-δ')]
# [(Y, 4), (Co, 3)]
#    [(Y, 4), (Co, 3)]
# [(Zr, 5), (Pt, 3), (O, 0.6)]
#    [(Zr, 5), (Pt, 3), (O, '1-a')]
# [(Gd, 1), (O, 0.91), (F, 0.09), (Fe, 1), (As, 1)]
#    [(Gd, 1), (O, '1-a'), (F, 'a'), (Fe, 1), (As, 1)]
# [(Th, 1), (C, 0.78), (N, 0.22)]
#    [(Th, 1), (C, '1-a'), (N, 'a')]
# [(Cs, 'y'), (Fe, 2), (Se, 2)]
#    [(Cs, 'y'), (Fe, 2), (Se, 2)]
# [(Cu, 1), (Be, 1)]
#    [(Cu, 1), (Be, 1)]
# [(Nb, 1), (Ge, 1)]
#    [(Nb, 1), (Ge, 1)]
# [(Sn, 1), (Nb, 1), (Se, 2)]
#    [(Sn, 1), (Nb, 1), (Se, 2)]
# [(Gd, 4), (Fe, 2), (As, 2), (Te, '1-x'), (O, '4-y'), (F, 'y')]
#    [(Gd, 4), (Fe, 2), (As, 2), (Te, '1-x'), (O, '4-y'), (F, 'y')]
# [(Sm, '1-x'), (F, 'x'), (Fe, 1), (As, 1), (O, 1)]
#    [(Sm, '1-x'), (F, 'x'), (Fe, 1), (As, 1), (O, 1)]
# [(La, 1), (Pd, 2), (Si, 2)]
#    [(La, 1), (Pd, 2), (Si, 2)]
# [(La, 1), (O, 1), (Fe, 0.85), (Co, 0.15), (As, 1)]
#    [(La, 1), (O, 1), (Fe, '1-a'), (Co, 'a'), (As, 1)]
# [(La, 1), (B, 8), (H, 1)]
#    [(La, 1), (B, 8), (H, 1)]
# [([(Eu, 1), (K, 1)], 1), (Fe, 2), (As, 2)]
#    [(Eu, 1), (K, 1), (Fe, 2), (As, 2)]
# [(Ta, 2), (Pd, 3), (Te, 5)]
#    [(Ta, 2), (Pd, 3), (Te, 5)]
# [(Fe, 1), (Bi, 2)]
#    [(Fe, 1), (Bi, 2)]
# [(Sc, 1), (Ir, 1), (P, 1)]
#    [(Sc, 1), (Ir, 1), (P, 1)]
# [(Nb, 1), (Se, 3)]
#    [(Nb, 1), (Se, 3)]
# [(Zr, 2), (Ru, 3), (Si, 4)]
#    [(Zr, 2), (Ru, 3), (Si, 4)]
# [(Ga, 0.95), (Mn, 0.05), (As, 1)]
#    [(Ga, '1-a'), (Mn, 'a'), (As, 1)]
# [(Pd, 1), (Cu, 1), (H, 'x')]
#    [(Pd, 1), (Cu, 1), (H, 'x')]
# [(Sr, 1), (Pt, 3), (P, 1)]
#    [(Sr, 1), (Pt, 3), (P, 1)]
# [(Nb, 1), (B, 2.0)]
#    [(Nb, 1), (B, 2.0)]
# [(Sr, 1), (F, 1), (Fe, 0.87), (Co, 0.13), (As, 1)]
#    [(Sr, 1), (F, 1), (Fe, '1-a'), (Co, 'a'), (As, 1)]
# [(La, 1), (O, '1-x'), (F, 'x'), (Bi, 1), (S, 1), (Se, 1)]
#    [(La, 1), (O, '1-x'), (F, 'x'), (Bi, 1), (S, 1), (Se, 1)]
# [(Br, 1)]
#    [(Br, 1)]
# [(Ni, 0.53), (Cu, 0.47)]
#    [(Ni, '1-a'), (Cu, 'a')]
# [(Fe, 1), (Co, 1)]
#    [(Fe, 1), (Co, 1)]
# [(Fe, 1.01), (Te, 0.67), (Se, 0.33)]
#    [(Fe, '2-b'), (Te, '1-a'), (Se, 'a')]
# [(Cs, 3), (C, 1)]
#    [(Cs, 3), (C, 1)]
# [(Mo, 2), (C, 1), ([(O, 1), (H, 1)], 2)]
#    [(Mo, 2), (C, 1), ([(O, 1), (H, 1)], 2)]
# [(Y, 0.9), (Ca, 0.1), (Ba, 2), (Cu, 3), (O, 7)]
#    [(Y, '1-a'), (Ca, 'a'), (Ba, 2), (Cu, 3), (O, 7)]
# [(Tl, 2), (Fe, 4), (Se, 5)]
#    [(Tl, 2), (Fe, 4), (Se, 5)]
# [(Ir, 1)]
#    [(Ir, 1)]
# [(Ca, 1), (K, 1), ([(Fe, 0.95), (Ni, 0.05)], 4), (As, 4)]
#    [(Ca, 1), (K, 1), ([(Fe, '1-a'), (Ni, 'a')], 4), (As, 4)]
# [(Dy, 2), (O, 3)]
#    [(Dy, 2), (O, 3)]
# [(I, '4m2-'), (Sn, 1), (H, 8)]
#    [(I, '4m2-'), (Sn, 1), (H, 8)]
# [(Sm, 1), (Fe, 1), (As, 0.435), (P, 0.565), (O, 1)]
#    [(Sm, 1), (Fe, 1), (As, 'a'), (P, '1-a'), (O, 1)]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.99)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [([(Y, 1), (Gd, 1)], 1), (Ba, 2), (Cu, 3), (O, '7-x')]
#    [(Y, 1), (Gd, 1), (Ba, 2), (Cu, 3), (O, '7-x')]
# [(Se, 2)]
#    [(Se, 2)]
# [(Na, 2), (Cr, 3), (As, 3)]
#    [(Na, 2), (Cr, 3), (As, 3)]
# [(Ba, 1), (Fe, 2), ([(As, 0.72), (P, 0.28)], 2)]
#    [(Ba, 1), (Fe, 2), ([(As, '1-a'), (P, 'a')], 2)]
# [(La, 3), (Pt, 4)]
#    [(La, 3), (Pt, 4)]
# [(Mg, 1), (O, 1)]
#    [(Mg, 1), (O, 1)]
# [(Pr, 1), (Fe, 1), (As, 1), (O, '1-x'), (F, 'x')]
#    [(Pr, 1), (Fe, 1), (As, 1), (O, '1-x'), (F, 'x')]
# [(Au, 1), (Te, 2)]
#    [(Au, 1), (Te, 2)]
# [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, '8+δ')]
#    [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, '8+δ')]
# [(Gd, 2), (Cu, 3)]
#    [(Gd, 2), (Cu, 3)]
# [(Ni, 4)]
#    [(Ni, 4)]
# [(Y, 0.86), (Pr, 0.32), (Cu, 1), (O, 4)]
#    [(Y, '1-a'), (Pr, 'b'), (Cu, 1), (O, 4)]
# [(Cs, 0.8), (Fe, 1.6), (Fe, 2)]
#    [(Cs, '1-a'), (Fe, '2-b'), (Fe, 2)]
# [([(Sr, 1), (Ba, 1)], '1-x'), (K, 'x'), (Fe, 2), (As, 2)]
#    [([(Sr, 1), (Ba, 1)], '1-x'), (K, 'x'), (Fe, 2), (As, 2)]
# [(Nb, 5), (Ir, 1.4), (Pt, 1.6), (O, 1)]
#    [(Nb, 5), (Ir, '1+a'), (Pt, '2-a'), (O, 1)]
# [(Sr, 1), (Fe, 2), (As, '2-x'), (P, 'x')]
#    [(Sr, 1), (Fe, 2), (As, '2-x'), (P, 'x')]
# [(Nd, 1), (Fe, 1), (As, 1), (O, 0.9), (F, 0.1)]
#    [(Nd, 1), (Fe, 1), (As, 1), (O, '1-a'), (F, 'a')]
# [(K, 'x'), (Fe, '1.6+y'), (Se, 2)]
#    [(K, 'x'), (Fe, '1.6+y'), (Se, 2)]
# [(Sr, 3), (Sc, 2), (Fe, 2), (As, 2), (O, 5)]
#    [(Sr, 3), (Sc, 2), (Fe, 2), (As, 2), (O, 5)]
# [(La, 0.1), (Sr, 0.9), (Cu, 1), (O, 2)]
#    [(La, 'a'), (Sr, '1-a'), (Cu, 1), (O, 2)]
# [(Cs, 0.86), (Fe, 1.66), (Se, 2)]
#    [(Cs, '1-a'), (Fe, '2-b'), (Se, 2)]
# [(B, 1), (C, 1), (C, 1)]
#    [(B, 1), (C, 1), (C, 1)]
# [(Y, 1), (Pd, 2)]
#    [(Y, 1), (Pd, 2)]
# [(Ba, 1), (Fe, 2), ([(As, 0.8), (P, 0.2)], 2)]
#    [(Ba, 1), (Fe, 2), ([(As, '1-a'), (P, 'a')], 2)]
# [(Cu, 1), (O, 4)]
#    [(Cu, 1), (O, 4)]
# [(Bi, 1), (O, 1), (Cu, '1-y'), (S, 1)]
#    [(Bi, 1), (O, 1), (Cu, '1-y'), (S, 1)]
# [(La, 1), (Os, 4), (Sb, 12)]
#    [(La, 1), (Os, 4), (Sb, 12)]
# [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, 7)]
#    [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, 7)]
# [(Th, 1), (Co, 1), (As, 1), (N, 1)]
#    [(Th, 1), (Co, 1), (As, 1), (N, 1)]
# [(Gd, 0.9), (Sr, 0.1), (O, 1), (Ni, 1), (Bi, 1)]
#    [(Gd, '1-a'), (Sr, 'a'), (O, 1), (Ni, 1), (Bi, 1)]
# [(Th, 2), (C, 3)]
#    [(Th, 2), (C, 3)]
# [(Ce, 3), (Pt, 1), (In, 11)]
#    [(Ce, 3), (Pt, 1), (In, 11)]
# [(Bi, 1.7), (Pb, 0.3), (Sr, 2), (Ca, 2), (Cu, 3), (O, '10-δ')]
#    [(Bi, '2-a'), (Pb, 'a'), (Sr, 2), (Ca, 2), (Cu, 3), (O, '10-δ')]
# [(Nb, 3), (Ga, 'or'), (V, 3), (Ga, 1)]
#    [(Nb, 3), (Ga, 'or'), (V, 3), (Ga, 1)]
# [(La, 1), (Mn, 0.5), (Ga, 0.5), (O, 3)]
#    [(La, 1), (Mn, 'a'), (Ga, '1-a'), (O, 3)]
# [(Al, 1), (Mg, 2), (B, 6)]
#    [(Al, 1), (Mg, 2), (B, 6)]
# [(Ce, 1), ([(Ni, 0.65), (Pd, 0.25)], 2), (Ge, 2)]
#    [(Ce, 1), ([(Ni, '1-a'), (Pd, 'b')], 2), (Ge, 2)]
# [(K, 1), (Hg, 1), (C, 4)]
#    [(K, 1), (Hg, 1), (C, 4)]
# [(La, '2-x'), (Ca, '1+x'), (Cu, 2), (O, 6)]
#    [(La, '2-x'), (Ca, '1+x'), (Cu, 2), (O, 6)]
# [(Ba, '1-x'), (K, 'x'), (Fe, 2), (As, 2)]
#    [(Ba, '1-x'), (K, 'x'), (Fe, 2), (As, 2)]
# [(Cu, 1), (Ba, 2), (Ca, 3), (Cu, 4), (O, '12-δ')]
#    [(Cu, 1), (Ba, 2), (Ca, 3), (Cu, 4), (O, '12-δ')]
# [(Pr, 1), (Ba, 2), (Cu, 3), (O, 'x')]
#    [(Pr, 1), (Ba, 2), (Cu, 3), (O, 'x')]
# [(Tl, 2), (Ca, 2), (Ba, 2), (Cu, 3), (O, '10-δ')]
#    [(Tl, 2), (Ca, 2), (Ba, 2), (Cu, 3), (O, '10-δ')]
# [(Na, '1-x'), (Sn, 2), (P, 2)]
#    [(Na, '1-x'), (Sn, 2), (P, 2)]
# [(Ba, 1), (Al, 1), (Si, 1)]
#    [(Ba, 1), (Al, 1), (Si, 1)]
# [([(Li, '1-x'), (Fe, 'x')], 1), (O, 1), (H, 1), (Fe, '1-y'), (Se, 1)]
#    [(Li, '1-x'), (Fe, 'x'), (O, 1), (H, 1), (Fe, '1-y'), (Se, 1)]
# [(Sr, 1)]
#    [(Sr, 1)]
# [(Ba, 1), (Si, 2)]
#    [(Ba, 1), (Si, 2)]
# [(Ba, 0.5), (Sr, 0.5), ([(Fe, '1-x'), (Co, 'x')], 2), (As, 2)]
#    [(Ba, 'a'), (Sr, '1-a'), ([(Fe, '1-x'), (Co, 'x')], 2), (As, 2)]
# [(Si, 3), (N, 4)]
#    [(Si, 3), (N, 4)]
# [(La, 1), (O, 0.5), (F, 0.5), (Bi, 1), (S, 2), (H, 1), (P, 1)]
#    [(La, 1), (O, 'a'), (F, '1-a'), (Bi, 1), (S, 2), (H, 1), (P, 1)]
# [(Lu, 1), (Ni, 2), (B, 2), (C, 1)]
#    [(Lu, 1), (Ni, 2), (B, 2), (C, 1)]
# [([(V, 1), (O, 1)], 2), (P, 2), (O, 7)]
#    [([(V, 1), (O, 1)], 2), (P, 2), (O, 7)]
# [(La, 0.5), (Ca, 0.5), (Mn, 1), (O, 3)]
#    [(La, 'a'), (Ca, '1-a'), (Mn, 1), (O, 3)]
# [(Pr, 1), ([(O, 1), (F, 1)], 1), (Bi, 1), (S, 2)]
#    [(Pr, 1), (O, 1), (F, 1), (Bi, 1), (S, 2)]
# [(Sr, 1.4), (Ba, 0.6), (Cu, 1), (O, '3+δ')]
#    [(Sr, '2-a'), (Ba, 'a'), (Cu, 1), (O, '3+δ')]
# [(Co, 3), (Sn, 2), (S, 2)]
#    [(Co, 3), (Sn, 2), (S, 2)]
# [(Ta, 1), (Se, 2)]
#    [(Ta, 1), (Se, 2)]
# [(C, 2), (S, 2), (H, 4)]
#    [(C, 2), (S, 2), (H, 4)]
# [(Mg, 1), ([(B, 0.875), (C, 0.125)], 2)]
#    [(Mg, 1), ([(B, '1-a'), (C, 'a')], 2)]
# [(Hg, 1), (Ba, 2), (Cu, 1), (O, 6)]
#    [(Hg, 1), (Ba, 2), (Cu, 1), (O, 6)]
# [(La, 0.8), (Th, 0.2), (O, 1), (Bi, 1), (S, 2)]
#    [(La, '1-a'), (Th, 'a'), (O, 1), (Bi, 1), (S, 2)]
# [(Nd, 0.8), (Sr, 0.2), (Ni, 1), (O, 2)]
#    [(Nd, '1-a'), (Sr, 'a'), (Ni, 1), (O, 2)]
# [(Ce, 1), (Rh, 1), (Si, 3)]
#    [(Ce, 1), (Rh, 1), (Si, 3)]
# [(Ba, 2), (Cu, 1), (O, '3+δ')]
#    [(Ba, 2), (Cu, 1), (O, '3+δ')]
# [(Nb, 5), (Se, 2), (S, 2)]
#    [(Nb, 5), (Se, 2), (S, 2)]
# [([(Sr, '1-x'), (Ca, 'x')], 3), (Rh, 4), (Sn, 13)]
#    [([(Sr, '1-x'), (Ca, 'x')], 3), (Rh, 4), (Sn, 13)]
# [(La, 1), (Ir, 2), (Zn, 20)]
#    [(La, 1), (Ir, 2), (Zn, 20)]
# [(Sn, 1), (H, 12)]
#    [(Sn, 1), (H, 12)]
# [(Ca, 1), (Os, 4), (P, 12)]
#    [(Ca, 1), (Os, 4), (P, 12)]
# [(Ce, 1), (O, 0.3), (F, 0.7), (Bi, 1), (S, 2)]
#    [(Ce, 1), (O, 'a'), (F, '1-a'), (Bi, 1), (S, 2)]
# [(Ba, 0.6), (K, 0.4), (Fe, 2), (As, 1)]
#    [(Ba, '1-a'), (K, 'a'), (Fe, 2), (As, 1)]
# [(Li, 0.6), ([(N, 1), (H, 2)], 0.2), ([(N, 1), (H, 3)], 0.8), (Fe, 2), (Se, 2)]
#    [(Li, '1-b'), ([(N, 1), (H, 2)], 'a'), ([(N, 1), (H, 3)], '1-a'), (Fe, 2), (Se, 2)]
# [(La, 1.875), (Sr, 1), (Cu, 1), (O, 4)]
#    [(La, '2-a'), (Sr, 1), (Cu, 1), (O, 4)]
# [(La, 1), ([(O, 1), (F, 1)], 1), (Bi, 1), (S, 2)]
#    [(La, 1), (O, 1), (F, 1), (Bi, 1), (S, 2)]
# [(Nb, 65.2), (Rh, 34.8)]
#    [(Nb, '66-a'), (Rh, '34+a')]
# [(Dy, 2)]
#    [(Dy, 2)]
# [(Nb, 1), (Zr, 1)]
#    [(Nb, 1), (Zr, 1)]
# [(K, 'x'), (Ba, '1-x'), (Fe, 2), (As, 2)]
#    [(K, 'x'), (Ba, '1-x'), (Fe, 2), (As, 2)]
# [(Ga, '1-x'), (Mn, 'x'), (As, 1)]
#    [(Ga, '1-x'), (Mn, 'x'), (As, 1)]
# [([(Sr, 1)], 1), (Fe, 2), (As, 2)]
#    [(Sr, 1), (Fe, 2), (As, 2)]
# [(Tl, 1), (Ba, 1), (Ca, 1), (Cu, 1), (O, 1)]
#    [(Tl, 1), (Ba, 1), (Ca, 1), (Cu, 1), (O, 1)]
# [(Ca, 1), ([(Si, 0.5), (Al, 0.5)], 2)]
#    [(Ca, 1), ([(Si, 'a'), (Al, '1-a')], 2)]
# [(Cr, 5)]
#    [(Cr, 5)]
# [(K, '1-y'), (Fe, '2-x'), (Se, 2)]
#    [(K, '1-y'), (Fe, '2-x'), (Se, 2)]
# [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, 8)]
#    [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, 8)]
# [(La, 3), (In, 1)]
#    [(La, 3), (In, 1)]
# [(Bi, 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, 10)]
#    [(Bi, 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, 10)]
# [(Ba, 0.7), (K, 0.3), (Fe, 2), (As, 2)]
#    [(Ba, '1-a'), (K, 'a'), (Fe, 2), (As, 2)]
# [(Y, 1), (Ni, 2), (B, 2), (C, 1)]
#    [(Y, 1), (Ni, 2), (B, 2), (C, 1)]
# [(Sn, 0.5), (In, 0.5), (Te, 1)]
#    [(Sn, 'a'), (In, '1-a'), (Te, 1)]
# [(Ru, 1), (Sr, 2), (Er, 1), (Cu, 2), (O, 8)]
#    [(Ru, 1), (Sr, 2), (Er, 1), (Cu, 2), (O, 8)]
# [(Sr, 1), (Ru, 4), (As, 12)]
#    [(Sr, 1), (Ru, 4), (As, 12)]
# [(Mo, 3), (Rh, 2), (N, 1)]
#    [(Mo, 3), (Rh, 2), (N, 1)]
# [(Cu, 1), ([(N, 1), ([(C, 1), (N, 1)], 2)], 1), (Br, 'or'), (Cu, 1), ([(S, 1), (C, 1), (N, 1)], 2)]
#    [(Cu, 1), (N, 1), ([(C, 1), (N, 1)], 2), (Br, 'or'), (Cu, 1), ([(S, 1), (C, 1), (N, 1)], 2)]
# [([(Li, '1-x'), (Fe, 'x')], 1), (O, 1), (H, 1), (Fe, 1), (Se, 1)]
#    [(Li, '1-x'), (Fe, 'x'), (O, 1), (H, 1), (Fe, 1), (Se, 1)]
# [(Ca, 1), (Fe, 1), (As, 1), (F, 0.8), (H, 0.2)]
#    [(Ca, 1), (Fe, 1), (As, 1), (F, '1-a'), (H, 'a')]
# [(Gd, 1), (Fe, 1), (As, 1), (O, '1-x')]
#    [(Gd, 1), (Fe, 1), (As, 1), (O, '1-x')]
# [(Eu, 1), (Sr, 2), (Bi, 2), (S, 2), (Se, 2), (F, 4)]
#    [(Eu, 1), (Sr, 2), (Bi, 2), (S, 2), (Se, 2), (F, 4)]
# [(Na, '1-x'), (Fe, 1), (As, 1)]
#    [(Na, '1-x'), (Fe, 1), (As, 1)]
# [(Bi, 1.7), (Pb, 0.5), (Sr, 1.9), (Ca, 1), (Cu, 2), (O, '8+δ')]
#    [(Bi, '2-a'), (Pb, 'b'), (Sr, '2-c'), (Ca, 1), (Cu, 2), (O, '8+δ')]
# [([(K, 1), (Sr, 1)], 1), (Fe, 2), (As, 2)]
#    [(K, 1), (Sr, 1), (Fe, 2), (As, 2)]
# [(Fe, 1), ([(Se, '1-x'), (Te, 'x')], '1-δ')]
#    [(Fe, 1), ([(Se, '1-x'), (Te, 'x')], '1-δ')]
# [(Hf, 1), (B, 2)]
#    [(Hf, 1), (B, 2)]
# [(Ca, '1-x'), (Eu, 'x'), (Fe, 1), (As, 2)]
#    [(Ca, '1-x'), (Eu, 'x'), (Fe, 1), (As, 2)]
# [(Y, 0.85), (Ca, 0.15), (Ba, 2), (Cu, 3), (O, '6+x')]
#    [(Y, '1-a'), (Ca, 'a'), (Ba, 2), (Cu, 3), (O, '6+x')]
# [(Pt, 1)]
#    [(Pt, 1)]
# [(S, 1), (W, 1), (C, 1), (N, 1)]
#    [(S, 1), (W, 1), (C, 1), (N, 1)]
# [(Sm, 1), (O, 0.5), (F, 0.5), (Bi, 1), (S, 2)]
#    [(Sm, 1), (O, 'a'), (F, '1-a'), (Bi, 1), (S, 2)]
# [(Ir, 0.95), (Pd, 0.05), (Te, 2)]
#    [(Ir, '1-a'), (Pd, 'a'), (Te, 2)]
# [(Nb, 5), (Ir, 3), (O, 1)]
#    [(Nb, 5), (Ir, 3), (O, 1)]
# [(La, 2), (O, 3)]
#    [(La, 2), (O, 3)]
# [(Na, 1), (Fe, 0.99), (Co, 0.01), (As, 1)]
#    [(Na, 1), (Fe, '1-a'), (Co, 'a'), (As, 1)]
# [(Sr, 0.5), (Nd, 0.5), (F, 1), (Bi, 1), (S, 2)]
#    [(Sr, 'a'), (Nd, '1-a'), (F, 1), (Bi, 1), (S, 2)]
# [(Cu, 1), (Nb, '15k')]
#    [(Cu, 1), (Nb, '15k')]
# [(Sr, 1), (Cu, 1), (O, '6+δ')]
#    [(Sr, 1), (Cu, 1), (O, '6+δ')]
# [(Ca, '3-x'), (Ce, 'x'), (Rh, 4), (Sn, 13)]
#    [(Ca, '3-x'), (Ce, 'x'), (Rh, 4), (Sn, 13)]
# [(La, 3), (Ni, 2), (B, 2), (N, '3-δ')]
#    [(La, 3), (Ni, 2), (B, 2), (N, '3-δ')]
# [(Mg, 9.3), (Ir, 19), (B, 16.7)]
#    [(Mg, '9+a'), (Ir, 19), (B, '17-a')]
# [(C, 60)]
#    [(C, 60)]
# [(B, 4), (S, 1)]
#    [(B, 4), (S, 1)]
# [(Na, 0.35), ([(H, 2), (O, 1)], 1.3), (Co, 1), (O, '2-δ')]
#    [(Na, 'a'), ([(H, 2), (O, 1)], '2-b'), (Co, 1), (O, '2-δ')]
# [(Tl, 0.45), (K, 0.34), (Fe, 1.84), (Se, 2)]
#    [(Tl, 'a'), (K, 'b'), (Fe, '2-c'), (Se, 2)]
# [(Ho, 1)]
#    [(Ho, 1)]
# [(V, 1.98), (Cr, 0.02), (O, 3)]
#    [(V, '2-a'), (Cr, 'a'), (O, 3)]
# [(Pd, 1), (Te, 1)]
#    [(Pd, 1), (Te, 1)]
# [(Li, 1), (Fe, 1), (As, 21)]
#    [(Li, 1), (Fe, 1), (As, 21)]
# [(Mg, 1), ([(B, '1-x'), (C, 'x')], 2)]
#    [(Mg, 1), ([(B, '1-x'), (C, 'x')], 2)]
# [(Sr, 1), (Fe, '2-x'), (Pt, 'x'), (As, 2)]
#    [(Sr, 1), (Fe, '2-x'), (Pt, 'x'), (As, 2)]
# [(P, 1), (H, 2)]
#    [(P, 1), (H, 2)]
# [(Mg, 0.8), (Al, 0.2), (B, 2)]
#    [(Mg, '1-a'), (Al, 'a'), (B, 2)]
# [(Cs, 3), (C, 60)]
#    [(Cs, 3), (C, 60)]
# [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8+δ')]
#    [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8+δ')]
# [(La, 1), ([(O, 1), (F, 1)], 1), (Bi, 1), (S, 1), (Se, 1)]
#    [(La, 1), (O, 1), (F, 1), (Bi, 1), (S, 1), (Se, 1)]
# [([(Ba, 1.6), (K, 0.4)], 1), (Fe, 2), (As, 2)]
#    [(Ba, '2-a'), (K, 'a'), (Fe, 2), (As, 2)]
# [(Na, 2), (Ti, 2), (Sb, 2), (O, 1)]
#    [(Na, 2), (Ti, 2), (Sb, 2), (O, 1)]
# [(La, 0.7), (Ce, 0.3), (Mn, 1), (O, 3)]
#    [(La, '1-a'), (Ce, 'a'), (Mn, 1), (O, 3)]
# [(Sr, 1), ([(Fe, 0.92), (Pt, 0.08)], 2), (As, 2)]
#    [(Sr, 1), ([(Fe, '1-a'), (Pt, 'a')], 2), (As, 2)]
# [(Mo, 0.8), (Si, 0.2)]
#    [(Mo, '1-a'), (Si, 'a')]
# [(W, 1), (Si, 'x')]
#    [(W, 1), (Si, 'x')]
# [(Sn, 1), (Mo, 6), (S, 8)]
#    [(Sn, 1), (Mo, 6), (S, 8)]
# [(Ni, 1), (Bi, 3)]
#    [(Ni, 1), (Bi, 3)]
# [(Li, 1.07), ([(Zn, 0.93), (Mn, 0.07)], 1), (P, 1)]
#    [(Li, '2-a'), (Zn, '1-a'), (Mn, 'a'), (P, 1)]
# [(La, 1.675), (Eu, 0.2), (Sr, 0.125), (Cu, 1), (O, 4)]
#    [(La, '2-a'), (Eu, 'b'), (Sr, 'c'), (Cu, 1), (O, 4)]
# [(Nb, 1), (B, 'x')]
#    [(Nb, 1), (B, 'x')]
# [([(Ba, 1), (La, 1)], 1), (Pb, 1), (O, 3)]
#    [(Ba, 1), (La, 1), (Pb, 1), (O, 3)]
# [(Re, 0.82), (Nb, 0.18)]
#    [(Re, '1-a'), (Nb, 'a')]
# [(Mg, 1), (C, 0.93), (Ni, 2.85)]
#    [(Mg, 1), (C, '1-a'), (Ni, '3-b')]
# [([(Ru, 1), (Rh, 1)], 1), (P, 1)]
#    [(Ru, 1), (Rh, 1), (P, 1)]
# [(Sr, 1), (C, 6)]
#    [(Sr, 1), (C, 6)]
# [(Nd, 1), (Fe, '1-x'), (Rh, 'x'), (As, 1), (O, 1)]
#    [(Nd, 1), (Fe, '1-x'), (Rh, 'x'), (As, 1), (O, 1)]
# [(Rb, 1), (Fe, 2), (Se, 2)]
#    [(Rb, 1), (Fe, 2), (Se, 2)]
# [(Ba, 1), (Fe, 2), ([(As, 0.47), (P, 0.53)], 2)]
#    [(Ba, 1), (Fe, 2), ([(As, 'a'), (P, '1-a')], 2)]
# [(La, 1), (Rh, 1), (Al, 1)]
#    [(La, 1), (Rh, 1), (Al, 1)]
# [(Nb, 0.9), (Bi, 1.2), (Se, 3)]
#    [(Nb, '1-a'), (Bi, '2-b'), (Se, 3)]
# [(Ba, 1.5)]
#    [(Ba, '2-a')]
# [(Ba, 1), (Rh, 2), (As, 2)]
#    [(Ba, 1), (Rh, 2), (As, 2)]
# [(Sr, 0.4), (Ca, 13.6), (Cu, 24), (O, 41.8)]
#    [(Sr, 'a'), (Ca, '14-a'), (Cu, 24), (O, '42-b')]
# [(Yb, 2.75), (C, 60)]
#    [(Yb, '3-a'), (C, 60)]
# [(Ni, 1), (Te, 1)]
#    [(Ni, 1), (Te, 1)]
# [(Ba, 1), (K, 1), (Fe, 1), (As, 1)]
#    [(Ba, 1), (K, 1), (Fe, 1), (As, 1)]
# [(Sr, 1), (Ir, 2)]
#    [(Sr, 1), (Ir, 2)]
# [(Cr, 2), (Re, 3), (B, 1)]
#    [(Cr, 2), (Re, 3), (B, 1)]
# [(Y, 1), (Ba, 1.9), (La, 0.1), (Cu, 4), (O, 8)]
#    [(Y, 1), (Ba, '2-a'), (La, 'a'), (Cu, 4), (O, 8)]
# [(Ba, 0.6), (K, 0.4), (Fe, 1), (As, 2)]
#    [(Ba, '1-a'), (K, 'a'), (Fe, 1), (As, 2)]
# [(Nb, 4), (Rh, 2), (C, 1)]
#    [(Nb, 4), (Rh, 2), (C, 1)]
# [(Al, 1)]
#    [(Al, 1)]
# [(Ge, 2)]
#    [(Ge, 2)]
# [(Co, 1)]
#    [(Co, 1)]
# [(Sm, 1), (Ba, 2), (Cu, 3), (O, 7)]
#    [(Sm, 1), (Ba, 2), (Cu, 3), (O, 7)]
# [(Sr, 1), ([(Fe, '1-x'), (Ni, 'x')], 2), (As, 2)]
#    [(Sr, 1), ([(Fe, '1-x'), (Ni, 'x')], 2), (As, 2)]
# [(N, 'd'), (O, 0.86), (F, 0.14), (F, 'e'), (As, 1)]
#    [(N, 'd'), (O, '1-a'), (F, 'a'), (F, 'e'), (As, 1)]
# [(Mo, '8-x'), (V, 'x'), (Ga, 41)]
#    [(Mo, '8-x'), (V, 'x'), (Ga, 41)]
# [(Cs, '1-y'), (Fe, '2-x'), (Se, 2)]
#    [(Cs, '1-y'), (Fe, '2-x'), (Se, 2)]
# [(Pb, '1-x'), (Tl, 'x'), (Te, 1)]
#    [(Pb, '1-x'), (Tl, 'x'), (Te, 1)]
# [(Y, 1), (Ir, 2), (Si, 2)]
#    [(Y, 1), (Ir, 2), (Si, 2)]
# [(Ba, 1), ([(Fe, 0.973), (Ir, 0.027)], 2), (As, 2)]
#    [(Ba, 1), ([(Fe, '1-a'), (Ir, 'a')], 2), (As, 2)]
# [(Li, 1), (Nb, 1), (O, 2)]
#    [(Li, 1), (Nb, 1), (O, 2)]
# [(Ca, 1), (Fe, 1.947), (Ni, 0.053), (As, 2)]
#    [(Ca, 1), (Fe, '2-a'), (Ni, 'a'), (As, 2)]
# [(U, 1), (Co, 1), (Al, 1)]
#    [(U, 1), (Co, 1), (Al, 1)]
# [([(Tl, 1), (Rb, 1)], 1), (Fe, '2-x'), (Se, 2)]
#    [(Tl, 1), (Rb, 1), (Fe, '2-x'), (Se, 2)]
# [(Sn, 1), (O, 1)]
#    [(Sn, 1), (O, 1)]
# [(Fe, 1), ([(Te, '1-x'), (S, 'x')], 'y')]
#    [(Fe, 1), ([(Te, '1-x'), (S, 'x')], 'y')]
# [(Fe, 1), (Se, 'x')]
#    [(Fe, 1), (Se, 'x')]
# [(Nb, 0.9), (B, 2)]
#    [(Nb, '1-a'), (B, 2)]
# [(Pr, 1), (Fe, 1), (As, 1), (O, 0.9)]
#    [(Pr, 1), (Fe, 1), (As, 1), (O, '1-a')]
# [(S, 'un'), (Cu, 1)]
#    [(S, 'un'), (Cu, 1)]
# [(Sn, 1), (Sb, 1)]
#    [(Sn, 1), (Sb, 1)]
# [(Ba, 1), (Fe, '2-x'), (Ru, 'x'), (As, 2)]
#    [(Ba, 1), (Fe, '2-x'), (Ru, 'x'), (As, 2)]
# [(La, 1), (Ru, 4), (As, 12)]
#    [(La, 1), (Ru, 4), (As, 12)]
# [([(Sr, 0.6), (Na, 0.4)], 1), (Fe, 2), (As, 2)]
#    [(Sr, '1-a'), (Na, 'a'), (Fe, 2), (As, 2)]
# [(Ti, 3), (N, 4)]
#    [(Ti, 3), (N, 4)]
# [(Ca, 1.5), (C, 22), (H, 14)]
#    [(Ca, '2-a'), (C, 22), (H, 14)]
# [(C, 1), (Li, 1)]
#    [(C, 1), (Li, 1)]
# [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, 'y')]
#    [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, 'y')]
# [(Ru, 1), (Eu, 1.5), (Ce, 0.5), (Sr, 2), (Cu, 2), (O, 10)]
#    [(Ru, 1), (Eu, '2-a'), (Ce, 'a'), (Sr, 2), (Cu, 2), (O, 10)]
# [(Cu, 2.01), (O, '8+δ')]
#    [(Cu, '3-a'), (O, '8+δ')]
# [(Nd, 2), (Mo, 2), (O, 7)]
#    [(Nd, 2), (Mo, 2), (O, 7)]
# [(S, 1), (Cd, 1)]
#    [(S, 1), (Cd, 1)]
# [(Sr, 'x'), (Bi, 2), (Se, 3)]
#    [(Sr, 'x'), (Bi, 2), (Se, 3)]
# [(K, 0.8), (Fe, '2-y'), (Se, 2)]
#    [(K, '1-a'), (Fe, '2-y'), (Se, 2)]
# [(K, 1), (Tl, 1.5), (C, 4)]
#    [(K, 1), (Tl, '2-a'), (C, 4)]
# [(Pr, 1.85), (Ce, 0.15), (Cu, 1), (O, '4-y')]
#    [(Pr, '2-a'), (Ce, 'a'), (Cu, 1), (O, '4-y')]
# [(Lu, 0.814), (Y, 0.186), (Fe, 2), (Ge, 2)]
#    [(Lu, '1-a'), (Y, 'a'), (Fe, 2), (Ge, 2)]
# [(Bi, 2.15), (Sr, 1.85), (Ca, 1), (Cu, 2), (O, '8+x')]
#    [(Bi, '3-a'), (Sr, '1+a'), (Ca, 1), (Cu, 2), (O, '8+x')]
# [(La, 1), (Sn, 3)]
#    [(La, 1), (Sn, 3)]
# [(Mg, 1), (Fe, 1), (Se, 1), (O, 1)]
#    [(Mg, 1), (Fe, 1), (Se, 1), (O, 1)]
# [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8+y')]
#    [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8+y')]
# [(Sr, 1), (Ce, 1), (F, 2), (Bi, 2), (S, 4), (Pd, 4)]
#    [(Sr, 1), (Ce, 1), (F, 2), (Bi, 2), (S, 4), (Pd, 4)]
# [(Bi, 2), (Sr, 2), (Ca, 7), (Cu, 8), (O, '20+x')]
#    [(Bi, 2), (Sr, 2), (Ca, 7), (Cu, 8), (O, '20+x')]
# [(Sm, 1), (Co, 1), (Fe, 1), (As, 1), (O, 1)]
#    [(Sm, 1), (Co, 1), (Fe, 1), (As, 1), (O, 1)]
# [(Ca, 1), (B, 3), (H, 1)]
#    [(Ca, 1), (B, 3), (H, 1)]
# [(Li, 2), (Ru, 3), (B, 1)]
#    [(Li, 2), (Ru, 3), (B, 1)]
# [(Zr, 40), (Cu, 60)]
#    [(Zr, 40), (Cu, 60)]
# [(Ca, 10), ([(Pt, 3), (As, 8)], 1), ([(Fe, 2), (As, 2)], 5)]
#    [(Ca, 10), (Pt, 3), (As, 8), ([(Fe, 2), (As, 2)], 5)]
# [([(Mo, 1), (S, 2)], 2), (Na, 1)]
#    [([(Mo, 1), (S, 2)], 2), (Na, 1)]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.8)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(Y, 1), (B, 2), (C, 3), (O, '6+δ')]
#    [(Y, 1), (B, 2), (C, 3), (O, '6+δ')]
# [(Li, 2), (Pt, 3), (B, 1)]
#    [(Li, 2), (Pt, 3), (B, 1)]
# [(Ba, 1), (Ti, 1), (O, 3)]
#    [(Ba, 1), (Ti, 1), (O, 3)]
# [(Nb, '1-x'), (Sn, 'x')]
#    [(Nb, '1-x'), (Sn, 'x')]
# [(Ce, 1), (Pd, 2), (Ge, 2)]
#    [(Ce, 1), (Pd, 2), (Ge, 2)]
# [(La, '1.6-x'), (Nd, 0.4), (Sr, 'x'), (Cu, 1), (O, 4)]
#    [(La, '1.6-x'), (Nd, 'a'), (Sr, 'x'), (Cu, 1), (O, 4)]
# [(Sm, 1), (Fe, 1), (As, 1), (O, 0.85)]
#    [(Sm, 1), (Fe, 1), (As, 1), (O, '1-a')]
# [(Ba, 1), (Fe, 1.906), (Co, 0.094), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Co, 'a'), (As, 2)]
# [(La, 1.86), (Sr, 0.14), (Cu, 0.988), (Zn, 0.012), (O, 4)]
#    [(La, '2-a'), (Sr, 'a'), (Cu, '1-b'), (Zn, 'b'), (O, 4)]
# [(Ni, 1)]
#    [(Ni, 1)]
# [(Cu, 1), (Rh, 2), (Se, 4)]
#    [(Cu, 1), (Rh, 2), (Se, 4)]
# [(Pd, 84), (Ni, 16)]
#    [(Pd, 84), (Ni, 16)]
# [(H, 1), (P, 1), (Sn, '1-x'), (Ag, 'x'), (Te, 1)]
#    [(H, 1), (P, 1), (Sn, '1-x'), (Ag, 'x'), (Te, 1)]
# [(Hg, 1), (Ba, 1), (Ca, 1), (Cu, 1), (O, 1)]
#    [(Hg, 1), (Ba, 1), (Ca, 1), (Cu, 1), (O, 1)]
# [(Ru, 0.55), (Rh, 0.45), (P, 1)]
#    [(Ru, '1-a'), (Rh, 'a'), (P, 1)]
# [(La, 1), (Ru, 1), (P, 1), (O, 1)]
#    [(La, 1), (Ru, 1), (P, 1), (O, 1)]
# [(Zn, 1), (N, 1)]
#    [(Zn, 1), (N, 1)]
# [(Li, 2), (Ag, 3), (B, 1)]
#    [(Li, 2), (Ag, 3), (B, 1)]
# [(Cs, 'x'), (Fe, '2-y'), (Se, 2)]
#    [(Cs, 'x'), (Fe, '2-y'), (Se, 2)]
# [(Cu, 0.3), (Bi, 2), (Se, 3)]
#    [(Cu, 'a'), (Bi, 2), (Se, 3)]
# [(Ce, 1), (Cu, 2), (Ge, 2)]
#    [(Ce, 1), (Cu, 2), (Ge, 2)]
# [(La, 1), ([(O, 0.93), (F, 0.07)], 1), (Fe, 1), (As, 1)]
#    [(La, 1), (O, '1-a'), (F, 'a'), (Fe, 1), (As, 1)]
# [(Sr, 4), (Sc, 2), (O, 6)]
#    [(Sr, 4), (Sc, 2), (O, 6)]
# [(In, 1), (O, 4)]
#    [(In, 1), (O, 4)]
# [(Nd, 1.9), (Ce, 0.1), (Cu, 1), (O, 4)]
#    [(Nd, '2-a'), (Ce, 'a'), (Cu, 1), (O, 4)]
# [(Sr, 2), (Sc, 1), (Fe, 1), (P, 1), (O, 3)]
#    [(Sr, 2), (Sc, 1), (Fe, 1), (P, 1), (O, 3)]
# [([(La, '1-x'), (Sr, 'x')], 1), (Fe, 1), (As, 1), (O, 1)]
#    [(La, '1-x'), (Sr, 'x'), (Fe, 1), (As, 1), (O, 1)]
# [(Sr, 2), ([(Mg, 'y'), (Ti, '1-y')], 1), (O, 3), (Fe, 1), (As, 1)]
#    [(Sr, 2), (Mg, 'y'), (Ti, '1-y'), (O, 3), (Fe, 1), (As, 1)]
# [(Li, 2), (Ir, 1), (Si, 3)]
#    [(Li, 2), (Ir, 1), (Si, 3)]
# [(Y, 1)]
#    [(Y, 1)]
# [(Pr, 1), (Ba, 2), (Cu, 4), (O, 7)]
#    [(Pr, 1), (Ba, 2), (Cu, 4), (O, 7)]
# [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, '8+x')]
#    [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, '8+x')]
# [(Na, 'no'), (B, 1), (Mg, 1), (B, 2)]
#    [(Na, 'no'), (B, 1), (Mg, 1), (B, 2)]
# [(La, 1), ([(O, 1), (F, 1)], 1), (Bi, 1), (Se, 1), (S, 1)]
#    [(La, 1), (O, 1), (F, 1), (Bi, 1), (Se, 1), (S, 1)]
# [(Sm, 0.9), (Th, 0.1), (Fe, 1), (As, 1), (O, 0.85), (F, 0.15)]
#    [(Sm, '1-a'), (Th, 'a'), (Fe, 1), (As, 1), (O, '1-b'), (F, 'b')]
# [(Nb, 2), (Pd, 'x'), (S, '5-y')]
#    [(Nb, 2), (Pd, 'x'), (S, '5-y')]
# [(Ba, 2), (Ti, 2), (Fe, 2), (As, 4), (O, 2)]
#    [(Ba, 2), (Ti, 2), (Fe, 2), (As, 4), (O, 2)]
# [(O, 6.93)]
#    [(O, '7-a')]
# [(Na, 'x'), (Cu, 1), (O, 2), (Cl, 2)]
#    [(Na, 'x'), (Cu, 1), (O, 2), (Cl, 2)]
# [([(Y, 0.7), (Th, 0.3)], 2), (C, 3)]
#    [([(Y, '1-a'), (Th, 'a')], 2), (C, 3)]
# [(Na, 1), (Fe, 0.972), (Co, 0.028), (As, 1)]
#    [(Na, 1), (Fe, '1-a'), (Co, 'a'), (As, 1)]
# [(Bi, 1)]
#    [(Bi, 1)]
# [(Rb, 'y'), (Fe, '1.6+x'), (Se, 2)]
#    [(Rb, 'y'), (Fe, '1.6+x'), (Se, 2)]
# [(Ca, 0.73), (La, 0.27), (Fe, 1), (As, 2)]
#    [(Ca, '1-a'), (La, 'a'), (Fe, 1), (As, 2)]
# [(Fe, 1), (Te, 0.65), (Se, 0.35)]
#    [(Fe, 1), (Te, '1-a'), (Se, 'a')]
# [(Ta, 1), (Nb, 1)]
#    [(Ta, 1), (Nb, 1)]
# [(Ba, 0.6), (K, 0.4), (Bi, 1), (O, 3)]
#    [(Ba, '1-a'), (K, 'a'), (Bi, 1), (O, 3)]
# [(La, 3), (Co, 4), (Sn, '13-x'), (In, 'x')]
#    [(La, 3), (Co, 4), (Sn, '13-x'), (In, 'x')]
# [(Y, 1), (Ba, 2), ([(Cu, '1-x'), (Li, 'x')], 3), (O, 6.6)]
#    [(Y, 1), (Ba, 2), ([(Cu, '1-x'), (Li, 'x')], 3), (O, '7-a')]
# [(Sr, 'n+1'), (Ru, 'n'), (O, '3n+1')]
#    [(Sr, 'n+1'), (Ru, 'n'), (O, '3n+1')]
# [(Zr, 1), (Pd, 2), (Al, 1)]
#    [(Zr, 1), (Pd, 2), (Al, 1)]
# [(Pb, 1), (Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, 8)]
#    [(Pb, 1), (Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, 8)]
# [(La, 3), (Co, 4), (Sn, 11.7), (In, 1.3)]
#    [(La, 3), (Co, 4), (Sn, '12-a'), (In, '1+a')]
# [(Eu, 1), (Fe, 4), (Sb, 12)]
#    [(Eu, 1), (Fe, 4), (Sb, 12)]
# [(Eu, 1), ([(Fe, 0.75), (Ru, 0.25)], 2), (As, 2)]
#    [(Eu, 1), ([(Fe, '1-a'), (Ru, 'a')], 2), (As, 2)]
# [(La, 1), ([(Ba, 1), (Ca, 1)], 2), (Cu, 3), (O, 'x')]
#    [(La, 1), ([(Ba, 1), (Ca, 1)], 2), (Cu, 3), (O, 'x')]
# [(C, 8), (Cs, 1)]
#    [(C, 8), (Cs, 1)]
# [(Sc, 1), (In, 1), (Au, 2)]
#    [(Sc, 1), (In, 1), (Au, 2)]
# [(Ni, 1), (S, 2)]
#    [(Ni, 1), (S, 2)]
# [(Sr, 0.6), (La, 0.4), (Ru, 1), (O, 3)]
#    [(Sr, '1-a'), (La, 'a'), (Ru, 1), (O, 3)]
# [(La, 1), (O, 0.9), (F, 0.1), (Fe, 1), (As, '1-δ')]
#    [(La, 1), (O, '1-a'), (F, 'a'), (Fe, 1), (As, '1-δ')]
# [(Ca, 0.11), ([(N, 1), (H, 3)], 'y'), (Hf, 1), (N, 1), (Cl, 1)]
#    [(Ca, 'a'), ([(N, 1), (H, 3)], 'y'), (Hf, 1), (N, 1), (Cl, 1)]
# [(Ir, 0.95), (Pt, 0.05), (Te, 2)]
#    [(Ir, '1-a'), (Pt, 'a'), (Te, 2)]
# [(Cu, 1), (S, 2)]
#    [(Cu, 1), (S, 2)]
# [(N, 'b'), (C, 1)]
#    [(N, 'b'), (C, 1)]
# [(La, '2-x'), (Sr, 'x'), (Cu, '1-y'), (Zn, 'y'), (O, 4)]
#    [(La, '2-x'), (Sr, 'x'), (Cu, '1-y'), (Zn, 'y'), (O, 4)]
# [(Ca, '1-x'), (La, 'x'), (Fe, 2), ([(As, '1-y'), (P, 'y')], 2)]
#    [(Ca, '1-x'), (La, 'x'), (Fe, 2), ([(As, '1-y'), (P, 'y')], 2)]
# [(Nb, 1), (N, 1)]
#    [(Nb, 1), (N, 1)]
# [(Ag, 20)]
#    [(Ag, 20)]
# [(Pb, 1), (Te, 1), (Sn, 1), (Te, 1)]
#    [(Pb, 1), (Te, 1), (Sn, 1), (Te, 1)]
# [(Li, 1), (Fe, 0.98), (Cu, 0.02), (As, 1)]
#    [(Li, 1), (Fe, '1-a'), (Cu, 'a'), (As, 1)]
# [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8-δ')]
#    [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8-δ')]
# [(Tb, 1), (Pd, 1), (Bi, 1)]
#    [(Tb, 1), (Pd, 1), (Bi, 1)]
# [([(Sm, 1), (Sr, 1)], 1), (Mn, 1), (O, 3)]
#    [(Sm, 1), (Sr, 1), (Mn, 1), (O, 3)]
# [(La, 1), (Cu, 1), (O, '4+δ')]
#    [(La, 1), (Cu, 1), (O, '4+δ')]
# [(Sb, 2), (Te, 3)]
#    [(Sb, 2), (Te, 3)]
# [(F, 1), (B, 1), (S, 's')]
#    [(F, 1), (B, 1), (S, 's')]
# [(Gd, 2), (Ti, 2), (O, 7)]
#    [(Gd, 2), (Ti, 2), (O, 7)]
# [(Ca, 1), (Ru, 1), (O, 3)]
#    [(Ca, 1), (Ru, 1), (O, 3)]
# [(Yb, 1), (Rh, 2), (Si, 2)]
#    [(Yb, 1), (Rh, 2), (Si, 2)]
# [(C, 1), (S, 3)]
#    [(C, 1), (S, 3)]
# [(Sm, 1), (Co, 1), (As, 1), (O, 1)]
#    [(Sm, 1), (Co, 1), (As, 1), (O, 1)]
# [(C, 7)]
#    [(C, 7)]
# [(Dy, 1), (Sc, 1), (O, 3)]
#    [(Dy, 1), (Sc, 1), (O, 3)]
# [(Li, 'x'), (B, 1), (C, 1)]
#    [(Li, 'x'), (B, 1), (C, 1)]
# [(Rh, 2), (Ga, 9)]
#    [(Rh, 2), (Ga, 9)]
# [(Ba, '1-x'), ([(K, 1), (Na, 1)], 'x'), (Fe, 2), (As, 2)]
#    [(Ba, '1-x'), ([(K, 1), (Na, 1)], 'x'), (Fe, 2), (As, 2)]
# [(C, 2), (S, 3), (H, 4)]
#    [(C, 2), (S, 3), (H, 4)]
# [(La, 1), (Pt, 1), (Bi, 1)]
#    [(La, 1), (Pt, 1), (Bi, 1)]
# [(Ta, 1), (Rh, 2), (B, 2)]
#    [(Ta, 1), (Rh, 2), (B, 2)]
# [(Sr, 2), (Sc, 1), (Fe, 1), (As, 1), (O, 3)]
#    [(Sr, 2), (Sc, 1), (Fe, 1), (As, 1), (O, 3)]
# [(Th, 1), (H, 10)]
#    [(Th, 1), (H, 10)]
# [(Ba, 1), (Fe, '2-2x'), (Co, '2x'), (As, 2)]
#    [(Ba, 1), (Fe, '2-2x'), (Co, '2x'), (As, 2)]
# [([(Y, 0.7), (Ca, 0.3)], 1), (Ba, 2), (Cu, 3), (O, 7)]
#    [(Y, '1-a'), (Ca, 'a'), (Ba, 2), (Cu, 3), (O, 7)]
# [(Ba, 1), (Fe, 1.84), (Co, 0.16)]
#    [(Ba, 1), (Fe, '2-a'), (Co, 'a')]
# [(La, 1), (N, 'i'), (As, 1), (O, 1)]
#    [(La, 1), (N, 'i'), (As, 1), (O, 1)]
# [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, 'y')]
#    [(Bi, 2), (Sr, 2), (Ca, 1), (Cu, 2), (O, 'y')]
# [(Tl, 1), (Ba, 2), (Ca, 4), (Cu, 5), (O, 'y')]
#    [(Tl, 1), (Ba, 2), (Ca, 4), (Cu, 5), (O, 'y')]
# [(Na, 0.05), (W, 1), (O, 3)]
#    [(Na, 'a'), (W, 1), (O, 3)]
# [(Sn, 3)]
#    [(Sn, 3)]
# [(Eu, '1-x'), ([(K, 1), (Na, 1)], 'x'), (Fe, 2), (As, 2)]
#    [(Eu, '1-x'), ([(K, 1), (Na, 1)], 'x'), (Fe, 2), (As, 2)]
# [(Pr, 1), (Fe, 1), (As, 1), (O, 'x'), (F, 'y')]
#    [(Pr, 1), (Fe, 1), (As, 1), (O, 'x'), (F, 'y')]
# [([(Ru, 1), (Rh, 1)], 1), (As, 1)]
#    [(Ru, 1), (Rh, 1), (As, 1)]
# [(Zr, 70), (Cu, 30)]
#    [(Zr, 70), (Cu, 30)]
# [(Li, 1), (Sn, 1), (Se, 2)]
#    [(Li, 1), (Sn, 1), (Se, 2)]
# [(Ba, 1), (Fe, 1.094), (Ni, 0.096), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Ni, 'b'), (As, 2)]
# [(Ba, 'x'), (K, '1-x'), (Bi, 1), (O, 3)]
#    [(Ba, 'x'), (K, '1-x'), (Bi, 1), (O, 3)]
# [(Ir, 2), (Ga, 9)]
#    [(Ir, 2), (Ga, 9)]
# [(La, '1-x'), (Sm, 'x'), (O, 0.5), (F, 0.5), (Bi, 1), (S, 2)]
#    [(La, '1-x'), (Sm, 'x'), (O, 'a'), (F, '1-a'), (Bi, 1), (S, 2)]
# [(Bi, 1.85), (Pb, 0.35), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8+x')]
#    [(Bi, '2-a'), (Pb, 'b'), (Sr, 2), (Ca, 1), (Cu, 2), (O, '8+x')]
# [(Fe, 1)]
#    [(Fe, 1)]
# [(Nb, 3), (Sn, 6)]
#    [(Nb, 3), (Sn, 6)]
# [(Rb, 2), (Mo, 3), (As, 3)]
#    [(Rb, 2), (Mo, 3), (As, 3)]
# [(Ba, 1), (Fe, 1.88), (Co, 0.12)]
#    [(Ba, 1), (Fe, '2-a'), (Co, 'a')]
# [(Bi, 2), (Sr, '2-x'), (La, 'x'), (Cu, 1), (O, 'y')]
#    [(Bi, 2), (Sr, '2-x'), (La, 'x'), (Cu, 1), (O, 'y')]
# [(Cu, 1), (Fe, 1), (As, 1)]
#    [(Cu, 1), (Fe, 1), (As, 1)]
# [(K, 0.8), (Fe, '2-y'), (Se, 1.01), (S, 0.99)]
#    [(K, '1-b'), (Fe, '2-y'), (Se, '2-a'), (S, 'a')]
# [(Ca, 1), (Fe, 0.9), (Co, 0.1), (As, 1), (F, 1)]
#    [(Ca, 1), (Fe, '1-a'), (Co, 'a'), (As, 1), (F, 1)]
# [(Nb, 3), (Se, 4)]
#    [(Nb, 3), (Se, 4)]
# [(Mo, 2), (C, 1)]
#    [(Mo, 2), (C, 1)]
# [([(Tl, 1), (K, 1)], 'x'), (Fe, '2-y'), (Se, 2)]
#    [([(Tl, 1), (K, 1)], 'x'), (Fe, '2-y'), (Se, 2)]
# [(Bi, 1.7), (Pb, 0.4), (Sr, 1.6), (Cu, 2), (O, '6+δ')]
#    [(Bi, '2-b'), (Pb, 'a'), (Sr, '2-a'), (Cu, 2), (O, '6+δ')]
# [(Au, '1-x'), (Pt, 'x'), (Te, 2)]
#    [(Au, '1-x'), (Pt, 'x'), (Te, 2)]
# [(Nd, 1.85), (Ce, 0.15), (Cu, 1), (O, '4-y')]
#    [(Nd, '2-a'), (Ce, 'a'), (Cu, 1), (O, '4-y')]
# [(La, '0.5-x'), (Na, '0.5+x'), (Fe, 2), (As, 2)]
#    [(La, '0.5-x'), (Na, '0.5+x'), (Fe, 2), (As, 2)]
# [(Nb, 2), (B, 1), (N, 1)]
#    [(Nb, 2), (B, 1), (N, 1)]
# [(Mg, 1), (V, 2), (O, 4)]
#    [(Mg, 1), (V, 2), (O, 4)]
# [(Ba, 1), (Fe, 1.926), (Ni, 0.074), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Ni, 'a'), (As, 2)]
# [(Li, 1), (Fe, 1), (P, 1)]
#    [(Li, 1), (Fe, 1), (P, 1)]
# [(Fe, 1), (Se, 0.3), (Te, 0.7)]
#    [(Fe, 1), (Se, 'a'), (Te, '1-a')]
# [(Nd, 1), (Ba, 2), (Cu, 3), (O, 'x')]
#    [(Nd, 1), (Ba, 2), (Cu, 3), (O, 'x')]
# [(Ga, 0.947), (Mn, 0.053)]
#    [(Ga, '1-a'), (Mn, 'a')]
# [(Ni, 0.33), (Ta, 2), (S, 2), (C, 1)]
#    [(Ni, 'a'), (Ta, 2), (S, 2), (C, 1)]
# [(Ti, 1), (N, 1), (Cl, 1)]
#    [(Ti, 1), (N, 1), (Cl, 1)]
# [([(Li, 0.8), (Fe, 0.2), (O, 1), (H, 1)], 1), (Fe, 1), (Se, 1)]
#    [(Li, '1-a'), (Fe, 'a'), (O, 1), (H, 1), (Fe, 1), (Se, 1)]
# [(La, 1), (O, 1), (Cu, 1), (Bi, 1)]
#    [(La, 1), (O, 1), (Cu, 1), (Bi, 1)]
# [(Nb, 1), (Ru, 1), (B, 1)]
#    [(Nb, 1), (Ru, 1), (B, 1)]
# [(B, 1), (K, 1), (B, 1), (O, 25)]
#    [(B, 1), (K, 1), (B, 1), (O, 25)]
# [(La, 3), (Co, 4), (Sn, 12.35), (In, 0.65)]
#    [(La, 3), (Co, 4), (Sn, '13-a'), (In, 'a')]
# [(Fe, 1), (Cr, 2), (S, 4)]
#    [(Fe, 1), (Cr, 2), (S, 4)]
# [(Li, 2), (B, 2)]
#    [(Li, 2), (B, 2)]
# [(Ba, 1), (Mn, 2), (As, 2)]
#    [(Ba, 1), (Mn, 2), (As, 2)]
# [(Sm, 1), (Fe, 1), (As, 1), (O, '1-x'), (F, 'x')]
#    [(Sm, 1), (Fe, 1), (As, 1), (O, '1-x'), (F, 'x')]
# [(Ru, 1), (Sr, 2), ([(Gd, 1.3), (Ce, 0.7)], 1), (Cu, 2), (O, '10-δ')]
#    [(Ru, 1), (Sr, 2), (Gd, '2-a'), (Ce, 'a'), (Cu, 2), (O, '10-δ')]
# [(Li, 'x'), ([(C, 2), (H, 8), (N, 2)], 'y'), (Mo, 1), (Se, 2)]
#    [(Li, 'x'), ([(C, 2), (H, 8), (N, 2)], 'y'), (Mo, 1), (Se, 2)]
# [(Sn, 1), (H, 14)]
#    [(Sn, 1), (H, 14)]
# [(Ba, '1-x'), (K, 1), (Fe, 2), (As, 2)]
#    [(Ba, '1-x'), (K, 1), (Fe, 2), (As, 2)]
# [(Fe, 1), (Se, 0.85)]
#    [(Fe, 1), (Se, '1-a')]
# [(Nd, 1), (Fe, 1), (As, 1), (O, 0.7), (F, 0.3)]
#    [(Nd, 1), (Fe, 1), (As, 1), (O, '1-a'), (F, 'a')]
# [(La, 0.85), (Sr, 0.15), (Fe, 1), (As, 1), (O, 1)]
#    [(La, '1-a'), (Sr, 'a'), (Fe, 1), (As, 1), (O, 1)]
# [([(La, 1), (Nd, 1), (Sr, 1), (Ba, 1)], 2), (Cu, 1), (O, 4)]
#    [([(La, 1), (Nd, 1), (Sr, 1), (Ba, 1)], 2), (Cu, 1), (O, 4)]
# [(Cd, 3), (As, 2)]
#    [(Cd, 3), (As, 2)]
# [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, 10)]
#    [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, 10)]
# [(Ba, 1), (Fe, 1.92), (Co, 0.08), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Co, 'a'), (As, 2)]
# [(K, 1), (F, 1), (S, 1), (I, 1)]
#    [(K, 1), (F, 1), (S, 1), (I, 1)]
# [(Y, 7), (Ba, 11), (Cu, 18), (O, 7)]
#    [(Y, 7), (Ba, 11), (Cu, 18), (O, 7)]
# [(La, 1), (O, '1-x'), (F, 'x'), (Fe, 1), (As, 2)]
#    [(La, 1), (O, '1-x'), (F, 'x'), (Fe, 1), (As, 2)]
# [(Bi, 1), (Se, 2)]
#    [(Bi, 1), (Se, 2)]
# [(Al, 6), (Re, 1)]
#    [(Al, 6), (Re, 1)]
# [(Nd, 1), (O, 1), (Bi, 1), (S, 2)]
#    [(Nd, 1), (O, 1), (Bi, 1), (S, 2)]
# [(Mg, 12), (Ir, 19), (B, 19)]
#    [(Mg, 12), (Ir, 19), (B, 19)]
# [(Tl, '2-x'), (Mo, 6), (Se, 6)]
#    [(Tl, '2-x'), (Mo, 6), (Se, 6)]
# [(Y, 1), (Ba, 1), (Cu, 1), (O, 6.6)]
#    [(Y, 1), (Ba, 1), (Cu, 1), (O, '7-a')]
# [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, '10-x')]
#    [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, '10-x')]
# [(Re, 0.56), (Nb, 0.11), (Ti, 0.11), (Zr, 0.11), (Hf, 0.11)]
#    [(Re, '1-a'), (Nb, 'b'), (Ti, 'c'), (Zr, 'd'), (Hf, 'e')]
# [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, '7-δ')]
#    [(Hg, 1), (Ba, 2), (Ca, 2), (Cu, 3), (O, '7-δ')]
# [([(Y, 0.95), (Ca, 0.05)], 1), (Ba, 2), (Cu, 3), (O, '7-δ')]
#    [(Y, '1-a'), (Ca, 'a'), (Ba, 2), (Cu, 3), (O, '7-δ')]
# [(Bi, 35), (Pb, 65)]
#    [(Bi, 35), (Pb, 65)]
# [(Hf, 70), (Cu, 30)]
#    [(Hf, 70), (Cu, 30)]
# [(Mo, 3), (Al, 2), (C, 1)]
#    [(Mo, 3), (Al, 2), (C, 1)]
# [(Hg, 1), (Ba, 2), (Ca, 3), (Cu, 4), (O, 12)]
#    [(Hg, 1), (Ba, 2), (Ca, 3), (Cu, 4), (O, 12)]
# [(Ba, 2), (Ca, 1), (Cu, 2), (O, 4), (F, 2)]
#    [(Ba, 2), (Ca, 1), (Cu, 2), (O, 4), (F, 2)]
# [(K, 'x'), (Os, 2), (O, 6)]
#    [(K, 'x'), (Os, 2), (O, 6)]
# [(Y, 0.95), (Ca, 0.05), (Ba, 2), ([(Cu, 0.98), (Zn, 0.02)], 3), (O, '7-δ')]
#    [(Y, '1-a'), (Ca, 'a'), (Ba, 2), ([(Cu, '1-a'), (Zn, 'a')], 3), (O, '7-δ')]
# [(Be, 1), (Au, 1)]
#    [(Be, 1), (Au, 1)]
# [(Sm, 1), (Fe, '1-x'), (Zn, 'x'), (As, 1), (O, 0.9), (F, 0.1)]
#    [(Sm, 1), (Fe, '1-x'), (Zn, 'x'), (As, 1), (O, '1-a'), (F, 'a')]
# [(Sr, 1), (Ni, 2), (P, 2)]
#    [(Sr, 1), (Ni, 2), (P, 2)]
# [(La, 1), (Fe, '1-x'), (Ni, 'x'), (As, 1), (O, 1)]
#    [(La, 1), (Fe, '1-x'), (Ni, 'x'), (As, 1), (O, 1)]
# [(Fe, 1), (Se, 'x'), (Te, 'y')]
#    [(Fe, 1), (Se, 'x'), (Te, 'y')]
# [(Ba, 2), (Cu, 1), (O, 3.2)]
#    [(Ba, 2), (Cu, 1), (O, '4-a')]
# [(Sr, 0.9), (Gd, 0.1), (Cu, 1), (O, 2)]
#    [(Sr, '1-a'), (Gd, 'a'), (Cu, 1), (O, 2)]
# [(Cu, 0.6), (Ta, 2), (S, 2), (C, 1)]
#    [(Cu, '1-a'), (Ta, 2), (S, 2), (C, 1)]
# [(Pr, 0.3), (Y, 0.7), (Ba, 2), (Cu, 3), (O, 6.95)]
#    [(Pr, 'a'), (Y, '1-a'), (Ba, 2), (Cu, 3), (O, '7-b')]
# [(O, 2)]
#    [(O, 2)]
# [(Ca, '1-x'), ([(K, 1), (Na, 1)], 'x'), (Fe, 2), (As, 2)]
#    [(Ca, '1-x'), ([(K, 1), (Na, 1)], 'x'), (Fe, 2), (As, 2)]
# [(La, 1), (Fe, 1), (As, 1)]
#    [(La, 1), (Fe, 1), (As, 1)]
# [(Y, 1), (Pd, 2), (Sn, 1)]
#    [(Y, 1), (Pd, 2), (Sn, 1)]
# [(K, '1-x'), (Sm, 'x'), (Fe, 2), (As, 2)]
#    [(K, '1-x'), (Sm, 'x'), (Fe, 2), (As, 2)]
# [(Fe, '1+x'), (Se, 0.6), (Te, 0.4)]
#    [(Fe, '1+x'), (Se, '1-a'), (Te, 'a')]
# [(La, 1), (Fe, 1), (As, 1), (O, '1-δ')]
#    [(La, 1), (Fe, 1), (As, 1), (O, '1-δ')]
# [(Mg, 1), (B, 2), (C, 2)]
#    [(Mg, 1), (B, 2), (C, 2)]
# [(O, 1), (H, 1), (Fe, 1), (Se, 23)]
#    [(O, 1), (H, 1), (Fe, 1), (Se, 23)]
# [(In, 1), (As, 1), (Ga, 1), (Sb, 1)]
#    [(In, 1), (As, 1), (Ga, 1), (Sb, 1)]
# [(Pr, 2), (Cu, 1), (O, 4)]
#    [(Pr, 2), (Cu, 1), (O, 4)]
# [(K, 'x'), (Co, 1), (O, 2)]
#    [(K, 'x'), (Co, 1), (O, 2)]
# [(Ba, 0.46), (K, 0.54), (Fe, 2), (As, 2)]
#    [(Ba, 'a'), (K, '1-a'), (Fe, 2), (As, 2)]
# [(Ta, 1)]
#    [(Ta, 1)]
# [(Y, 2), (C, 2), (I, 2)]
#    [(Y, 2), (C, 2), (I, 2)]
# [(Al, 1), (B, 6)]
#    [(Al, 1), (B, 6)]
# [(La, 3), (Ni, 4), (O, 2), (P, 4)]
#    [(La, 3), (Ni, 4), (O, 2), (P, 4)]
# [(Ba, 2), (Ca, 3), (Cu, 4), (O, 8), (F, 2)]
#    [(Ba, 2), (Ca, 3), (Cu, 4), (O, 8), (F, 2)]
# [(Ba, 1), (Fe, 1.82), (Ni, 0.18), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Ni, 'a'), (As, 2)]
# [(Tl, 'x'), (Fe, 2), (Se, 2)]
#    [(Tl, 'x'), (Fe, 2), (Se, 2)]
# [(Fe, 1), (Te, 0.51), (Se, 0.49)]
#    [(Fe, 1), (Te, '1-a'), (Se, 'a')]
# [(Lu, 1), (Ga, 3)]
#    [(Lu, 1), (Ga, 3)]
# [(C, 1), (S, 1), (Re, 3), (W, 1)]
#    [(C, 1), (S, 1), (Re, 3), (W, 1)]
# [(H, 7.2)]
#    [(H, '8-a')]
# [(Ba, 2), (Ca, 4), (Cu, 5), (O, 10), ([(F, 1), (O, 1)], 2)]
#    [(Ba, 2), (Ca, 4), (Cu, 5), (O, 10), ([(F, 1), (O, 1)], 2)]
# [(Sr, 4), (Sc, 2), (O, 6), (Fe, 2), (P, 2)]
#    [(Sr, 4), (Sc, 2), (O, 6), (Fe, 2), (P, 2)]
# [(Sr, 1), (Fe, 1), (As, 1), (F, 1)]
#    [(Sr, 1), (Fe, 1), (As, 1), (F, 1)]
# [(Nb, 'x'), (B, 2)]
#    [(Nb, 'x'), (B, 2)]
# [(Rb, 'x'), (Fe, '2-y'), (Se, 2)]
#    [(Rb, 'x'), (Fe, '2-y'), (Se, 2)]
# [(C, 14), (H, 10)]
#    [(C, 14), (H, 10)]
# [(Rb, 1), (Ge, 2)]
#    [(Rb, 1), (Ge, 2)]
# [(Ir, '1-y'), (Pd, 'y'), (Te, 2)]
#    [(Ir, '1-y'), (Pd, 'y'), (Te, 2)]
# [(Cu, 1), (Rh, 2), (S, 4)]
#    [(Cu, 1), (Rh, 2), (S, 4)]
# [(Y, 1), (Ti, 1), (O, 3)]
#    [(Y, 1), (Ti, 1), (O, 3)]
# [(Li, 1), (Fe, 0.95), (Co, 0.05), (As, 1)]
#    [(Li, 1), (Fe, '1-a'), (Co, 'a'), (As, 1)]
# [([(Fe, 2), (P, 2)], 1), ([(Sr, 4), (Sc, 2), (O, 6)], 10)]
#    [(Fe, 2), (P, 2), ([(Sr, 4), (Sc, 2), (O, 6)], 10)]
# [(H, 3), (Se, 1)]
#    [(H, 3), (Se, 1)]
# [(Eu, 1), (P, 1)]
#    [(Eu, 1), (P, 1)]
# [(Li, 0.2), (Sn, 1), (Se, 2)]
#    [(Li, 'a'), (Sn, 1), (Se, 2)]
# [(Nd, 1), (O, 0.9), (F, 0.1), (Fe, 1), (As, 1)]
#    [(Nd, 1), (O, '1-a'), (F, 'a'), (Fe, 1), (As, 1)]
# [(C, 30), (H, 18)]
#    [(C, 30), (H, 18)]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.93)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(La, 2), (Cu, 1), (O, '4+x')]
#    [(La, 2), (Cu, 1), (O, '4+x')]
# [(Yb, 0.2), ([(N, 1), (H, 3)], 'y'), (Hf, 1), (N, 1), (Cl, 1)]
#    [(Yb, 'a'), ([(N, 1), (H, 3)], 'y'), (Hf, 1), (N, 1), (Cl, 1)]
# [(S, 'ample'), (B, 2)]
#    [(S, 'ample'), (B, 2)]
# [(Ba, 1), ([(Fe, '1-x'), (Ru, 'x')], 2), (As, 2)]
#    [(Ba, 1), ([(Fe, '1-x'), (Ru, 'x')], 2), (As, 2)]
# [(Ba, 1), (Fe, 1.87), (Co, 0.13), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Co, 'a'), (As, 2)]
# [(Nb, 2), (Sn, 1), (C, 1)]
#    [(Nb, 2), (Sn, 1), (C, 1)]
# [(Li, 1), ([(Zn, 1), (Mn, 1)], 1), (P, 1)]
#    [(Li, 1), (Zn, 1), (Mn, 1), (P, 1)]
# [(La, 1), (Ni, 1), (Bi, 1), (O, 1)]
#    [(La, 1), (Ni, 1), (Bi, 1), (O, 1)]
# [(Nb, 2), (Pd, 0.81), (Se, 5)]
#    [(Nb, 2), (Pd, '1-a'), (Se, 5)]
# [(La, 1), (Ni, 1), (B, 1), (N, 1)]
#    [(La, 1), (Ni, 1), (B, 1), (N, 1)]
# [(Nb, 2), (Pd, 1), (S, 5)]
#    [(Nb, 2), (Pd, 1), (S, 5)]
# [(Bi, 2.2), (Sr, 1.8), (Cu, 1), (O, 'y')]
#    [(Bi, '3-a'), (Sr, '1+a'), (Cu, 1), (O, 'y')]
# [(La, 1.85), (Ba, 0.15), (Cu, 1), (O, 4)]
#    [(La, '2-a'), (Ba, 'a'), (Cu, 1), (O, 4)]
# [(Lu, '1-x'), (Zr, 'x'), (B, 12)]
#    [(Lu, '1-x'), (Zr, 'x'), (B, 12)]
# [(Sm, 1), (O, 0.9), (F, 0.1), (F, 'e'), (As, 1)]
#    [(Sm, 1), (O, '1-a'), (F, 'a'), (F, 'e'), (As, 1)]
# [(Sr, 0.8), (La, 0.2), (Fe, 1), (As, 1), (F, 1)]
#    [(Sr, '1-a'), (La, 'a'), (Fe, 1), (As, 1), (F, 1)]
# [(Mg, 1), (B, '2-x'), (C, 'x')]
#    [(Mg, 1), (B, '2-x'), (C, 'x')]
# [(Ba, 1), (Fe, 1), (Co, 1), (As, 1)]
#    [(Ba, 1), (Fe, 1), (Co, 1), (As, 1)]
# [(Rh, 1)]
#    [(Rh, 1)]
# [(Na, 1), (Fe, 0.925), (Co, 0.075)]
#    [(Na, 1), (Fe, '1-a'), (Co, 'a')]
# [(Ba, 1), (Fe, '2-x'), (Ni, 'x'), (As, 2)]
#    [(Ba, 1), (Fe, '2-x'), (Ni, 'x'), (As, 2)]
# [(K, 'x'), (Fe, 'y'), (Se, 2)]
#    [(K, 'x'), (Fe, 'y'), (Se, 2)]
# [(Pt, 1), (Si, 1)]
#    [(Pt, 1), (Si, 1)]
# [(Eu, 2), (Cu, 1), (O, 4)]
#    [(Eu, 2), (Cu, 1), (O, 4)]
# [(Fe, 1), (Se, 1), (Te, 1)]
#    [(Fe, 1), (Se, 1), (Te, 1)]
# [(Pr, 1), (Fe, 1), (As, 1), (O, 0.7)]
#    [(Pr, 1), (Fe, 1), (As, 1), (O, '1-a')]
# [(Ru, 1), (Sr, 2), (Sm, 1), (Cu, 2), (O, 8)]
#    [(Ru, 1), (Sr, 2), (Sm, 1), (Cu, 2), (O, 8)]
# [(Eu, 1), ([(Fe, 0.91), (Ir, 0.09)], 2), (As, 2)]
#    [(Eu, 1), ([(Fe, '1-a'), (Ir, 'a')], 2), (As, 2)]
# [(Sr, 0.9), (Cu, 1), (O, 2)]
#    [(Sr, '1-a'), (Cu, 1), (O, 2)]
# [(Au, 1), (In, 2)]
#    [(Au, 1), (In, 2)]
# [(Sm, 0.8), (Th, 0.2), (Fe, 1), (As, 1), (O, 0.775), (F, 0.225)]
#    [(Sm, '1-a'), (Th, 'a'), (Fe, 1), (As, 1), (O, '1-b'), (F, 'b')]
# [(La, 1), (Bi, 1)]
#    [(La, 1), (Bi, 1)]
# [(Y, 1), (Ba, 2), (Cu, 2), (O, 7)]
#    [(Y, 1), (Ba, 2), (Cu, 2), (O, 7)]
# [(Er, 2), (Ti, 2), (O, 7)]
#    [(Er, 2), (Ti, 2), (O, 7)]
# [([(Cs, '1-x'), (Sr, 'x')], 1), (Fe, 2), (As, 2)]
#    [(Cs, '1-x'), (Sr, 'x'), (Fe, 2), (As, 2)]
# [(Fe, 1), ([(Te, 0.9), (S, 0.1)], 0.9)]
#    [(Fe, 1), ([(Te, '1-a'), (S, 'a')], '1-a')]
# [(Pd, 1), (Te, 2)]
#    [(Pd, 1), (Te, 2)]
# [(La, '1-x'), (Hf, 'x'), (O, 1), (Bi, 1), (S, 2)]
#    [(La, '1-x'), (Hf, 'x'), (O, 1), (Bi, 1), (S, 2)]
# [(Gd, 1), (Ba, 2), (Cu, 3), (O, '7-x')]
#    [(Gd, 1), (Ba, 2), (Cu, 3), (O, '7-x')]
# [(Y, 1), (Rh, 3), (B, 1)]
#    [(Y, 1), (Rh, 3), (B, 1)]
# [(Ni, 2)]
#    [(Ni, 2)]
# [(La, 1), (Ru, 2), (P, 2)]
#    [(La, 1), (Ru, 2), (P, 2)]
# [(K, 1), (Ta, 1), (O, 3)]
#    [(K, 1), (Ta, 1), (O, 3)]
# [(Sn, 0.13), (Nb, 1), (Se, 1.7)]
#    [(Sn, 'a'), (Nb, 1), (Se, '2-b')]
# [(La, 1), (Fe, 1), (As, 0.4), (P, 0.6), (O, 0.95), (F, 0.05)]
#    [(La, 1), (Fe, 1), (As, 'a'), (P, '1-a'), (O, '1-b'), (F, 'b')]
# [(Fe, 1), (Se, 0.7), (Te, 0.3)]
#    [(Fe, 1), (Se, '1-a'), (Te, 'a')]
# [(Mg, 1), (B, 2), (C, 1)]
#    [(Mg, 1), (B, 2), (C, 1)]
# [(Fe, '1+y'), (Te, 'x'), (Se, '1-x')]
#    [(Fe, '1+y'), (Te, 'x'), (Se, '1-x')]
# [(Cs, 'x'), (Fe, 'y'), (Se, 2)]
#    [(Cs, 'x'), (Fe, 'y'), (Se, 2)]
# [(Cu, 0.2), (Bi, 2), (Se, 3)]
#    [(Cu, 'a'), (Bi, 2), (Se, 3)]
# [(Sr, '1-x'), (Sm, 'x'), (Fe, 1), (As, 1), (F, 1)]
#    [(Sr, '1-x'), (Sm, 'x'), (Fe, 1), (As, 1), (F, 1)]
# [([(Bi, '1-y'), (Pb, 'y')], 2), (Sr, 2), (Cu, 1), (O, '6+x')]
#    [([(Bi, '1-y'), (Pb, 'y')], 2), (Sr, 2), (Cu, 1), (O, '6+x')]
# [(Ca, 2), (Ru, 1), (O, 4)]
#    [(Ca, 2), (Ru, 1), (O, 4)]
# [(Sm, 1.25)]
#    [(Sm, '2-a')]
# [([(Sr, 0.5), (Na, 0.5)], 1), (Fe, 2), (As, 2)]
#    [(Sr, 'a'), (Na, '1-a'), (Fe, 2), (As, 2)]
# [(Nb, 35), (Ti, 60), (Zr, 5)]
#    [(Nb, 35), (Ti, 60), (Zr, 5)]
# [(Tb, '1-x'), (Th, 'x'), (Fe, 1), (As, 1), (O, 1)]
#    [(Tb, '1-x'), (Th, 'x'), (Fe, 1), (As, 1), (O, 1)]
# [(V, 1)]
#    [(V, 1)]
# [(K, 'x'), (F, 'e2'), (Se, 2)]
#    [(K, 'x'), (F, 'e2'), (Se, 2)]
# [(Tl, 1), (Fe, 3), (Te, 3)]
#    [(Tl, 1), (Fe, 3), (Te, 3)]
# [(Ba, 1), (K, 0.76)]
#    [(Ba, 1), (K, '1-a')]
# [(Ba, 1), (Pb, '1-x'), (Bi, 'x'), (O, 3)]
#    [(Ba, 1), (Pb, '1-x'), (Bi, 'x'), (O, 3)]
# [(Fe, 1.03), (Se, 0.57), (Te, 0.43)]
#    [(Fe, '2-b'), (Se, '1-a'), (Te, 'a')]
# [(Cs, 2), (Rb, 1), (C, 60)]
#    [(Cs, 2), (Rb, 1), (C, 60)]
# [(Sc, 1), (In, 3)]
#    [(Sc, 1), (In, 3)]
# [(Ti, 2), (C, 1), (H, 2)]
#    [(Ti, 2), (C, 1), (H, 2)]
# [(Ce, 0.95), (Nd, 0.05), (Co, 1), (In, 5)]
#    [(Ce, '1-a'), (Nd, 'a'), (Co, 1), (In, 5)]
# [(K, 1), (Fe, 3), ([(S, 1), (O, 4)], 2)]
#    [(K, 1), (Fe, 3), ([(S, 1), (O, 4)], 2)]
# [(Tl, '1-x'), (Fe, '2-y'), (Se, 2)]
#    [(Tl, '1-x'), (Fe, '2-y'), (Se, 2)]
# [(Y, 1), (B, 1), (Co, 1), (C, 1), (O, 1)]
#    [(Y, 1), (B, 1), (Co, 1), (C, 1), (O, 1)]
# [(K, 3), (Ba, 3), (C, 60)]
#    [(K, 3), (Ba, 3), (C, 60)]
# [(K, 1), (H, 0.65), (Cr, 3), (As, 3)]
#    [(K, 1), (H, '1-a'), (Cr, 3), (As, 3)]
# [(Li, 1), ([(Fe, '1-x'), (Cu, 'x')], 1), (As, 1)]
#    [(Li, 1), (Fe, '1-x'), (Cu, 'x'), (As, 1)]
# [(Nd, 1), ([(O, 1), (F, 1)], 1), (Bi, 1), (S, 2)]
#    [(Nd, 1), (O, 1), (F, 1), (Bi, 1), (S, 2)]
# [(Bi, 2), (Sr, 2), ([(Ca, 1), (Dy, 1)], 1), (Cu, 2), (O, '8+δ')]
#    [(Bi, 2), (Sr, 2), (Ca, 1), (Dy, 1), (Cu, 2), (O, '8+δ')]
# [([(Ba, 'x'), (Li, '1-x')], 1), (Fe, 2), (As, 2)]
#    [(Ba, 'x'), (Li, '1-x'), (Fe, 2), (As, 2)]
# [(Pd, 'x-'), (Bi, 2), (Te, 3)]
#    [(Pd, 'x-'), (Bi, 2), (Te, 3)]
# [(La, 1), (O, '1-x'), (F, 'x')]
#    [(La, 1), (O, '1-x'), (F, 'x')]
# [([(Ca, 0.33), (Na, 0.66)], 1), (Fe, 2), (As, 2)]
#    [(Ca, 'a'), (Na, '1-b'), (Fe, 2), (As, 2)]
# [(Sr, 3), (Rh, 8), (B, 6)]
#    [(Sr, 3), (Rh, 8), (B, 6)]
# [(Ba, 1), (Pt, 4), (Ge, 12)]
#    [(Ba, 1), (Pt, 4), (Ge, 12)]
# [(Sr, 1), (F, 1), (Fe, 1), (As, 1)]
#    [(Sr, 1), (F, 1), (Fe, 1), (As, 1)]
# [(La, 1), (Bi, 1), (S, 2), (O, 0.5), (F, 0.5)]
#    [(La, 1), (Bi, 1), (S, 2), (O, 'a'), (F, '1-a')]
# [(Lu, 1), (B, 12)]
#    [(Lu, 1), (B, 12)]
# [(Xe, 1), (F, 2)]
#    [(Xe, 1), (F, 2)]
# [(K, 2), (Fe, 4), (Se, 5)]
#    [(K, 2), (Fe, 4), (Se, 5)]
# [(Mg, 1), (Al, 1), (B, 4)]
#    [(Mg, 1), (Al, 1), (B, 4)]
# [(Pr, '2-x'), (Ce, 'x'), (Cu, 1), (O, '4-δ')]
#    [(Pr, '2-x'), (Ce, 'x'), (Cu, 1), (O, '4-δ')]
# [(Mg, 0.97), (La, 0.03), (B, 2)]
#    [(Mg, '1-a'), (La, 'a'), (B, 2)]
# [(Li, 0.2), ([(P, 1), (C, 1)], 'y'), (Sn, 1), (Se, 2)]
#    [(Li, 'a'), ([(P, 1), (C, 1)], 'y'), (Sn, 1), (Se, 2)]
# [(W, 7), (Re, 13), (B, 1)]
#    [(W, 7), (Re, 13), (B, 1)]
# [(Fe, 1), (Se, 0.35), (Te, 0.65)]
#    [(Fe, 1), (Se, 'a'), (Te, '1-a')]
# [(Fe, 1.02), (Te, 0.55), (Se, 0.45)]
#    [(Fe, '2-b'), (Te, '1-a'), (Se, 'a')]
# [(Tl, 1), (Fe, 1.7), (Se, 2)]
#    [(Tl, 1), (Fe, '2-a'), (Se, 2)]
# [(Y, 1), (Ba, 23), (O, '6+y')]
#    [(Y, 1), (Ba, 23), (O, '6+y')]
# [(Re, 24), (Ti, 5)]
#    [(Re, 24), (Ti, 5)]
# [(Ce, 1), (O, 1), (Fe, 1), (As, 1)]
#    [(Ce, 1), (O, 1), (Fe, 1), (As, 1)]
# [(Li, 'x'), ([(N, 1), (H, 2)], 'y'), ([(N, 1), (H, 3)], '1-y'), (Fe, 2), (Se, 2)]
#    [(Li, 'x'), ([(N, 1), (H, 2)], 'y'), ([(N, 1), (H, 3)], '1-y'), (Fe, 2), (Se, 2)]
# [(Ta, 2), (Pd, 0.97), (Te, 6)]
#    [(Ta, 2), (Pd, '1-a'), (Te, 6)]
# [(La, 1.83), (Sr, 0.17)]
#    [(La, '2-a'), (Sr, 'a')]
# [(La, 1), (Bi, 3)]
#    [(La, 1), (Bi, 3)]
# [(Al, 2), (Mg, 1), (B, 6)]
#    [(Al, 2), (Mg, 1), (B, 6)]
# [(V, 1), (B, 2)]
#    [(V, 1), (B, 2)]
# [(Sr, 2), (Y, 1), (Ru, 1), (O, 6)]
#    [(Sr, 2), (Y, 1), (Ru, 1), (O, 6)]
# [(Rb, 1), (V, 3), (Sb, 5)]
#    [(Rb, 1), (V, 3), (Sb, 5)]
# [(La, '1-x'), (Sr, 'x'), (Co, 1), (O, 3)]
#    [(La, '1-x'), (Sr, 'x'), (Co, 1), (O, 3)]
# [([(Y, 0.14), (Tm, 0.85)], 1), (Ba, 2), (Cu, 3), (O, 7)]
#    [(Y, 'a'), (Tm, '1-b'), (Ba, 2), (Cu, 3), (O, 7)]
# [(Ti, 4), (Co, 2), (O, 1)]
#    [(Ti, 4), (Co, 2), (O, 1)]
# [(Cs, 1), (Pb, 'x'), (Bi, '4-x'), (Te, 6)]
#    [(Cs, 1), (Pb, 'x'), (Bi, '4-x'), (Te, 6)]
# [(La, 1), (Mn, 1), (O, 3.04)]
#    [(La, 1), (Mn, 1), (O, '4-a')]
# [(Ca, 10), ([(Pt, '4-δ'), (As, 8)], 1), ([([(Fe, 0.97), (Pt, 0.03)], 2), (As, 2)], 5)]
#    [(Ca, 10), (Pt, '4-δ'), (As, 8), ([([(Fe, '1-a'), (Pt, 'a')], 2), (As, 2)], 5)]
# [(Ba, 1), ([(Fe, 0.925), (Co, 0.075)], 2), (As, 2)]
#    [(Ba, 1), ([(Fe, '1-a'), (Co, 'a')], 2), (As, 2)]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.94)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(La, 1), (Fe, 1), (O, 0.89), (F, 0.11)]
#    [(La, 1), (Fe, 1), (O, '1-a'), (F, 'a')]
# [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Cu, 1), (O, '6+δ')]
#    [([(Bi, 1), (Pb, 1)], 2), (Sr, 2), (Cu, 1), (O, '6+δ')]
# [(Nd, 1), (Ba, 2), (Cu, 3), (O, 6.96)]
#    [(Nd, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(Nb, 2), ([(Pd, '1-x'), (Ir, 'x')], 0.76), (S, 5)]
#    [(Nb, 2), ([(Pd, '1-x'), (Ir, 'x')], '1-a'), (S, 5)]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.61)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(Sr, 4), (B, 8)]
#    [(Sr, 4), (B, 8)]
# [(Sr, 2), (Mg, 0.2), (Ti, 0.8), (O, 3), (Fe, 1), (As, 1)]
#    [(Sr, 2), (Mg, 'a'), (Ti, '1-a'), (O, 3), (Fe, 1), (As, 1)]
# [(La, 1), (O, 1), (Fe, 1), (As, 0.9), (F, 0.1)]
#    [(La, 1), (O, 1), (Fe, 1), (As, '1-a'), (F, 'a')]
# [(Fe, 1), ([(Te, '1-x'), (S, 'x')], 0.9)]
#    [(Fe, 1), ([(Te, '1-x'), (S, 'x')], '1-a')]
# [(K, 1), (Fe, 2), (As, 2)]
#    [(K, 1), (Fe, 2), (As, 2)]
# [(La, 2), (C, '3-δ')]
#    [(La, 2), (C, '3-δ')]
# [(Si, 5)]
#    [(Si, 5)]
# [(La, 1), (Pd, 2), (P, 2)]
#    [(La, 1), (Pd, 2), (P, 2)]
# [(H, 1), (I, 1), (P, 'ed')]
#    [(H, 1), (I, 1), (P, 'ed')]
# [(In, '1-x'), (Mn, 'x'), (Sb, 1)]
#    [(In, '1-x'), (Mn, 'x'), (Sb, 1)]
# [(Sm, 1), (O, '1-x'), (F, 'x'), (F, 'e'), (As, 1)]
#    [(Sm, 1), (O, '1-x'), (F, 'x'), (F, 'e'), (As, 1)]
# [(In, 1), (Bi, 1)]
#    [(In, 1), (Bi, 1)]
# [(La, 1), (O, 0.9), (F, 0.1), (Ni, 1), (As, 1)]
#    [(La, 1), (O, '1-a'), (F, 'a'), (Ni, 1), (As, 1)]
# [(Sm, 1), ([(O, 1), (F, 1)], 1), (Bi, 1), (S, 2)]
#    [(Sm, 1), (O, 1), (F, 1), (Bi, 1), (S, 2)]
# [(Ba, 1), (Fe, 1.8), (Co, 0.2), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Co, 'a'), (As, 2)]
# [(Np, 1), (Co, 1), (Ga, 5)]
#    [(Np, 1), (Co, 1), (Ga, 5)]
# [(La, 1), (Sb, 2)]
#    [(La, 1), (Sb, 2)]
# [(Na, 0.42), (Co, 1), (O, 2)]
#    [(Na, 'a'), (Co, 1), (O, 2)]
# [(Y, 1), (Pt, 1), (Bi, 1)]
#    [(Y, 1), (Pt, 1), (Bi, 1)]
# [(La, 0.05), (Fe, 1), (As, 1), (O, 'y')]
#    [(La, 'a'), (Fe, 1), (As, 1), (O, 'y')]
# [(La, 1), (O, 0.9), (F, 0.2), (Fe, 1), (As, 1)]
#    [(La, 1), (O, '1-a'), (F, 'b'), (Fe, 1), (As, 1)]
# [(Na, 0.5), (Co, 1), (O, 2)]
#    [(Na, 'a'), (Co, 1), (O, 2)]
# [(La, 1), (Pd, 1), (In, 1)]
#    [(La, 1), (Pd, 1), (In, 1)]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.5)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(Zr, 30), (Cu, 70)]
#    [(Zr, 30), (Cu, 70)]
# ...
#    [(La, 1), (Ag, '1-a'), (Mn, 'a')]
# [(Sm, 1), (Fe, 1), (As, 1), (O, 1)]
#    [(Sm, 1), (Fe, 1), (As, 1), (O, 1)]
# [(La, 1), (Fe, 1), (P, 1), (O, 0.94), (F, 0.06)]
#    [(La, 1), (Fe, 1), (P, 1), (O, '1-a'), (F, 'a')]
# [(Na, 1), (V, 1), (O, 3)]
#    [(Na, 1), (V, 1), (O, 3)]
# [(Gd, 1), (Fe, 1), (As, 1), (O, 0.6)]
#    [(Gd, 1), (Fe, 1), (As, 1), (O, '1-a')]
# [([(Tl, 1), (Cs, 1)], 'x'), (Fe, '2-y'), (Se, 2)]
#    [([(Tl, 1), (Cs, 1)], 'x'), (Fe, '2-y'), (Se, 2)]
# [(Tl, 0.5), (K, 0.3), (Fe, 1.6), (Se, 2)]
#    [(Tl, 'a'), (K, 'b'), (Fe, '2-c'), (Se, 2)]
# [(Mo, 1), (Re, 1)]
#    [(Mo, 1), (Re, 1)]
# [(Ba, 1), ([(Fe, '1-x'), (Mn, 'x')], 2), (As, 2)]
#    [(Ba, 1), ([(Fe, '1-x'), (Mn, 'x')], 2), (As, 2)]
# [(La, 3), (Co, 4), (Sn, 13)]
#    [(La, 3), (Co, 4), (Sn, 13)]
# [(Li, 'x'), ([(C, 18), (H, 39), (N, 1)], 'y'), (Fe, '1-z'), (Se, 1)]
#    [(Li, 'x'), ([(C, 18), (H, 39), (N, 1)], 'y'), (Fe, '1-z'), (Se, 1)]
# [(Y, '1-x'), (Ca, 'x'), (Ba, 2), (Cu, 3), (O, 6)]
#    [(Y, '1-x'), (Ca, 'x'), (Ba, 2), (Cu, 3), (O, 6)]
# [(K, 8), (C, 1)]
#    [(K, 8), (C, 1)]
# [(Pr, 0.105), (Ca, 0.895), (Fe, 2), (As, 2)]
#    [(Pr, 'a'), (Ca, '1-a'), (Fe, 2), (As, 2)]
# [(Nd, '2-x-y'), (Ce, 'x'), (Sr, 'y'), (Cu, 1), (O, 4)]
#    [(Nd, '2-x-y'), (Ce, 'x'), (Sr, 'y'), (Cu, 1), (O, 4)]
# [(Sm, '1-x'), (La, 'x'), (O, '1-y'), (F, 'y'), (Fe, 1), (As, 1)]
#    [(Sm, '1-x'), (La, 'x'), (O, '1-y'), (F, 'y'), (Fe, 1), (As, 1)]
# [(Sr, 1), (Fe, '2-x'), (Ni, 'x'), (As, 2)]
#    [(Sr, 1), (Fe, '2-x'), (Ni, 'x'), (As, 2)]
# [(Li, 0.12), (Mo, 1), (S, 2)]
#    [(Li, 'a'), (Mo, 1), (S, 2)]
# [(Ag, 0.05), (Zr, 1), (Te, 3)]
#    [(Ag, 'a'), (Zr, 1), (Te, 3)]
# [(Nd, 1), (Fe, 1), (As, 1), (O, 0.88), (F, 0.12)]
#    [(Nd, 1), (Fe, 1), (As, 1), (O, '1-a'), (F, 'a')]
# [(Rb, 0.88), (Fe, 1.81), (Se, 2)]
#    [(Rb, '1-a'), (Fe, '2-b'), (Se, 2)]
# [(Bi, 1), (O, 1), (Cu, 1), (S, 1)]
#    [(Bi, 1), (O, 1), (Cu, 1), (S, 1)]
# [(Ga, 1), (Mn, 1), (Sb, 1)]
#    [(Ga, 1), (Mn, 1), (Sb, 1)]
# [(Fe, 1), (Te, 0.5), (Se, 0.5)]
#    [(Fe, 1), (Te, 'a'), (Se, '1-a')]
# [(Ca, 0.86), (Pr, 0.14), (Fe, 2), (As, 2)]
#    [(Ca, '1-a'), (Pr, 'a'), (Fe, 2), (As, 2)]
# [(In, 'x'), (Sn, '1-x'), (Te, 1)]
#    [(In, 'x'), (Sn, '1-x'), (Te, 1)]
# [(Ni, 1), (Nd, 1), (O, 2)]
#    [(Ni, 1), (Nd, 1), (O, 2)]
# [(Ta, 1), (N, 1)]
#    [(Ta, 1), (N, 1)]
# [(Sn, 0.6), (In, 0.4), (Te, 1)]
#    [(Sn, '1-a'), (In, 'a'), (Te, 1)]
# [(Ti, 1), (Au, 1)]
#    [(Ti, 1), (Au, 1)]
# [(Ca, 1), (Ba, 1), (Cu, 1), (O, 1)]
#    [(Ca, 1), (Ba, 1), (Cu, 1), (O, 1)]
# [(Pd, 1), (H, 1)]
#    [(Pd, 1), (H, 1)]
# [(Sm, 1), (Fe, '1-x'), (Ru, 'x'), (As, 1), (O, 0.85), (F, 0.15)]
#    [(Sm, 1), (Fe, '1-x'), (Ru, 'x'), (As, 1), (O, '1-a'), (F, 'a')]
# [([(La, 1), (Nd, 1), (Eu, 1)], 1.88), (Sr, 0.12), (Cu, 1), (O, 4)]
#    [([(La, 1), (Nd, 1), (Eu, 1)], '2-a'), (Sr, 'a'), (Cu, 1), (O, 4)]
# [(Nd, 0.2), (Sm, 0.8), (O, 0.7), (F, 0.3), (Bi, 1), (S, 2)]
#    [(Nd, 'a'), (Sm, '1-a'), (O, '1-b'), (F, 'b'), (Bi, 1), (S, 2)]
# [(Sr, 1), (Pd, 2), (Bi, 2)]
#    [(Sr, 1), (Pd, 2), (Bi, 2)]
# [(Fe, 'y'), (Se, '1-x'), (Te, 'x')]
#    [(Fe, 'y'), (Se, '1-x'), (Te, 'x')]
# [(Y, '1-b'), ([(Ca, 1)], 'b'), (Ba, 2), (Cu, 3), (O, '6+x')]
#    [(Y, '1-b'), ([(Ca, 1)], 'b'), (Ba, 2), (Cu, 3), (O, '6+x')]
# [([(Ca, 1), (La, 1)], 1), (Fe, 2), ([(As, 1), (P, 1)], 2)]
#    [(Ca, 1), (La, 1), (Fe, 2), ([(As, 1), (P, 1)], 2)]
# [(Bi, 2), (Sr, 2), (Dy, 0.2), (Ca, 0.8), (Cu, 2), (O, '8+δ')]
#    [(Bi, 2), (Sr, 2), (Dy, 'a'), (Ca, '1-a'), (Cu, 2), (O, '8+δ')]
# [(Ba, '1-x'), (K, 'x')]
#    [(Ba, '1-x'), (K, 'x')]
# [(K, 0.68), (Fe, 1.79), (Se, 2)]
#    [(K, '1-a'), (Fe, '2-b'), (Se, 2)]
# [(Sr, 1), (Au, 1), (Si, 3)]
#    [(Sr, 1), (Au, 1), (Si, 3)]
# [(Sm, 0.85), (Nd, 0.15), (Fe, 1), (As, 1), (O, 0.85), (F, 0.15)]
#    [(Sm, '1-a'), (Nd, 'a'), (Fe, 1), (As, 1), (O, '1-b'), (F, 'b')]
# [(Ba, 0.5), (Sr, 0.5), (Fe, 2), ([(As, '1-x'), (P, 'x')], 2)]
#    [(Ba, 'a'), (Sr, '1-a'), (Fe, 2), ([(As, '1-x'), (P, 'x')], 2)]
# [(Ce, 1), (Rh, 2), (As, 2)]
#    [(Ce, 1), (Rh, 2), (As, 2)]
# [(Nd, 1), (Fe, 1), (As, 1), (O, '1-x'), (F, 'x')]
#    [(Nd, 1), (Fe, 1), (As, 1), (O, '1-x'), (F, 'x')]
# [(Re, 23.8), (Nb, 5.2)]
#    [(Re, '24-a'), (Nb, '5+a')]
# [(C, 1), (N, 's')]
#    [(C, 1), (N, 's')]
# [(Ga, 1), (As, 1)]
#    [(Ga, 1), (As, 1)]
# [(Sm, 'x'), (C, 60)]
#    [(Sm, 'x'), (C, 60)]
# [(Mg, 2), (Rh, 3), (P, 1)]
#    [(Mg, 2), (Rh, 3), (P, 1)]
# [(Y, 1), (B, 5.9)]
#    [(Y, 1), (B, '6-a')]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.98)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(La, 1.9), (Sr, 0.1), (Cu, 1), (O, 4)]
#    [(La, '2-a'), (Sr, 'a'), (Cu, 1), (O, 4)]
# [(V, 3), (Si, 1), (Nb, 3), (S, 'n')]
#    [(V, 3), (Si, 1), (Nb, 3), (S, 'n')]
# [(Si, 1), (Cl, 4)]
#    [(Si, 1), (Cl, 4)]
# [(Pu, 1), (Co, 1), (Ga, 4), (Ge, 1)]
#    [(Pu, 1), (Co, 1), (Ga, 4), (Ge, 1)]
# [(Eu, 1), ([(Fe, '1-x'), (Ir, 'x')], 2), (As, 2)]
#    [(Eu, 1), ([(Fe, '1-x'), (Ir, 'x')], 2), (As, 2)]
# [(Cu, 1), (O, 2)]
#    [(Cu, 1), (O, 2)]
# [(La, 'x'), (Rh, 4), (P, 12)]
#    [(La, 'x'), (Rh, 4), (P, 12)]
# [(Pb, 0.5), (Bi, 1.55), (Sr, 1.2), (La, 0.8), (Cu, 1), (O, '6+δ')]
#    [(Pb, 'b'), (Bi, '2-b'), (Sr, '2-a'), (La, 'a'), (Cu, 1), (O, '6+δ')]
# [(Ca, 0.5), (Na, 0.5), (Fe, 2), (As, 2)]
#    [(Ca, 'a'), (Na, '1-a'), (Fe, 2), (As, 2)]
# [(H, 3), (S, 1)]
#    [(H, 3), (S, 1)]
# [(Sr, 1), (Fe, 1.84), (Pt, 0.16), (As, 2)]
#    [(Sr, 1), (Fe, '2-a'), (Pt, 'a'), (As, 2)]
# [(Rb, 1), (Sr, 1), (Fe, 4), (As, 4)]
#    [(Rb, 1), (Sr, 1), (Fe, 4), (As, 4)]
# [(Na, 'x'), (Fe, 1), (As, 1)]
#    [(Na, 'x'), (Fe, 1), (As, 1)]
# [(Bi, 2.1), (Sr, 1.9), (Ca, 0.9), (Cu, 2), (O, '8+δ')]
#    [(Bi, '3-a'), (Sr, '1+a'), (Ca, '1-b'), (Cu, 2), (O, '8+δ')]
# [(Nd, 3), (Ni, 2), (B, 2), (N, '3-δ')]
#    [(Nd, 3), (Ni, 2), (B, 2), (N, '3-δ')]
# [(K, 2), (Mo, 3), (As, 3)]
#    [(K, 2), (Mo, 3), (As, 3)]
# [(Eu, 1), ([(Gd, 1)], 1), (Sr, 2), (Ru, 1), (Cu, 2), (O, 8)]
#    [(Eu, 1), (Gd, 1), (Sr, 2), (Ru, 1), (Cu, 2), (O, 8)]
# [(In, 'x'), (Ta, 1), (S, 2)]
#    [(In, 'x'), (Ta, 1), (S, 2)]
# [(Ba, 1), (Fe, 1.9), (Pt, 0.1), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Pt, 'a'), (As, 2)]
# [(La, 1), (Ni, 1), (Si, 1)]
#    [(La, 1), (Ni, 1), (Si, 1)]
# [(Rb, 'x'), (Fe, '1-y'), (Se, 2)]
#    [(Rb, 'x'), (Fe, '1-y'), (Se, 2)]
# [(Nd, 1), (O, '1-y'), (Fe, 1), (As, 1)]
#    [(Nd, 1), (O, '1-y'), (Fe, 1), (As, 1)]
# [(Eu, 1), (B, 6)]
#    [(Eu, 1), (B, 6)]
# [(Pb, 1), (In, 1)]
#    [(Pb, 1), (In, 1)]
# [(Sn, 'x'), (Nb, 1), (Se, '2-δ')]
#    [(Sn, 'x'), (Nb, 1), (Se, '2-δ')]
# [(In, 'x'), (O, 1)]
#    [(In, 'x'), (O, 1)]
# [(Nd, 1), (Fe, 1), (As, 1), (O, 'x'), (F, 'y')]
#    [(Nd, 1), (Fe, 1), (As, 1), (O, 'x'), (F, 'y')]
# [(Li, 'x'), (Ti, 1), (N, 1), (Cl, 1)]
#    [(Li, 'x'), (Ti, 1), (N, 1), (Cl, 1)]
# [(Nb, 5), (Si, 2.4), (B, 0.6)]
#    [(Nb, 5), (Si, '3-a'), (B, 'a')]
# [(Ca, 1), (K, 1), ([(Fe, '1-x'), (Ni, 'x')], 4), (As, 4)]
#    [(Ca, 1), (K, 1), ([(Fe, '1-x'), (Ni, 'x')], 4), (As, 4)]
# [(Cs, 2), (Cr, 3), (As, 3)]
#    [(Cs, 2), (Cr, 3), (As, 3)]
# [(Fe, 1), (B, 4)]
#    [(Fe, 1), (B, 4)]
# [(C, 70)]
#    [(C, 70)]
# [(Pu, 1), (Fe, 1), (As, 1), (O, 1)]
#    [(Pu, 1), (Fe, 1), (As, 1), (O, 1)]
# [(Sc, 3), (Co, 13), (C, 4)]
#    [(Sc, 3), (Co, 13), (C, 4)]
# [(W, 'x'), (Si, '1-x')]
#    [(W, 'x'), (Si, '1-x')]
# [(Yb, 1), (O, 0.5), (F, 0.5), (Bi, 1), (S, 2)]
#    [(Yb, 1), (O, 'a'), (F, '1-a'), (Bi, 1), (S, 2)]
# [(Eu, 1), (Fe, 1), (As, 1), (O, 0.85), (F, 0.15)]
#    [(Eu, 1), (Fe, 1), (As, 1), (O, '1-a'), (F, 'a')]
# [(Cu, 1), (Ir, 2), (Te, 1.9), (I, 0.1)]
#    [(Cu, 1), (Ir, 2), (Te, '2-a'), (I, 'a')]
# [(La, 1), (Ru, 2), (As, 2)]
#    [(La, 1), (Ru, 2), (As, 2)]
# [(K, 72)]
#    [(K, 72)]
# [([(Nd, 1), (Ce, 1)], 2), (Cu, 1), (O, 4)]
#    [([(Nd, 1), (Ce, 1)], 2), (Cu, 1), (O, 4)]
# [(In, 2), (H, 1), (Nb, 1), (S, 2)]
#    [(In, 2), (H, 1), (Nb, 1), (S, 2)]
# [(Bi, 2), (Sr, '2-x'), (La, 'x'), (Cu, 1), (O, '6-δ')]
#    [(Bi, 2), (Sr, '2-x'), (La, 'x'), (Cu, 1), (O, '6-δ')]
# [(Li, 2), (Al, 1), (B, 4)]
#    [(Li, 2), (Al, 1), (B, 4)]
# [(Pr, 1), (Fe, 1), (As, 1), (O, 0.7), (F, 0.3)]
#    [(Pr, 1), (Fe, 1), (As, 1), (O, '1-a'), (F, 'a')]
# [(K, 0.62), (Fe, 1.7), (Se, 2)]
#    [(K, '1-a'), (Fe, '2-b'), (Se, 2)]
# [([(Tl, 1), (Rb, 1)], 'y'), (Fe, '2-x'), (Se, 2)]
#    [([(Tl, 1), (Rb, 1)], 'y'), (Fe, '2-x'), (Se, 2)]
# [(Li, 1), (Fe, 0.97), (Co, 0.03), (As, 1)]
#    [(Li, 1), (Fe, '1-a'), (Co, 'a'), (As, 1)]
# [(Pb, 0.38), (Bi, 1.74), (Sr, 1.88), (Cu, 1), (O, '6+δ')]
#    [(Pb, 'a'), (Bi, '2-b'), (Sr, '2-c'), (Cu, 1), (O, '6+δ')]
# [(C, 12), (H, 22), (O, 11)]
#    [(C, 12), (H, 22), (O, 11)]
# [(Zr, 1)]
#    [(Zr, 1)]
# [(Ba, 1), (Fe, 2), (P, 2)]
#    [(Ba, 1), (Fe, 2), (P, 2)]
# [(Ca, 1), (Ti, 1), (O, 3)]
#    [(Ca, 1), (Ti, 1), (O, 3)]
# [(C, 3), (H, 7), (N, 1), (O, 1)]
#    [(C, 3), (H, 7), (N, 1), (O, 1)]
# [([(La, 1), (Sr, 1)], 1), ([(Ta, 1), (Al, 1)], 1), (O, 3)]
#    [(La, 1), (Sr, 1), (Ta, 1), (Al, 1), (O, 3)]
# [(Rb, 2), (Cr, 3), (As, 3)]
#    [(Rb, 2), (Cr, 3), (As, 3)]
# [(Ca, '1-x'), (La, 'x'), (Fe, 1), ([(As, 0.99), (Sb, 0.01)], 2)]
#    [(Ca, '1-x'), (La, 'x'), (Fe, 1), ([(As, '1-a'), (Sb, 'a')], 2)]
# [(Sr, 1), (Fe, 1.57), (Ir, 0.43), (As, 2)]
#    [(Sr, 1), (Fe, '2-a'), (Ir, 'a'), (As, 2)]
# [(Lu, 2), (Fe, 3), (Si, 5)]
#    [(Lu, 2), (Fe, 3), (Si, 5)]
# [(Ca, 1), (Ir, 1), (Si, 3)]
#    [(Ca, 1), (Ir, 1), (Si, 3)]
# [(Cs, 1), (Bi, 4), (Te, 6)]
#    [(Cs, 1), (Bi, 4), (Te, 6)]
# [(Fe, 1), (Se, 0.8), (S, 0.2)]
#    [(Fe, 1), (Se, '1-a'), (S, 'a')]
# [(Nd, 1), (O, '1-x'), (F, 'x'), (Fe, 1), (As, 1)]
#    [(Nd, 1), (O, '1-x'), (F, 'x'), (Fe, 1), (As, 1)]
# [(Pr, '1.3-x'), (La, 0.7), (Ce, 'x'), (Cu, 1), (O, 4)]
#    [(Pr, '1.3-x'), (La, '1-a'), (Ce, 'x'), (Cu, 1), (O, 4)]
# [(S, 1), (W, 1), (N, 1), (Ts, 1)]
#    [(S, 1), (W, 1), (N, 1), (Ts, 1)]
# [(Fe, 1), (S, 1), (C, 1), (Ba, 2), (Fe, 2), (Ti, 2), (As, 4), (O, 1)]
#    [(Fe, 1), (S, 1), (C, 1), (Ba, 2), (Fe, 2), (Ti, 2), (As, 4), (O, 1)]
# [(Gd, 1), (Pd, 1), (Bi, 1)]
#    [(Gd, 1), (Pd, 1), (Bi, 1)]
# [(Ca, '2x'), (Na, 'x'), (Cu, 1), (O, 2), (Cl, 2)]
#    [(Ca, '2x'), (Na, 'x'), (Cu, 1), (O, 2), (Cl, 2)]
# [(Nb, 2), (S, 2), (C, 1)]
#    [(Nb, 2), (S, 2), (C, 1)]
# [(La, 1)]
#    [(La, 1)]
# [(La, 1), (Fe, 1), (As, 1), (O, '1-δ'), (F, 'δ')]
#    [(La, 1), (Fe, 1), (As, 1), (O, '1-δ'), (F, 'δ')]
# [(Pr, 1), (Ti, 2), (Al, 20)]
#    [(Pr, 1), (Ti, 2), (Al, 20)]
# [(Ba, 1), (Fe, 1.908), (Ni, 0.092), (As, 2)]
#    [(Ba, 1), (Fe, '2-a'), (Ni, 'a'), (As, 2)]
# [(La, 1.89), (Sr, 0.11), (Cu, 1), (O, 4)]
#    [(La, '2-a'), (Sr, 'a'), (Cu, 1), (O, 4)]
# [(Sr, 1), (F, 1), (Bi, 1), (S, 2)]
#    [(Sr, 1), (F, 1), (Bi, 1), (S, 2)]
# [(Mn, 'x'), (Ga, '1-x'), (As, 1)]
#    [(Mn, 'x'), (Ga, '1-x'), (As, 1)]
# [(La, 1.82), (Sr, 0.18), (Cu, 1), (O, 4)]
#    [(La, '2-a'), (Sr, 'a'), (Cu, 1), (O, 4)]
# [(La, 'x'), (Fe, 1), (As, 2)]
#    [(La, 'x'), (Fe, 1), (As, 2)]
# [(Se, 39)]
#    [(Se, 39)]
# [(La, 4), (Ni, 3), (O, 8)]
#    [(La, 4), (Ni, 3), (O, 8)]
# [(Cu, 3), (O, '6+x')]
#    [(Cu, 3), (O, '6+x')]
# [(Er, 1)]
#    [(Er, 1)]
# [(Sm, 1), ([(O, 1), (F, 1)], 1), (Fe, 1), (As, 2)]
#    [(Sm, 1), (O, 1), (F, 1), (Fe, 1), (As, 2)]
# [(La, 1.94), (Sr, 0.06), (Cu, 1), (O, '4+y')]
#    [(La, '2-a'), (Sr, 'a'), (Cu, 1), (O, '4+y')]
# [(Pb, 0.3), (Bi, 0.7)]
#    [(Pb, 'a'), (Bi, '1-a')]
# [(La, 1), (Fe, 1), (As, 1), (O, 'y')]
#    [(La, 1), (Fe, 1), (As, 1), (O, 'y')]
# [(Bi, 2), (Ba, 2), (Cu, 1), (O, '6+δ')]
#    [(Bi, 2), (Ba, 2), (Cu, 1), (O, '6+δ')]
# [(Fe, '1+x'), (Te, '1-y'), (Se, 'y')]
#    [(Fe, '1+x'), (Te, '1-y'), (Se, 'y')]
# [(Ba, 0.12), (K, 0.88), (Fe, 2), (As, 2)]
#    [(Ba, 'a'), (K, '1-a'), (Fe, 2), (As, 2)]
# [(Ca, 1), (Rb, 1), (Fe, 4), (As, 4)]
#    [(Ca, 1), (Rb, 1), (Fe, 4), (As, 4)]
# [(Mg, 0.2), (Ti, 0.8)]
#    [(Mg, 'a'), (Ti, '1-a')]
# [(Eu, 3), (Bi, 2), (S, 4), (F, 4)]
#    [(Eu, 3), (Bi, 2), (S, 4), (F, 4)]
# [(Ga, 1), (As, 1), (H, 6)]
#    [(Ga, 1), (As, 1), (H, 6)]
# [(Fe, 1), (Te, 0.8), (Se, 0.2)]
#    [(Fe, 1), (Te, '1-a'), (Se, 'a')]
# [(Ca, 1), ([(Fe, 0.927), (Co, 0.073)], 2), (As, 2)]
#    [(Ca, 1), ([(Fe, '1-a'), (Co, 'a')], 2), (As, 2)]
# [([(K, 1), (Tl, 1), (Rb, 1), (Cs, 1)], 'x'), (Fe, '2-y'), (Se, 2)]
#    [([(K, 1), (Tl, 1), (Rb, 1), (Cs, 1)], 'x'), (Fe, '2-y'), (Se, 2)]
# [(Cu, 0.05), (Pd, 1), (Te, 2)]
#    [(Cu, 'a'), (Pd, 1), (Te, 2)]
# [(Bi, '2+z'), (Sr, '2-z'), (Cu, 1), (O, 'y')]
#    [(Bi, '2+z'), (Sr, '2-z'), (Cu, 1), (O, 'y')]
# [(Fe, 2), (As, 2)]
#    [(Fe, 2), (As, 2)]
# [(Ru, 0.75), (Rh, 0.25), (As, 1)]
#    [(Ru, '1-a'), (Rh, 'a'), (As, 1)]
# [(Nb, 20), (Re, 20), (Zr, 20), (Hf, 20), (Ti, 20)]
#    [(Nb, 20), (Re, 20), (Zr, 20), (Hf, 20), (Ti, 20)]
# [(Ba, 1), ([(Fe, 0.915), (Co, 0.085)], 2), (As, 2)]
#    [(Ba, 1), ([(Fe, '1-a'), (Co, 'a')], 2), (As, 2)]
# [(Ce, 1), (Cr, 1), (Sb, 3)]
#    [(Ce, 1), (Cr, 1), (Sb, 3)]
# [(Y, 3), (Ba, 5), (Cu, 8), (O, 7)]
#    [(Y, 3), (Ba, 5), (Cu, 8), (O, 7)]
# [(Ga, 1), (Nb, 4), (Se, 8)]
#    [(Ga, 1), (Nb, 4), (Se, 8)]
# [(Y, 2), (Ba, 4), (Cu, 7), (O, 7)]
#    [(Y, 2), (Ba, 4), (Cu, 7), (O, 7)]
# [(Y, 0.7), (Pr, 0.3), (Ba, 2), (Cu, 3), (O, 1)]
#    [(Y, '1-a'), (Pr, 'a'), (Ba, 2), (Cu, 3), (O, 1)]
# [(Li, 'x'), ([(C, 2), (H, 8), (N, 2)], 'y'), (Fe, '2-z'), (Se, 2)]
#    [(Li, 'x'), ([(C, 2), (H, 8), (N, 2)], 'y'), (Fe, '2-z'), (Se, 2)]
# [(Sn, 1), (H, 'x')]
#    [(Sn, 1), (H, 'x')]
# [(Nd, 1), (Fe, 1), (As, 1), (O, 0.85), (F, 0.15)]
#    [(Nd, 1), (Fe, 1), (As, 1), (O, '1-a'), (F, 'a')]
# [(Pr, 1), (O, 0.89), (F, 0.11), (Fe, 1), (As, 1)]
#    [(Pr, 1), (O, '1-a'), (F, 'a'), (Fe, 1), (As, 1)]
# [(S, 1), (Cs, 1)]
#    [(S, 1), (Cs, 1)]
# [(Sn, 1), (Se, 2)]
#    [(Sn, 1), (Se, 2)]
# [(Hg, 1), (Ba, 2), (Ca, 'n-1'), (Cu, 'n'), (O, '2n+2+δ')]
#    [(Hg, 1), (Ba, 2), (Ca, 'n-1'), (Cu, 'n'), (O, '2n+2+δ')]
# [(Ti, 4), (Rh, 2), (O, 1)]
#    [(Ti, 4), (Rh, 2), (O, 1)]
# [(N, 1), (C, 1), (S, 1), (C, 1), (Mo, 3), (Rh, 2), (N, 1)]
#    [(N, 1), (C, 1), (S, 1), (C, 1), (Mo, 3), (Rh, 2), (N, 1)]
# [(Nb, 2), (Se, 3)]
#    [(Nb, 2), (Se, 3)]
# [(Mg, 1), (H, 6)]
#    [(Mg, 1), (H, 6)]
# [(Cr, 1), (Br, 3)]
#    [(Cr, 1), (Br, 3)]
# [([(Y, 0.94), (Ca, 0.06)], 1), (Ba, 2), (Cu, 4), (O, 8)]
#    [(Y, '1-a'), (Ca, 'a'), (Ba, 2), (Cu, 4), (O, 8)]
# [(K, 0.77), (Fe, 1.65), (Se, 2)]
#    [(K, '1-a'), (Fe, '2-b'), (Se, 2)]
# [(Mg, '1-x'), (Mn, 'x'), (B, 2)]
#    [(Mg, '1-x'), (Mn, 'x'), (B, 2)]
# [(Ca, '1-x'), (La, 'x'), (Fe, '1-y'), (Co, 'y'), (As, 2)]
#    [(Ca, '1-x'), (La, 'x'), (Fe, '1-y'), (Co, 'y'), (As, 2)]
# [(Ta, 1), (O, 1)]
#    [(Ta, 1), (O, 1)]
# [(Mo, 52), (Re, 48)]
#    [(Mo, 52), (Re, 48)]
# [(K, 0.8), (Fe, 2.2), (Se, 2)]
#    [(K, 'a'), (Fe, '3-a'), (Se, 2)]
# [(La, 1), (Ir, 2), (Ge, 2)]
#    [(La, 1), (Ir, 2), (Ge, 2)]
# [(Th, 4), (H, 15)]
#    [(Th, 4), (H, 15)]
# [(N, 1), (S, 4)]
#    [(N, 1), (S, 4)]
# [(Ba, 1), ([(Fe, 0.5), (Ru, 0.5)], 2), (As, 2)]
#    [(Ba, 1), ([(Fe, 'a'), (Ru, '1-a')], 2), (As, 2)]
# [(Tl, 2), (Ba, 2), (Ca, 2), (Cu, 3), (O, '6+x')]
#    [(Tl, 2), (Ba, 2), (Ca, 2), (Cu, 3), (O, '6+x')]
# [(Fe, 1.074), (Te, 1)]
#    [(Fe, '2-a'), (Te, 1)]
# [(La, 3), (Pd, 5), (Si, 1)]
#    [(La, 3), (Pd, 5), (Si, 1)]
# [([(Sr, '1-x'), (Ca, 'x')], '1-y'), (Cu, 1), (O, 2)]
#    [([(Sr, '1-x'), (Ca, 'x')], '1-y'), (Cu, 1), (O, 2)]
# [(Nd, 1), (Fe, 1), (As, 1), (O, 0.8), (F, 0.2)]
#    [(Nd, 1), (Fe, 1), (As, 1), (O, '1-a'), (F, 'a')]
# [(Y, 1), (Ba, 2), (Cu, 3), (O, 6.44)]
#    [(Y, 1), (Ba, 2), (Cu, 3), (O, '7-a')]
# [(Lu, 5), (Ir, 4), (Si, 10)]
#    [(Lu, 5), (Ir, 4), (Si, 10)]
# [(Be, 1)]
#    [(Be, 1)]
# [(La, 1.86), (Sr, 0.14), (Cu, 0.988), (Zn, 0.012), (O, '4-δ')]
#    [(La, '2-a'), (Sr, 'a'), (Cu, '1-b'), (Zn, 'b'), (O, '4-δ')]
# [(Pu, 1), (Rh, 1), (Ga, 5)]
#    [(Pu, 1), (Rh, 1), (Ga, 5)]
# [(Ca, 1), (F, 1), (Fe, 1), (As, 1)]
#    [(Ca, 1), (F, 1), (Fe, 1), (As, 1)]
# [(K, 1), (F, 1), (S, 1), (S, 1), (C, 1)]
#    [(K, 1), (F, 1), (S, 1), (S, 1), (C, 1)]
# [(Ca, 1), (Fe, '1-x'), (Co, 'x'), (As, 1), (F, 1)]
#    [(Ca, 1), (Fe, '1-x'), (Co, 'x'), (As, 1), (F, 1)]
# [(K, 2)]
#    [(K, 2)]
# [(Fe, 1.03), (Se, 0.3), (Te, 0.7)]
#    [(Fe, '2-b'), (Se, 'a'), (Te, '1-a')]
# [(Ca, 1), (C, 2)]
#    [(Ca, 1), (C, 2)]
# [([(Bi, 1), (P, 'b')], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, 10)]
#    [([(Bi, 1), (P, 'b')], 2), (Sr, 2), (Ca, 2), (Cu, 3), (O, 10)]
# [(Lu, 3), (Fe, 3), (Si, 5)]
#    [(Lu, 3), (Fe, 3), (Si, 5)]
# [(Ba, 1), ([(Fe, 0.955), (Co, 0.045)], 2), (As, 2)]
#    [(Ba, 1), ([(Fe, '1-a'), (Co, 'a')], 2), (As, 2)]
# [(Bi, 2), (Sr, 2), (Ca, 0.8), (Y, 0.2), (Cu, 2), (O, 'y')]
#    [(Bi, 2), (Sr, 2), (Ca, '1-a'), (Y, 'a'), (Cu, 2), (O, 'y')]
# [(La, 1), (Al, 1), (O, 3)]
#    [(La, 1), (Al, 1), (O, 3)]
# [(La, 1), (Fe, 1), (As, 1), (O, '1-d')]
#    [(La, 1), (Fe, 1), (As, 1), (O, '1-d')]

# %% [markdown]
# ### Compare with Supercon v1 dataset:

# %%
# separate out known T_c from unknown T_c data:
known_tc = (supercon_df.Tc != 0)
supercon_df['KnownTc'] = known_tc

print('Supercon v1 materials: ', len(supercon_df))
print('Supercon v2 materials: ', len(cleaned_supercon2_df))
# Out:
# Supercon v1 materials:  16414
# Supercon v2 materials:  23881
